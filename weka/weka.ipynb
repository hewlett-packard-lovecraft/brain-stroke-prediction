# %%
import pandas as pd

# %%
weka_df = pd.read_csv('./brain_stroke_prediction.csv')

weka_df
# Out:
#              Key_Dataset  Key_Run  \
# 0   full_data_clean_weka        1
# 1   full_data_clean_weka        2
# 2   full_data_clean_weka        3
# 3   full_data_clean_weka        4
# 4   full_data_clean_weka        5
# 5   full_data_clean_weka        6
# 6   full_data_clean_weka        7
# 7   full_data_clean_weka        8
# 8   full_data_clean_weka        9
# 9   full_data_clean_weka       10
# 10  full_data_clean_weka        1
# 11  full_data_clean_weka        2
# 12  full_data_clean_weka        3
# 13  full_data_clean_weka        4
# 14  full_data_clean_weka        5
# 15  full_data_clean_weka        6
# 16  full_data_clean_weka        7
# 17  full_data_clean_weka        8
# 18  full_data_clean_weka        9
# 19  full_data_clean_weka       10
# 20  full_data_clean_weka        1
# 21  full_data_clean_weka        2
# 22  full_data_clean_weka        3
# 23  full_data_clean_weka        4
# 24  full_data_clean_weka        5
# 25  full_data_clean_weka        6
# ...

# %%
weka_df['Area_under_ROC']
# Out:
# 0     0.655639
# 1     0.742520
# 2     0.716430
# 3     0.678928
# 4     0.725127
# 5     0.729600
# 6     0.710418
# 7     0.559964
# 8     0.703148
# 9     0.729755
# 10    0.500000
# 11    0.500000
# 12    0.500000
# 13    0.500000
# 14    0.500000
# 15    0.500000
# 16    0.500000
# 17    0.500000
# 18    0.500000
# 19    0.500000
# 20    0.710171
# 21    0.713202
# 22    0.625757
# 23    0.541111
# 24    0.599705
# 25    0.708663
# 26    0.504491
# 27    0.460239
# 28    0.603755
# 29    0.620921
# Name: Area_under_ROC, dtype: float64
