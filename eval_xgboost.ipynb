# %%
import pandas as pd
import random
import sklearn

from pathlib import Path
import xgboost as xgb
from xgboost.callback import EarlyStopping
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTENC

# %%
CATEGORICAL_FEATURE_NAMES = [
    "gender",
    "hypertension",
    "heart_disease",
    "ever_married",
    "work_type",
    "residence_type",
    "smoking_status",
]

NUMERIC_FEATURE_NAMES = ["age", "avg_glucose_level", "bmi"]


def encode_int(data: pd.DataFrame, categorical_features: list[str]):
    return pd.get_dummies(data, columns=categorical_features, drop_first=True)


def split_label(data: pd.DataFrame):
    x = data.copy().drop("stroke", axis=1)
    y = data["stroke"]  # labels

    return x, y


def resample(data: pd.DataFrame, seed: int, categorical_features: list[str]):
    """oversample positive cases with SMOTE and undersample negative with EEN"""
    # encode categorical features first
    enc = OrdinalEncoder()
    data[categorical_features] = enc.fit_transform(data[categorical_features])

    X = data.drop(columns=["stroke"], axis=1)
    Y = data["stroke"]

    cat_features_indices = [
        data.columns.get_loc(label) for label in categorical_features
    ]

    smote_nc = SMOTENC(categorical_features=cat_features_indices, random_state=seed)
    smote_een = SMOTEENN(smote=smote_nc, random_state=seed, sampling_strategy="auto")

    x_resampled, y_resampled = smote_een.fit_resample(X, Y)
    x_resampled["stroke"] = y_resampled

    x_resampled[categorical_features] = enc.inverse_transform(
        x_resampled[categorical_features]
    )

    return pd.DataFrame(x_resampled, columns=data.columns)


def scale(df):
    X_num = df[NUMERIC_FEATURE_NAMES]
    X_cat = df[CATEGORICAL_FEATURE_NAMES]

    scaler = StandardScaler()
    scaler.fit(X_num)

    X_scaled = scaler.transform(X_num)
    X_scaled = pd.DataFrame(X_scaled, index=X_num.index, columns=X_num.columns)

    df_scaled = pd.concat([X_scaled, X_cat, df["stroke"]], axis=1)

    return df_scaled


def split_train_valid_test(data_df, seed: int, resample_training: bool):
    data_df = data_df.sample(frac=1, random_state=seed)

    test_set = data_df[round(len(data_df) * 0.85) :]
    train_validation_data = data_df[: round(len(data_df) * 0.85)].sample(
        frac=1, random_state=seed
    )

    train_set = train_validation_data[: round(len(data_df) * 0.70)]
    validation_set = train_validation_data[round(len(data_df) * 0.70) :]

    if resample_training:
        train_set = resample(
            train_set, seed, categorical_features=CATEGORICAL_FEATURE_NAMES
        )

    return train_set, validation_set, test_set


def one_hot_encode(
    data_df: pd.DataFrame,
    train_df: pd.DataFrame,
    validation_df: pd.DataFrame,
    test_df: pd.DataFrame,
):
    # ensure train, validation, and test all have the same columns after ohe

    ohe_columns = encode_int(data_df, CATEGORICAL_FEATURE_NAMES).columns

    train_df_e, validation_df_e, test_df_e = [
        pd.DataFrame(
            encode_int(data=df, categorical_features=CATEGORICAL_FEATURE_NAMES),
            columns=ohe_columns,
        ).fillna(0)
        for df in [train_df, validation_df, test_df]
    ]

    return train_df_e, validation_df_e, test_df_e


def prepare_data(seed: int, resample_training: bool):
    data_df = pd.read_csv(Path().resolve().joinpath("dataset/full_data_clean.csv"))

    train_df, validation_df, test_df = split_train_valid_test(
        data_df, seed, resample_training
    )

    train_df, validation_df, test_df = [
        scale(df) for df in [train_df, validation_df, test_df]
    ]

    return one_hot_encode(data_df, train_df, validation_df, test_df)

# %%
RESULT_COLS = [
    "classifier",
    "precision",
    "recall",
    "fscore",
    "accuracy",
    "auc",
    "miss_rate",
    "fall_out_rate",
]
NUM_EXPERIMENTS = 10
NUM_ROUNDS = 20


def metrics(y_pred, p_pred, y_true):
    tn, fp, fn, tp = confusion_matrix(y_pred=y_pred, y_true=y_true).ravel()

    # metrics
    auc = roc_auc_score(y_true=y_true, y_score=p_pred)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    fscore = 2 * tp / (2 * tp + fp + fn)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    miss_rate = fn / (tn + tp)
    fall_out_rate = fp / (fp + tn)

    # return
    return [precision, recall, fscore, accuracy, auc, miss_rate, fall_out_rate]

# %%
def run_experiment(seed, experiment, train_data, validation_data, test_data):
    # split labels
    train_validation = pd.concat([train_data, validation_data]).sample(
        frac=1, random_state=seed
    )

    x, y = split_label(train_validation)
    x_test, y_test = split_label(test_data)

    # metrics
    param = {"max_depth": 2, "eta": 1, "objective": "binary:logistic"}

    es = EarlyStopping(
        rounds=3,
        save_best=True,
        maximize=True,
        data_name="validation_0",
        metric_name="auc",
    )

    clf = xgb.sklearn.XGBClassifier(
        learning_rate=0.1,
        objective=param["objective"],
        gpu_id=0,
        predictor="gpu_predictor",
    )

    clf.fit(x, y, eval_set=[(x_test, y_test), (x, y)])

    y_pred = clf.predict(x_test)
    p_pred = clf.predict_proba(x_test)[:, 1]

    return y_pred, p_pred, y_test

# %%
# evaluate xgboost

results = {}
results_resample = {}

for experiment in range(NUM_EXPERIMENTS):
    seed = random.randint(0, 1000)

    train_data, validation_data, test_data = prepare_data(
        seed=experiment, resample_training=False
    )

    y_pred, p_pred, y_test = run_experiment(
        seed, experiment, train_data, validation_data, test_data
    )

    results[experiment] = list(metrics(y_pred, p_pred, y_test))

    train_data, validation_data, test_data = prepare_data(
        seed=experiment, resample_training=True
    )

    y_pred, p_pred, y_test = run_experiment(
        seed, experiment, train_data, validation_data, test_data
    )

    results_resample[experiment] = list(metrics(y_pred, p_pred, y_test))


results = (
    pd.DataFrame()
    .from_dict(results, orient="index", columns=RESULT_COLS)
    .assign(classifier="XGBoost")
)
results_resample = (
    pd.DataFrame()
    .from_dict(results_resample, orient="index", columns=RESULT_COLS)
    .assign(classifier="XGBoost")
)

results.to_csv(Path().resolve().joinpath("results/XGBoost_eval.csv"))
results_resample.to_csv(Path().resolve().joinpath("results/XGBoost_eval_resampled.csv"))
# Out:
# [0]	validation_0-logloss:0.60470	validation_1-logloss:0.60458
# [1]	validation_0-logloss:0.53225	validation_1-logloss:0.53207
# [2]	validation_0-logloss:0.47204	validation_1-logloss:0.47171
# [3]	validation_0-logloss:0.42115	validation_1-logloss:0.42079
# [4]	validation_0-logloss:0.37791	validation_1-logloss:0.37738
# [5]	validation_0-logloss:0.34087	validation_1-logloss:0.34007
# [6]	validation_0-logloss:0.30877	validation_1-logloss:0.30783
# [7]	validation_0-logloss:0.28103	validation_1-logloss:0.27981
# [8]	validation_0-logloss:0.25671	validation_1-logloss:0.25538
# [9]	validation_0-logloss:0.23548	validation_1-logloss:0.23399
# [10]	validation_0-logloss:0.21679	validation_1-logloss:0.21517
# [11]	validation_0-logloss:0.20041	validation_1-logloss:0.19861
# [12]	validation_0-logloss:0.18593	validation_1-logloss:0.18401
# [13]	validation_0-logloss:0.17318	validation_1-logloss:0.17108
# [14]	validation_0-logloss:0.16197	validation_1-logloss:0.15963
# [15]	validation_0-logloss:0.15200	validation_1-logloss:0.14951
# [16]	validation_0-logloss:0.14319	validation_1-logloss:0.14053
# [17]	validation_0-logloss:0.13543	validation_1-logloss:0.13249
# [18]	validation_0-logloss:0.12855	validation_1-logloss:0.12540
# [19]	validation_0-logloss:0.12251	validation_1-logloss:0.11908
# [20]	validation_0-logloss:0.11708	validation_1-logloss:0.11347
# [21]	validation_0-logloss:0.11231	validation_1-logloss:0.10842
# [22]	validation_0-logloss:0.10808	validation_1-logloss:0.10395
# [23]	validation_0-logloss:0.10427	validation_1-logloss:0.09990
# [24]	validation_0-logloss:0.10090	validation_1-logloss:0.09629
# [25]	validation_0-logloss:0.09791	validation_1-logloss:0.09305
# [26]	validation_0-logloss:0.09534	validation_1-logloss:0.09017
# [27]	validation_0-logloss:0.09294	validation_1-logloss:0.08757
# [28]	validation_0-logloss:0.09079	validation_1-logloss:0.08526
# [29]	validation_0-logloss:0.08892	validation_1-logloss:0.08319
# [30]	validation_0-logloss:0.08727	validation_1-logloss:0.08137
# [31]	validation_0-logloss:0.08581	validation_1-logloss:0.07972
# [32]	validation_0-logloss:0.08450	validation_1-logloss:0.07824
# [33]	validation_0-logloss:0.08336	validation_1-logloss:0.07689
# [34]	validation_0-logloss:0.08231	validation_1-logloss:0.07564
# [35]	validation_0-logloss:0.08149	validation_1-logloss:0.07452
# [36]	validation_0-logloss:0.08079	validation_1-logloss:0.07351
# [37]	validation_0-logloss:0.08005	validation_1-logloss:0.07259
# [38]	validation_0-logloss:0.07942	validation_1-logloss:0.07176
# [39]	validation_0-logloss:0.07882	validation_1-logloss:0.07103
# [40]	validation_0-logloss:0.07829	validation_1-logloss:0.07039
# [41]	validation_0-logloss:0.07776	validation_1-logloss:0.06983
# [42]	validation_0-logloss:0.07737	validation_1-logloss:0.06933
# [43]	validation_0-logloss:0.07704	validation_1-logloss:0.06887
# [44]	validation_0-logloss:0.07677	validation_1-logloss:0.06839
# [45]	validation_0-logloss:0.07653	validation_1-logloss:0.06802
# [46]	validation_0-logloss:0.07628	validation_1-logloss:0.06759
# [47]	validation_0-logloss:0.07613	validation_1-logloss:0.06727
# [48]	validation_0-logloss:0.07597	validation_1-logloss:0.06692
# [49]	validation_0-logloss:0.07585	validation_1-logloss:0.06662
# [50]	validation_0-logloss:0.07574	validation_1-logloss:0.06633
# [51]	validation_0-logloss:0.07569	validation_1-logloss:0.06609
# [52]	validation_0-logloss:0.07557	validation_1-logloss:0.06582
# [53]	validation_0-logloss:0.07544	validation_1-logloss:0.06553
# [54]	validation_0-logloss:0.07536	validation_1-logloss:0.06534
# [55]	validation_0-logloss:0.07531	validation_1-logloss:0.06516
# [56]	validation_0-logloss:0.07527	validation_1-logloss:0.06495
# [57]	validation_0-logloss:0.07526	validation_1-logloss:0.06480
# [58]	validation_0-logloss:0.07525	validation_1-logloss:0.06463
# [59]	validation_0-logloss:0.07525	validation_1-logloss:0.06449
# [60]	validation_0-logloss:0.07523	validation_1-logloss:0.06424
# [61]	validation_0-logloss:0.07521	validation_1-logloss:0.06409
# [62]	validation_0-logloss:0.07517	validation_1-logloss:0.06394
# [63]	validation_0-logloss:0.07517	validation_1-logloss:0.06382
# [64]	validation_0-logloss:0.07516	validation_1-logloss:0.06372
# [65]	validation_0-logloss:0.07511	validation_1-logloss:0.06360
# [66]	validation_0-logloss:0.07511	validation_1-logloss:0.06354
# [67]	validation_0-logloss:0.07507	validation_1-logloss:0.06343
# [68]	validation_0-logloss:0.07504	validation_1-logloss:0.06334
# [69]	validation_0-logloss:0.07508	validation_1-logloss:0.06316
# [70]	validation_0-logloss:0.07510	validation_1-logloss:0.06310
# [71]	validation_0-logloss:0.07509	validation_1-logloss:0.06303
# [72]	validation_0-logloss:0.07507	validation_1-logloss:0.06298
# [73]	validation_0-logloss:0.07512	validation_1-logloss:0.06293
# [74]	validation_0-logloss:0.07512	validation_1-logloss:0.06289
# [75]	validation_0-logloss:0.07512	validation_1-logloss:0.06284
# [76]	validation_0-logloss:0.07511	validation_1-logloss:0.06271
# [77]	validation_0-logloss:0.07516	validation_1-logloss:0.06267
# [78]	validation_0-logloss:0.07513	validation_1-logloss:0.06256
# [79]	validation_0-logloss:0.07516	validation_1-logloss:0.06252
# [80]	validation_0-logloss:0.07515	validation_1-logloss:0.06244
# [81]	validation_0-logloss:0.07520	validation_1-logloss:0.06231
# [82]	validation_0-logloss:0.07523	validation_1-logloss:0.06224
# [83]	validation_0-logloss:0.07518	validation_1-logloss:0.06213
# [84]	validation_0-logloss:0.07519	validation_1-logloss:0.06212
# [85]	validation_0-logloss:0.07521	validation_1-logloss:0.06206
# [86]	validation_0-logloss:0.07526	validation_1-logloss:0.06190
# [87]	validation_0-logloss:0.07531	validation_1-logloss:0.06182
# [88]	validation_0-logloss:0.07527	validation_1-logloss:0.06163
# [89]	validation_0-logloss:0.07531	validation_1-logloss:0.06153
# [90]	validation_0-logloss:0.07533	validation_1-logloss:0.06142
# [91]	validation_0-logloss:0.07534	validation_1-logloss:0.06140
# [92]	validation_0-logloss:0.07536	validation_1-logloss:0.06134
# [93]	validation_0-logloss:0.07540	validation_1-logloss:0.06124
# [94]	validation_0-logloss:0.07540	validation_1-logloss:0.06101
# [95]	validation_0-logloss:0.07542	validation_1-logloss:0.06097
# [96]	validation_0-logloss:0.07542	validation_1-logloss:0.06093
# [97]	validation_0-logloss:0.07540	validation_1-logloss:0.06077
# [98]	validation_0-logloss:0.07541	validation_1-logloss:0.06074
# [99]	validation_0-logloss:0.07542	validation_1-logloss:0.06072
# /tmp/ipykernel_245814/2120788987.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# /tmp/ipykernel_245814/272878867.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.66084	validation_1-logloss:0.63840
# [1]	validation_0-logloss:0.63752	validation_1-logloss:0.59322
# [2]	validation_0-logloss:0.61621	validation_1-logloss:0.55557
# [3]	validation_0-logloss:0.60097	validation_1-logloss:0.52365
# [4]	validation_0-logloss:0.58635	validation_1-logloss:0.49672
# [5]	validation_0-logloss:0.57554	validation_1-logloss:0.47229
# [6]	validation_0-logloss:0.56749	validation_1-logloss:0.45100
# [7]	validation_0-logloss:0.56020	validation_1-logloss:0.43224
# [8]	validation_0-logloss:0.55643	validation_1-logloss:0.41609
# [9]	validation_0-logloss:0.55402	validation_1-logloss:0.40201
# [10]	validation_0-logloss:0.55070	validation_1-logloss:0.38891
# [11]	validation_0-logloss:0.54674	validation_1-logloss:0.37749
# [12]	validation_0-logloss:0.54584	validation_1-logloss:0.36670
# [13]	validation_0-logloss:0.54248	validation_1-logloss:0.35743
# [14]	validation_0-logloss:0.54041	validation_1-logloss:0.34937
# [15]	validation_0-logloss:0.53837	validation_1-logloss:0.34110
# [16]	validation_0-logloss:0.53370	validation_1-logloss:0.33310
# [17]	validation_0-logloss:0.53174	validation_1-logloss:0.32692
# [18]	validation_0-logloss:0.53190	validation_1-logloss:0.32079
# [19]	validation_0-logloss:0.53287	validation_1-logloss:0.31557
# [20]	validation_0-logloss:0.52917	validation_1-logloss:0.30999
# [21]	validation_0-logloss:0.52854	validation_1-logloss:0.30557
# [22]	validation_0-logloss:0.52963	validation_1-logloss:0.30125
# [23]	validation_0-logloss:0.53016	validation_1-logloss:0.29712
# [24]	validation_0-logloss:0.52782	validation_1-logloss:0.29303
# [25]	validation_0-logloss:0.52628	validation_1-logloss:0.28931
# [26]	validation_0-logloss:0.52773	validation_1-logloss:0.28526
# [27]	validation_0-logloss:0.52919	validation_1-logloss:0.28199
# [28]	validation_0-logloss:0.53061	validation_1-logloss:0.27911
# [29]	validation_0-logloss:0.53407	validation_1-logloss:0.27536
# [30]	validation_0-logloss:0.53436	validation_1-logloss:0.27337
# [31]	validation_0-logloss:0.53694	validation_1-logloss:0.27114
# [32]	validation_0-logloss:0.53983	validation_1-logloss:0.26825
# [33]	validation_0-logloss:0.53995	validation_1-logloss:0.26613
# [34]	validation_0-logloss:0.53358	validation_1-logloss:0.26229
# [35]	validation_0-logloss:0.53586	validation_1-logloss:0.26007
# [36]	validation_0-logloss:0.53653	validation_1-logloss:0.25814
# [37]	validation_0-logloss:0.53324	validation_1-logloss:0.25585
# [38]	validation_0-logloss:0.53422	validation_1-logloss:0.25423
# [39]	validation_0-logloss:0.53115	validation_1-logloss:0.25224
# [40]	validation_0-logloss:0.53040	validation_1-logloss:0.25090
# [41]	validation_0-logloss:0.52966	validation_1-logloss:0.24988
# [42]	validation_0-logloss:0.52608	validation_1-logloss:0.24787
# [43]	validation_0-logloss:0.52601	validation_1-logloss:0.24565
# [44]	validation_0-logloss:0.52575	validation_1-logloss:0.24420
# [45]	validation_0-logloss:0.52202	validation_1-logloss:0.24168
# [46]	validation_0-logloss:0.52267	validation_1-logloss:0.23993
# [47]	validation_0-logloss:0.52366	validation_1-logloss:0.23881
# [48]	validation_0-logloss:0.52026	validation_1-logloss:0.23680
# [49]	validation_0-logloss:0.52015	validation_1-logloss:0.23581
# [50]	validation_0-logloss:0.52011	validation_1-logloss:0.23463
# [51]	validation_0-logloss:0.51936	validation_1-logloss:0.23377
# [52]	validation_0-logloss:0.51861	validation_1-logloss:0.23310
# [53]	validation_0-logloss:0.51944	validation_1-logloss:0.23232
# [54]	validation_0-logloss:0.51954	validation_1-logloss:0.23160
# [55]	validation_0-logloss:0.51989	validation_1-logloss:0.23046
# [56]	validation_0-logloss:0.52112	validation_1-logloss:0.22946
# [57]	validation_0-logloss:0.52259	validation_1-logloss:0.22829
# [58]	validation_0-logloss:0.52555	validation_1-logloss:0.22636
# [59]	validation_0-logloss:0.52279	validation_1-logloss:0.22479
# [60]	validation_0-logloss:0.52287	validation_1-logloss:0.22420
# [61]	validation_0-logloss:0.52126	validation_1-logloss:0.22239
# [62]	validation_0-logloss:0.52202	validation_1-logloss:0.22142
# [63]	validation_0-logloss:0.52360	validation_1-logloss:0.22071
# [64]	validation_0-logloss:0.52483	validation_1-logloss:0.22004
# [65]	validation_0-logloss:0.52162	validation_1-logloss:0.21759
# [66]	validation_0-logloss:0.52160	validation_1-logloss:0.21681
# [67]	validation_0-logloss:0.52484	validation_1-logloss:0.21520
# [68]	validation_0-logloss:0.52500	validation_1-logloss:0.21463
# [69]	validation_0-logloss:0.52572	validation_1-logloss:0.21399
# [70]	validation_0-logloss:0.52267	validation_1-logloss:0.21117
# [71]	validation_0-logloss:0.52268	validation_1-logloss:0.20912
# [72]	validation_0-logloss:0.52219	validation_1-logloss:0.20835
# [73]	validation_0-logloss:0.52258	validation_1-logloss:0.20739
# [74]	validation_0-logloss:0.51924	validation_1-logloss:0.20487
# [75]	validation_0-logloss:0.51945	validation_1-logloss:0.20412
# [76]	validation_0-logloss:0.51864	validation_1-logloss:0.20342
# [77]	validation_0-logloss:0.51804	validation_1-logloss:0.20273
# [78]	validation_0-logloss:0.52010	validation_1-logloss:0.20196
# [79]	validation_0-logloss:0.52204	validation_1-logloss:0.20091
# [80]	validation_0-logloss:0.52132	validation_1-logloss:0.20032
# [81]	validation_0-logloss:0.52205	validation_1-logloss:0.19985
# [82]	validation_0-logloss:0.52554	validation_1-logloss:0.19865
# [83]	validation_0-logloss:0.52954	validation_1-logloss:0.19674
# [84]	validation_0-logloss:0.53174	validation_1-logloss:0.19613
# [85]	validation_0-logloss:0.53312	validation_1-logloss:0.19544
# [86]	validation_0-logloss:0.53321	validation_1-logloss:0.19461
# [87]	validation_0-logloss:0.53585	validation_1-logloss:0.19245
# [88]	validation_0-logloss:0.53818	validation_1-logloss:0.19086
# [89]	validation_0-logloss:0.53695	validation_1-logloss:0.18944
# [90]	validation_0-logloss:0.53477	validation_1-logloss:0.18722
# [91]	validation_0-logloss:0.53639	validation_1-logloss:0.18686
# [92]	validation_0-logloss:0.53979	validation_1-logloss:0.18594
# [93]	validation_0-logloss:0.54266	validation_1-logloss:0.18455
# [94]	validation_0-logloss:0.54168	validation_1-logloss:0.18325
# [95]	validation_0-logloss:0.53991	validation_1-logloss:0.18154
# [96]	validation_0-logloss:0.54126	validation_1-logloss:0.18094
# [97]	validation_0-logloss:0.54247	validation_1-logloss:0.18052
# [98]	validation_0-logloss:0.54243	validation_1-logloss:0.17980
# [99]	validation_0-logloss:0.54148	validation_1-logloss:0.17852
# [0]	validation_0-logloss:0.60450	validation_1-logloss:0.60468
# [1]	validation_0-logloss:0.53183	validation_1-logloss:0.53228
# [2]	validation_0-logloss:0.47135	validation_1-logloss:0.47198
# [3]	validation_0-logloss:0.42036	validation_1-logloss:0.42110
# [4]	validation_0-logloss:0.37692	validation_1-logloss:0.37778
# [5]	validation_0-logloss:0.33960	validation_1-logloss:0.34059
# [6]	validation_0-logloss:0.30741	validation_1-logloss:0.30842
# [7]	validation_0-logloss:0.27935	validation_1-logloss:0.28046
# [8]	validation_0-logloss:0.25495	validation_1-logloss:0.25609
# [9]	validation_0-logloss:0.23360	validation_1-logloss:0.23478
# [10]	validation_0-logloss:0.21485	validation_1-logloss:0.21607
# [11]	validation_0-logloss:0.19836	validation_1-logloss:0.19961
# [12]	validation_0-logloss:0.18382	validation_1-logloss:0.18506
# [13]	validation_0-logloss:0.17094	validation_1-logloss:0.17221
# [14]	validation_0-logloss:0.15960	validation_1-logloss:0.16081
# [15]	validation_0-logloss:0.14960	validation_1-logloss:0.15069
# [16]	validation_0-logloss:0.14065	validation_1-logloss:0.14175
# [17]	validation_0-logloss:0.13280	validation_1-logloss:0.13380
# [18]	validation_0-logloss:0.12571	validation_1-logloss:0.12666
# [19]	validation_0-logloss:0.11952	validation_1-logloss:0.12034
# [20]	validation_0-logloss:0.11401	validation_1-logloss:0.11465
# [21]	validation_0-logloss:0.10914	validation_1-logloss:0.10958
# [22]	validation_0-logloss:0.10477	validation_1-logloss:0.10509
# [23]	validation_0-logloss:0.10093	validation_1-logloss:0.10108
# [24]	validation_0-logloss:0.09741	validation_1-logloss:0.09746
# [25]	validation_0-logloss:0.09430	validation_1-logloss:0.09424
# [26]	validation_0-logloss:0.09159	validation_1-logloss:0.09131
# [27]	validation_0-logloss:0.08920	validation_1-logloss:0.08874
# [28]	validation_0-logloss:0.08710	validation_1-logloss:0.08643
# [29]	validation_0-logloss:0.08510	validation_1-logloss:0.08440
# [30]	validation_0-logloss:0.08341	validation_1-logloss:0.08255
# [31]	validation_0-logloss:0.08189	validation_1-logloss:0.08090
# [32]	validation_0-logloss:0.08047	validation_1-logloss:0.07944
# [33]	validation_0-logloss:0.07932	validation_1-logloss:0.07806
# [34]	validation_0-logloss:0.07830	validation_1-logloss:0.07686
# [35]	validation_0-logloss:0.07738	validation_1-logloss:0.07577
# [36]	validation_0-logloss:0.07662	validation_1-logloss:0.07476
# [37]	validation_0-logloss:0.07594	validation_1-logloss:0.07387
# [38]	validation_0-logloss:0.07533	validation_1-logloss:0.07308
# [39]	validation_0-logloss:0.07480	validation_1-logloss:0.07230
# [40]	validation_0-logloss:0.07428	validation_1-logloss:0.07164
# [41]	validation_0-logloss:0.07387	validation_1-logloss:0.07106
# [42]	validation_0-logloss:0.07347	validation_1-logloss:0.07053
# [43]	validation_0-logloss:0.07309	validation_1-logloss:0.07001
# [44]	validation_0-logloss:0.07278	validation_1-logloss:0.06959
# [45]	validation_0-logloss:0.07260	validation_1-logloss:0.06915
# [46]	validation_0-logloss:0.07237	validation_1-logloss:0.06875
# [47]	validation_0-logloss:0.07214	validation_1-logloss:0.06844
# [48]	validation_0-logloss:0.07195	validation_1-logloss:0.06814
# [49]	validation_0-logloss:0.07184	validation_1-logloss:0.06780
# [50]	validation_0-logloss:0.07167	validation_1-logloss:0.06752
# [51]	validation_0-logloss:0.07155	validation_1-logloss:0.06716
# [52]	validation_0-logloss:0.07153	validation_1-logloss:0.06682
# [53]	validation_0-logloss:0.07141	validation_1-logloss:0.06657
# [54]	validation_0-logloss:0.07134	validation_1-logloss:0.06635
# [55]	validation_0-logloss:0.07127	validation_1-logloss:0.06621
# [56]	validation_0-logloss:0.07125	validation_1-logloss:0.06601
# [57]	validation_0-logloss:0.07120	validation_1-logloss:0.06580
# [58]	validation_0-logloss:0.07118	validation_1-logloss:0.06563
# [59]	validation_0-logloss:0.07113	validation_1-logloss:0.06546
# [60]	validation_0-logloss:0.07108	validation_1-logloss:0.06530
# [61]	validation_0-logloss:0.07106	validation_1-logloss:0.06518
# [62]	validation_0-logloss:0.07104	validation_1-logloss:0.06508
# [63]	validation_0-logloss:0.07103	validation_1-logloss:0.06498
# [64]	validation_0-logloss:0.07102	validation_1-logloss:0.06490
# [65]	validation_0-logloss:0.07106	validation_1-logloss:0.06470
# [66]	validation_0-logloss:0.07107	validation_1-logloss:0.06459
# [67]	validation_0-logloss:0.07103	validation_1-logloss:0.06450
# [68]	validation_0-logloss:0.07106	validation_1-logloss:0.06437
# [69]	validation_0-logloss:0.07110	validation_1-logloss:0.06429
# [70]	validation_0-logloss:0.07111	validation_1-logloss:0.06422
# [71]	validation_0-logloss:0.07114	validation_1-logloss:0.06415
# [72]	validation_0-logloss:0.07119	validation_1-logloss:0.06406
# [73]	validation_0-logloss:0.07120	validation_1-logloss:0.06400
# [74]	validation_0-logloss:0.07120	validation_1-logloss:0.06391
# [75]	validation_0-logloss:0.07122	validation_1-logloss:0.06385
# [76]	validation_0-logloss:0.07122	validation_1-logloss:0.06368
# [77]	validation_0-logloss:0.07123	validation_1-logloss:0.06365
# [78]	validation_0-logloss:0.07126	validation_1-logloss:0.06360
# [79]	validation_0-logloss:0.07126	validation_1-logloss:0.06351
# [80]	validation_0-logloss:0.07135	validation_1-logloss:0.06323
# [81]	validation_0-logloss:0.07141	validation_1-logloss:0.06317
# [82]	validation_0-logloss:0.07141	validation_1-logloss:0.06312
# [83]	validation_0-logloss:0.07142	validation_1-logloss:0.06308
# [84]	validation_0-logloss:0.07150	validation_1-logloss:0.06296
# [85]	validation_0-logloss:0.07156	validation_1-logloss:0.06279
# [86]	validation_0-logloss:0.07162	validation_1-logloss:0.06273
# [87]	validation_0-logloss:0.07161	validation_1-logloss:0.06269
# [88]	validation_0-logloss:0.07163	validation_1-logloss:0.06262
# [89]	validation_0-logloss:0.07164	validation_1-logloss:0.06257
# [90]	validation_0-logloss:0.07167	validation_1-logloss:0.06248
# [91]	validation_0-logloss:0.07173	validation_1-logloss:0.06243
# [92]	validation_0-logloss:0.07176	validation_1-logloss:0.06238
# [93]	validation_0-logloss:0.07178	validation_1-logloss:0.06231
# [94]	validation_0-logloss:0.07180	validation_1-logloss:0.06226
# [95]	validation_0-logloss:0.07182	validation_1-logloss:0.06223
# [96]	validation_0-logloss:0.07190	validation_1-logloss:0.06208
# [97]	validation_0-logloss:0.07191	validation_1-logloss:0.06205
# [98]	validation_0-logloss:0.07192	validation_1-logloss:0.06203
# [99]	validation_0-logloss:0.07191	validation_1-logloss:0.06193
# /tmp/ipykernel_245814/2120788987.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# /tmp/ipykernel_245814/272878867.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.65936	validation_1-logloss:0.63498
# [1]	validation_0-logloss:0.63505	validation_1-logloss:0.58792
# [2]	validation_0-logloss:0.61496	validation_1-logloss:0.54817
# [3]	validation_0-logloss:0.59996	validation_1-logloss:0.51369
# [4]	validation_0-logloss:0.58842	validation_1-logloss:0.48486
# [5]	validation_0-logloss:0.58115	validation_1-logloss:0.45924
# [6]	validation_0-logloss:0.57489	validation_1-logloss:0.43720
# [7]	validation_0-logloss:0.56841	validation_1-logloss:0.41805
# [8]	validation_0-logloss:0.55922	validation_1-logloss:0.40061
# [9]	validation_0-logloss:0.55802	validation_1-logloss:0.38622
# [10]	validation_0-logloss:0.55410	validation_1-logloss:0.37280
# [11]	validation_0-logloss:0.55466	validation_1-logloss:0.36148
# [12]	validation_0-logloss:0.55065	validation_1-logloss:0.35046
# [13]	validation_0-logloss:0.54874	validation_1-logloss:0.34057
# [14]	validation_0-logloss:0.54877	validation_1-logloss:0.33182
# [15]	validation_0-logloss:0.54904	validation_1-logloss:0.32433
# [16]	validation_0-logloss:0.55199	validation_1-logloss:0.31765
# [17]	validation_0-logloss:0.55198	validation_1-logloss:0.31141
# [18]	validation_0-logloss:0.54938	validation_1-logloss:0.30396
# [19]	validation_0-logloss:0.55036	validation_1-logloss:0.29890
# [20]	validation_0-logloss:0.54901	validation_1-logloss:0.29428
# [21]	validation_0-logloss:0.55413	validation_1-logloss:0.28939
# [22]	validation_0-logloss:0.55543	validation_1-logloss:0.28525
# [23]	validation_0-logloss:0.56035	validation_1-logloss:0.28109
# [24]	validation_0-logloss:0.55721	validation_1-logloss:0.27625
# [25]	validation_0-logloss:0.55635	validation_1-logloss:0.27208
# [26]	validation_0-logloss:0.55728	validation_1-logloss:0.26887
# [27]	validation_0-logloss:0.55532	validation_1-logloss:0.26557
# [28]	validation_0-logloss:0.55394	validation_1-logloss:0.26281
# [29]	validation_0-logloss:0.55729	validation_1-logloss:0.25939
# [30]	validation_0-logloss:0.55815	validation_1-logloss:0.25686
# [31]	validation_0-logloss:0.55803	validation_1-logloss:0.25461
# [32]	validation_0-logloss:0.56054	validation_1-logloss:0.25165
# [33]	validation_0-logloss:0.55299	validation_1-logloss:0.24779
# [34]	validation_0-logloss:0.55216	validation_1-logloss:0.24519
# [35]	validation_0-logloss:0.55217	validation_1-logloss:0.24286
# [36]	validation_0-logloss:0.54889	validation_1-logloss:0.24056
# [37]	validation_0-logloss:0.54828	validation_1-logloss:0.23818
# [38]	validation_0-logloss:0.54451	validation_1-logloss:0.23619
# [39]	validation_0-logloss:0.54596	validation_1-logloss:0.23474
# [40]	validation_0-logloss:0.54518	validation_1-logloss:0.23277
# [41]	validation_0-logloss:0.53788	validation_1-logloss:0.22990
# [42]	validation_0-logloss:0.53693	validation_1-logloss:0.22908
# [43]	validation_0-logloss:0.53676	validation_1-logloss:0.22792
# [44]	validation_0-logloss:0.53103	validation_1-logloss:0.22554
# [45]	validation_0-logloss:0.53240	validation_1-logloss:0.22450
# [46]	validation_0-logloss:0.53055	validation_1-logloss:0.22330
# [47]	validation_0-logloss:0.53151	validation_1-logloss:0.22253
# [48]	validation_0-logloss:0.52869	validation_1-logloss:0.22093
# [49]	validation_0-logloss:0.52733	validation_1-logloss:0.21861
# [50]	validation_0-logloss:0.52690	validation_1-logloss:0.21821
# [51]	validation_0-logloss:0.52483	validation_1-logloss:0.21694
# [52]	validation_0-logloss:0.52140	validation_1-logloss:0.21481
# [53]	validation_0-logloss:0.52121	validation_1-logloss:0.21367
# [54]	validation_0-logloss:0.52172	validation_1-logloss:0.21289
# [55]	validation_0-logloss:0.52026	validation_1-logloss:0.21175
# [56]	validation_0-logloss:0.52250	validation_1-logloss:0.21076
# [57]	validation_0-logloss:0.52254	validation_1-logloss:0.20929
# [58]	validation_0-logloss:0.51971	validation_1-logloss:0.20751
# [59]	validation_0-logloss:0.51997	validation_1-logloss:0.20602
# [60]	validation_0-logloss:0.51938	validation_1-logloss:0.20494
# [61]	validation_0-logloss:0.51882	validation_1-logloss:0.20380
# [62]	validation_0-logloss:0.51647	validation_1-logloss:0.20269
# [63]	validation_0-logloss:0.51480	validation_1-logloss:0.20189
# [64]	validation_0-logloss:0.51022	validation_1-logloss:0.19964
# [65]	validation_0-logloss:0.51181	validation_1-logloss:0.19838
# [66]	validation_0-logloss:0.51181	validation_1-logloss:0.19673
# [67]	validation_0-logloss:0.50658	validation_1-logloss:0.19342
# [68]	validation_0-logloss:0.50723	validation_1-logloss:0.19285
# [69]	validation_0-logloss:0.50868	validation_1-logloss:0.19191
# [70]	validation_0-logloss:0.50779	validation_1-logloss:0.19024
# [71]	validation_0-logloss:0.50296	validation_1-logloss:0.18745
# [72]	validation_0-logloss:0.50165	validation_1-logloss:0.18567
# [73]	validation_0-logloss:0.50056	validation_1-logloss:0.18498
# [74]	validation_0-logloss:0.49905	validation_1-logloss:0.18433
# [75]	validation_0-logloss:0.49865	validation_1-logloss:0.18361
# [76]	validation_0-logloss:0.49669	validation_1-logloss:0.18214
# [77]	validation_0-logloss:0.49767	validation_1-logloss:0.18173
# [78]	validation_0-logloss:0.49953	validation_1-logloss:0.18082
# [79]	validation_0-logloss:0.50101	validation_1-logloss:0.18014
# [80]	validation_0-logloss:0.50092	validation_1-logloss:0.17973
# [81]	validation_0-logloss:0.50374	validation_1-logloss:0.17809
# [82]	validation_0-logloss:0.50364	validation_1-logloss:0.17693
# [83]	validation_0-logloss:0.50225	validation_1-logloss:0.17581
# [84]	validation_0-logloss:0.49962	validation_1-logloss:0.17442
# [85]	validation_0-logloss:0.50150	validation_1-logloss:0.17374
# [86]	validation_0-logloss:0.50153	validation_1-logloss:0.17254
# [87]	validation_0-logloss:0.50183	validation_1-logloss:0.17230
# [88]	validation_0-logloss:0.49860	validation_1-logloss:0.17036
# [89]	validation_0-logloss:0.49564	validation_1-logloss:0.16865
# [90]	validation_0-logloss:0.49425	validation_1-logloss:0.16713
# [91]	validation_0-logloss:0.49525	validation_1-logloss:0.16601
# [92]	validation_0-logloss:0.49840	validation_1-logloss:0.16444
# [93]	validation_0-logloss:0.49785	validation_1-logloss:0.16344
# [94]	validation_0-logloss:0.49975	validation_1-logloss:0.16287
# [95]	validation_0-logloss:0.49953	validation_1-logloss:0.16249
# [96]	validation_0-logloss:0.49873	validation_1-logloss:0.16118
# [97]	validation_0-logloss:0.50047	validation_1-logloss:0.15993
# [98]	validation_0-logloss:0.50331	validation_1-logloss:0.15898
# [99]	validation_0-logloss:0.50480	validation_1-logloss:0.15861
# [0]	validation_0-logloss:0.60465	validation_1-logloss:0.60465
# [1]	validation_0-logloss:0.53217	validation_1-logloss:0.53218
# [2]	validation_0-logloss:0.47188	validation_1-logloss:0.47181
# [3]	validation_0-logloss:0.42104	validation_1-logloss:0.42091
# [4]	validation_0-logloss:0.37774	validation_1-logloss:0.37754
# [5]	validation_0-logloss:0.34057	validation_1-logloss:0.34032
# [6]	validation_0-logloss:0.30846	validation_1-logloss:0.30814
# [7]	validation_0-logloss:0.28057	validation_1-logloss:0.28018
# [8]	validation_0-logloss:0.25626	validation_1-logloss:0.25582
# [9]	validation_0-logloss:0.23501	validation_1-logloss:0.23449
# [10]	validation_0-logloss:0.21634	validation_1-logloss:0.21573
# [11]	validation_0-logloss:0.19997	validation_1-logloss:0.19922
# [12]	validation_0-logloss:0.18546	validation_1-logloss:0.18460
# [13]	validation_0-logloss:0.17269	validation_1-logloss:0.17167
# [14]	validation_0-logloss:0.16143	validation_1-logloss:0.16026
# [15]	validation_0-logloss:0.15143	validation_1-logloss:0.15014
# [16]	validation_0-logloss:0.14269	validation_1-logloss:0.14117
# [17]	validation_0-logloss:0.13484	validation_1-logloss:0.13317
# [18]	validation_0-logloss:0.12790	validation_1-logloss:0.12604
# [19]	validation_0-logloss:0.12174	validation_1-logloss:0.11966
# [20]	validation_0-logloss:0.11624	validation_1-logloss:0.11399
# [21]	validation_0-logloss:0.11135	validation_1-logloss:0.10897
# [22]	validation_0-logloss:0.10703	validation_1-logloss:0.10450
# [23]	validation_0-logloss:0.10319	validation_1-logloss:0.10047
# [24]	validation_0-logloss:0.09974	validation_1-logloss:0.09689
# [25]	validation_0-logloss:0.09670	validation_1-logloss:0.09366
# [26]	validation_0-logloss:0.09400	validation_1-logloss:0.09081
# [27]	validation_0-logloss:0.09164	validation_1-logloss:0.08822
# [28]	validation_0-logloss:0.08958	validation_1-logloss:0.08588
# [29]	validation_0-logloss:0.08774	validation_1-logloss:0.08376
# [30]	validation_0-logloss:0.08618	validation_1-logloss:0.08189
# [31]	validation_0-logloss:0.08473	validation_1-logloss:0.08021
# [32]	validation_0-logloss:0.08344	validation_1-logloss:0.07869
# [33]	validation_0-logloss:0.08229	validation_1-logloss:0.07730
# [34]	validation_0-logloss:0.08129	validation_1-logloss:0.07602
# [35]	validation_0-logloss:0.08038	validation_1-logloss:0.07492
# [36]	validation_0-logloss:0.07964	validation_1-logloss:0.07389
# [37]	validation_0-logloss:0.07897	validation_1-logloss:0.07302
# [38]	validation_0-logloss:0.07828	validation_1-logloss:0.07224
# [39]	validation_0-logloss:0.07772	validation_1-logloss:0.07148
# [40]	validation_0-logloss:0.07725	validation_1-logloss:0.07081
# [41]	validation_0-logloss:0.07679	validation_1-logloss:0.07018
# [42]	validation_0-logloss:0.07642	validation_1-logloss:0.06963
# [43]	validation_0-logloss:0.07603	validation_1-logloss:0.06913
# [44]	validation_0-logloss:0.07573	validation_1-logloss:0.06861
# [45]	validation_0-logloss:0.07545	validation_1-logloss:0.06819
# [46]	validation_0-logloss:0.07516	validation_1-logloss:0.06775
# [47]	validation_0-logloss:0.07506	validation_1-logloss:0.06731
# [48]	validation_0-logloss:0.07482	validation_1-logloss:0.06692
# [49]	validation_0-logloss:0.07467	validation_1-logloss:0.06662
# [50]	validation_0-logloss:0.07457	validation_1-logloss:0.06631
# [51]	validation_0-logloss:0.07447	validation_1-logloss:0.06604
# [52]	validation_0-logloss:0.07438	validation_1-logloss:0.06582
# [53]	validation_0-logloss:0.07434	validation_1-logloss:0.06561
# [54]	validation_0-logloss:0.07422	validation_1-logloss:0.06540
# [55]	validation_0-logloss:0.07412	validation_1-logloss:0.06523
# [56]	validation_0-logloss:0.07406	validation_1-logloss:0.06507
# [57]	validation_0-logloss:0.07400	validation_1-logloss:0.06485
# [58]	validation_0-logloss:0.07398	validation_1-logloss:0.06464
# [59]	validation_0-logloss:0.07389	validation_1-logloss:0.06453
# [60]	validation_0-logloss:0.07388	validation_1-logloss:0.06440
# [61]	validation_0-logloss:0.07383	validation_1-logloss:0.06431
# [62]	validation_0-logloss:0.07379	validation_1-logloss:0.06422
# [63]	validation_0-logloss:0.07378	validation_1-logloss:0.06414
# [64]	validation_0-logloss:0.07376	validation_1-logloss:0.06406
# [65]	validation_0-logloss:0.07377	validation_1-logloss:0.06396
# [66]	validation_0-logloss:0.07374	validation_1-logloss:0.06390
# [67]	validation_0-logloss:0.07369	validation_1-logloss:0.06378
# [68]	validation_0-logloss:0.07367	validation_1-logloss:0.06368
# [69]	validation_0-logloss:0.07369	validation_1-logloss:0.06355
# [70]	validation_0-logloss:0.07369	validation_1-logloss:0.06350
# [71]	validation_0-logloss:0.07372	validation_1-logloss:0.06341
# [72]	validation_0-logloss:0.07374	validation_1-logloss:0.06332
# [73]	validation_0-logloss:0.07368	validation_1-logloss:0.06320
# [74]	validation_0-logloss:0.07368	validation_1-logloss:0.06314
# [75]	validation_0-logloss:0.07373	validation_1-logloss:0.06307
# [76]	validation_0-logloss:0.07374	validation_1-logloss:0.06303
# [77]	validation_0-logloss:0.07378	validation_1-logloss:0.06289
# [78]	validation_0-logloss:0.07382	validation_1-logloss:0.06276
# [79]	validation_0-logloss:0.07381	validation_1-logloss:0.06269
# [80]	validation_0-logloss:0.07384	validation_1-logloss:0.06263
# [81]	validation_0-logloss:0.07386	validation_1-logloss:0.06259
# [82]	validation_0-logloss:0.07387	validation_1-logloss:0.06251
# [83]	validation_0-logloss:0.07386	validation_1-logloss:0.06244
# [84]	validation_0-logloss:0.07386	validation_1-logloss:0.06234
# [85]	validation_0-logloss:0.07382	validation_1-logloss:0.06221
# [86]	validation_0-logloss:0.07382	validation_1-logloss:0.06206
# [87]	validation_0-logloss:0.07381	validation_1-logloss:0.06200
# [88]	validation_0-logloss:0.07380	validation_1-logloss:0.06195
# [89]	validation_0-logloss:0.07378	validation_1-logloss:0.06192
# [90]	validation_0-logloss:0.07379	validation_1-logloss:0.06189
# [91]	validation_0-logloss:0.07378	validation_1-logloss:0.06156
# [92]	validation_0-logloss:0.07379	validation_1-logloss:0.06139
# [93]	validation_0-logloss:0.07386	validation_1-logloss:0.06132
# [94]	validation_0-logloss:0.07388	validation_1-logloss:0.06129
# [95]	validation_0-logloss:0.07390	validation_1-logloss:0.06121
# [96]	validation_0-logloss:0.07390	validation_1-logloss:0.06104
# [97]	validation_0-logloss:0.07392	validation_1-logloss:0.06093
# [98]	validation_0-logloss:0.07393	validation_1-logloss:0.06081
# [99]	validation_0-logloss:0.07396	validation_1-logloss:0.06061
# /tmp/ipykernel_245814/2120788987.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# /tmp/ipykernel_245814/272878867.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.65808	validation_1-logloss:0.63709
# [1]	validation_0-logloss:0.63039	validation_1-logloss:0.59054
# [2]	validation_0-logloss:0.61211	validation_1-logloss:0.55139
# [3]	validation_0-logloss:0.59402	validation_1-logloss:0.51746
# [4]	validation_0-logloss:0.57838	validation_1-logloss:0.48823
# [5]	validation_0-logloss:0.57191	validation_1-logloss:0.46418
# [6]	validation_0-logloss:0.56572	validation_1-logloss:0.44307
# [7]	validation_0-logloss:0.55989	validation_1-logloss:0.42435
# [8]	validation_0-logloss:0.55146	validation_1-logloss:0.40654
# [9]	validation_0-logloss:0.54625	validation_1-logloss:0.39213
# [10]	validation_0-logloss:0.54182	validation_1-logloss:0.37953
# [11]	validation_0-logloss:0.53720	validation_1-logloss:0.36692
# [12]	validation_0-logloss:0.53730	validation_1-logloss:0.35684
# [13]	validation_0-logloss:0.53327	validation_1-logloss:0.34685
# [14]	validation_0-logloss:0.53175	validation_1-logloss:0.33769
# [15]	validation_0-logloss:0.52845	validation_1-logloss:0.32891
# [16]	validation_0-logloss:0.52854	validation_1-logloss:0.32260
# [17]	validation_0-logloss:0.52963	validation_1-logloss:0.31657
# [18]	validation_0-logloss:0.53047	validation_1-logloss:0.31022
# [19]	validation_0-logloss:0.53132	validation_1-logloss:0.30453
# [20]	validation_0-logloss:0.53190	validation_1-logloss:0.29883
# [21]	validation_0-logloss:0.53533	validation_1-logloss:0.29448
# [22]	validation_0-logloss:0.53710	validation_1-logloss:0.29044
# [23]	validation_0-logloss:0.54122	validation_1-logloss:0.28580
# [24]	validation_0-logloss:0.53712	validation_1-logloss:0.28085
# [25]	validation_0-logloss:0.54285	validation_1-logloss:0.27680
# [26]	validation_0-logloss:0.54783	validation_1-logloss:0.27346
# [27]	validation_0-logloss:0.55068	validation_1-logloss:0.27023
# [28]	validation_0-logloss:0.55290	validation_1-logloss:0.26769
# [29]	validation_0-logloss:0.55693	validation_1-logloss:0.26427
# [30]	validation_0-logloss:0.55972	validation_1-logloss:0.26094
# [31]	validation_0-logloss:0.56346	validation_1-logloss:0.25814
# [32]	validation_0-logloss:0.56399	validation_1-logloss:0.25531
# [33]	validation_0-logloss:0.56910	validation_1-logloss:0.25300
# [34]	validation_0-logloss:0.56882	validation_1-logloss:0.25098
# [35]	validation_0-logloss:0.57149	validation_1-logloss:0.24921
# [36]	validation_0-logloss:0.57418	validation_1-logloss:0.24709
# [37]	validation_0-logloss:0.57128	validation_1-logloss:0.24512
# [38]	validation_0-logloss:0.57374	validation_1-logloss:0.24335
# [39]	validation_0-logloss:0.57650	validation_1-logloss:0.24179
# [40]	validation_0-logloss:0.57108	validation_1-logloss:0.23925
# [41]	validation_0-logloss:0.57361	validation_1-logloss:0.23789
# [42]	validation_0-logloss:0.57297	validation_1-logloss:0.23649
# [43]	validation_0-logloss:0.56837	validation_1-logloss:0.23434
# [44]	validation_0-logloss:0.57081	validation_1-logloss:0.23321
# [45]	validation_0-logloss:0.57435	validation_1-logloss:0.23139
# [46]	validation_0-logloss:0.57278	validation_1-logloss:0.23036
# [47]	validation_0-logloss:0.57018	validation_1-logloss:0.22828
# [48]	validation_0-logloss:0.56866	validation_1-logloss:0.22693
# [49]	validation_0-logloss:0.56707	validation_1-logloss:0.22563
# [50]	validation_0-logloss:0.57058	validation_1-logloss:0.22389
# [51]	validation_0-logloss:0.57225	validation_1-logloss:0.22260
# [52]	validation_0-logloss:0.56794	validation_1-logloss:0.22071
# [53]	validation_0-logloss:0.56968	validation_1-logloss:0.21979
# [54]	validation_0-logloss:0.56757	validation_1-logloss:0.21726
# [55]	validation_0-logloss:0.56927	validation_1-logloss:0.21582
# [56]	validation_0-logloss:0.57178	validation_1-logloss:0.21445
# [57]	validation_0-logloss:0.57070	validation_1-logloss:0.21313
# [58]	validation_0-logloss:0.56785	validation_1-logloss:0.21082
# [59]	validation_0-logloss:0.56968	validation_1-logloss:0.21010
# [60]	validation_0-logloss:0.56883	validation_1-logloss:0.20870
# [61]	validation_0-logloss:0.56543	validation_1-logloss:0.20602
# [62]	validation_0-logloss:0.56297	validation_1-logloss:0.20457
# [63]	validation_0-logloss:0.56146	validation_1-logloss:0.20357
# [64]	validation_0-logloss:0.55910	validation_1-logloss:0.20212
# [65]	validation_0-logloss:0.55899	validation_1-logloss:0.20098
# [66]	validation_0-logloss:0.55800	validation_1-logloss:0.20038
# [67]	validation_0-logloss:0.55758	validation_1-logloss:0.19950
# [68]	validation_0-logloss:0.55815	validation_1-logloss:0.19908
# [69]	validation_0-logloss:0.55579	validation_1-logloss:0.19682
# [70]	validation_0-logloss:0.55380	validation_1-logloss:0.19495
# [71]	validation_0-logloss:0.55296	validation_1-logloss:0.19376
# [72]	validation_0-logloss:0.55534	validation_1-logloss:0.19224
# [73]	validation_0-logloss:0.55468	validation_1-logloss:0.19129
# [74]	validation_0-logloss:0.55564	validation_1-logloss:0.19054
# [75]	validation_0-logloss:0.55815	validation_1-logloss:0.18957
# [76]	validation_0-logloss:0.56274	validation_1-logloss:0.18807
# [77]	validation_0-logloss:0.56569	validation_1-logloss:0.18667
# [78]	validation_0-logloss:0.56777	validation_1-logloss:0.18558
# [79]	validation_0-logloss:0.56753	validation_1-logloss:0.18468
# [80]	validation_0-logloss:0.56809	validation_1-logloss:0.18432
# [81]	validation_0-logloss:0.56651	validation_1-logloss:0.18200
# [82]	validation_0-logloss:0.57118	validation_1-logloss:0.18078
# [83]	validation_0-logloss:0.56854	validation_1-logloss:0.17938
# [84]	validation_0-logloss:0.56900	validation_1-logloss:0.17907
# [85]	validation_0-logloss:0.56856	validation_1-logloss:0.17828
# [86]	validation_0-logloss:0.56912	validation_1-logloss:0.17740
# [87]	validation_0-logloss:0.57092	validation_1-logloss:0.17570
# [88]	validation_0-logloss:0.57439	validation_1-logloss:0.17486
# [89]	validation_0-logloss:0.57591	validation_1-logloss:0.17379
# [90]	validation_0-logloss:0.57648	validation_1-logloss:0.17347
# [91]	validation_0-logloss:0.57626	validation_1-logloss:0.17277
# [92]	validation_0-logloss:0.57811	validation_1-logloss:0.17147
# [93]	validation_0-logloss:0.57639	validation_1-logloss:0.17066
# [94]	validation_0-logloss:0.57676	validation_1-logloss:0.17048
# [95]	validation_0-logloss:0.57626	validation_1-logloss:0.16911
# [96]	validation_0-logloss:0.58002	validation_1-logloss:0.16832
# [97]	validation_0-logloss:0.57883	validation_1-logloss:0.16744
# [98]	validation_0-logloss:0.57850	validation_1-logloss:0.16725
# [99]	validation_0-logloss:0.57442	validation_1-logloss:0.16496
# [0]	validation_0-logloss:0.60496	validation_1-logloss:0.60455
# [1]	validation_0-logloss:0.53278	validation_1-logloss:0.53199
# [2]	validation_0-logloss:0.47269	validation_1-logloss:0.47157
# [3]	validation_0-logloss:0.42202	validation_1-logloss:0.42061
# [4]	validation_0-logloss:0.37887	validation_1-logloss:0.37718
# [5]	validation_0-logloss:0.34188	validation_1-logloss:0.33987
# [6]	validation_0-logloss:0.30993	validation_1-logloss:0.30765
# [7]	validation_0-logloss:0.28220	validation_1-logloss:0.27964
# [8]	validation_0-logloss:0.25800	validation_1-logloss:0.25523
# [9]	validation_0-logloss:0.23692	validation_1-logloss:0.23385
# [10]	validation_0-logloss:0.21837	validation_1-logloss:0.21506
# [11]	validation_0-logloss:0.20212	validation_1-logloss:0.19850
# [12]	validation_0-logloss:0.18779	validation_1-logloss:0.18391
# [13]	validation_0-logloss:0.17514	validation_1-logloss:0.17099
# [14]	validation_0-logloss:0.16399	validation_1-logloss:0.15954
# [15]	validation_0-logloss:0.15411	validation_1-logloss:0.14937
# [16]	validation_0-logloss:0.14543	validation_1-logloss:0.14035
# [17]	validation_0-logloss:0.13771	validation_1-logloss:0.13233
# [18]	validation_0-logloss:0.13089	validation_1-logloss:0.12516
# [19]	validation_0-logloss:0.12487	validation_1-logloss:0.11884
# [20]	validation_0-logloss:0.11954	validation_1-logloss:0.11322
# [21]	validation_0-logloss:0.11477	validation_1-logloss:0.10819
# [22]	validation_0-logloss:0.11066	validation_1-logloss:0.10366
# [23]	validation_0-logloss:0.10696	validation_1-logloss:0.09959
# [24]	validation_0-logloss:0.10360	validation_1-logloss:0.09598
# [25]	validation_0-logloss:0.10079	validation_1-logloss:0.09272
# [26]	validation_0-logloss:0.09822	validation_1-logloss:0.08981
# [27]	validation_0-logloss:0.09600	validation_1-logloss:0.08718
# [28]	validation_0-logloss:0.09408	validation_1-logloss:0.08485
# [29]	validation_0-logloss:0.09228	validation_1-logloss:0.08275
# [30]	validation_0-logloss:0.09071	validation_1-logloss:0.08087
# [31]	validation_0-logloss:0.08930	validation_1-logloss:0.07921
# [32]	validation_0-logloss:0.08812	validation_1-logloss:0.07769
# [33]	validation_0-logloss:0.08699	validation_1-logloss:0.07629
# [34]	validation_0-logloss:0.08608	validation_1-logloss:0.07506
# [35]	validation_0-logloss:0.08523	validation_1-logloss:0.07395
# [36]	validation_0-logloss:0.08444	validation_1-logloss:0.07298
# [37]	validation_0-logloss:0.08377	validation_1-logloss:0.07212
# [38]	validation_0-logloss:0.08322	validation_1-logloss:0.07129
# [39]	validation_0-logloss:0.08273	validation_1-logloss:0.07057
# [40]	validation_0-logloss:0.08231	validation_1-logloss:0.06986
# [41]	validation_0-logloss:0.08191	validation_1-logloss:0.06924
# [42]	validation_0-logloss:0.08154	validation_1-logloss:0.06867
# [43]	validation_0-logloss:0.08122	validation_1-logloss:0.06820
# [44]	validation_0-logloss:0.08098	validation_1-logloss:0.06764
# [45]	validation_0-logloss:0.08072	validation_1-logloss:0.06722
# [46]	validation_0-logloss:0.08052	validation_1-logloss:0.06679
# [47]	validation_0-logloss:0.08032	validation_1-logloss:0.06640
# [48]	validation_0-logloss:0.08015	validation_1-logloss:0.06608
# [49]	validation_0-logloss:0.07997	validation_1-logloss:0.06579
# [50]	validation_0-logloss:0.07982	validation_1-logloss:0.06554
# [51]	validation_0-logloss:0.07967	validation_1-logloss:0.06527
# [52]	validation_0-logloss:0.07962	validation_1-logloss:0.06502
# [53]	validation_0-logloss:0.07955	validation_1-logloss:0.06478
# [54]	validation_0-logloss:0.07947	validation_1-logloss:0.06458
# [55]	validation_0-logloss:0.07941	validation_1-logloss:0.06441
# [56]	validation_0-logloss:0.07934	validation_1-logloss:0.06421
# [57]	validation_0-logloss:0.07926	validation_1-logloss:0.06401
# [58]	validation_0-logloss:0.07921	validation_1-logloss:0.06388
# [59]	validation_0-logloss:0.07916	validation_1-logloss:0.06377
# [60]	validation_0-logloss:0.07912	validation_1-logloss:0.06363
# [61]	validation_0-logloss:0.07912	validation_1-logloss:0.06348
# [62]	validation_0-logloss:0.07910	validation_1-logloss:0.06339
# [63]	validation_0-logloss:0.07908	validation_1-logloss:0.06322
# [64]	validation_0-logloss:0.07902	validation_1-logloss:0.06315
# [65]	validation_0-logloss:0.07904	validation_1-logloss:0.06307
# [66]	validation_0-logloss:0.07903	validation_1-logloss:0.06293
# [67]	validation_0-logloss:0.07905	validation_1-logloss:0.06282
# [68]	validation_0-logloss:0.07913	validation_1-logloss:0.06268
# [69]	validation_0-logloss:0.07914	validation_1-logloss:0.06262
# [70]	validation_0-logloss:0.07914	validation_1-logloss:0.06255
# [71]	validation_0-logloss:0.07914	validation_1-logloss:0.06246
# [72]	validation_0-logloss:0.07918	validation_1-logloss:0.06237
# [73]	validation_0-logloss:0.07923	validation_1-logloss:0.06223
# [74]	validation_0-logloss:0.07921	validation_1-logloss:0.06216
# [75]	validation_0-logloss:0.07922	validation_1-logloss:0.06211
# [76]	validation_0-logloss:0.07922	validation_1-logloss:0.06197
# [77]	validation_0-logloss:0.07923	validation_1-logloss:0.06190
# [78]	validation_0-logloss:0.07922	validation_1-logloss:0.06184
# [79]	validation_0-logloss:0.07926	validation_1-logloss:0.06175
# [80]	validation_0-logloss:0.07927	validation_1-logloss:0.06172
# [81]	validation_0-logloss:0.07924	validation_1-logloss:0.06155
# [82]	validation_0-logloss:0.07930	validation_1-logloss:0.06139
# [83]	validation_0-logloss:0.07931	validation_1-logloss:0.06136
# [84]	validation_0-logloss:0.07932	validation_1-logloss:0.06127
# [85]	validation_0-logloss:0.07930	validation_1-logloss:0.06114
# [86]	validation_0-logloss:0.07932	validation_1-logloss:0.06112
# [87]	validation_0-logloss:0.07933	validation_1-logloss:0.06109
# [88]	validation_0-logloss:0.07931	validation_1-logloss:0.06106
# [89]	validation_0-logloss:0.07936	validation_1-logloss:0.06086
# [90]	validation_0-logloss:0.07937	validation_1-logloss:0.06083
# [91]	validation_0-logloss:0.07943	validation_1-logloss:0.06066
# [92]	validation_0-logloss:0.07941	validation_1-logloss:0.06060
# [93]	validation_0-logloss:0.07941	validation_1-logloss:0.06041
# [94]	validation_0-logloss:0.07945	validation_1-logloss:0.06026
# [95]	validation_0-logloss:0.07950	validation_1-logloss:0.06023
# [96]	validation_0-logloss:0.07956	validation_1-logloss:0.06006
# [97]	validation_0-logloss:0.07955	validation_1-logloss:0.05992
# [98]	validation_0-logloss:0.07960	validation_1-logloss:0.05980
# [99]	validation_0-logloss:0.07963	validation_1-logloss:0.05976
# /tmp/ipykernel_245814/2120788987.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# /tmp/ipykernel_245814/272878867.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.65959	validation_1-logloss:0.63708
# [1]	validation_0-logloss:0.63033	validation_1-logloss:0.59027
# [2]	validation_0-logloss:0.60634	validation_1-logloss:0.55145
# [3]	validation_0-logloss:0.58628	validation_1-logloss:0.51796
# [4]	validation_0-logloss:0.57460	validation_1-logloss:0.48946
# [5]	validation_0-logloss:0.56123	validation_1-logloss:0.46459
# [6]	validation_0-logloss:0.55217	validation_1-logloss:0.44240
# [7]	validation_0-logloss:0.54554	validation_1-logloss:0.42375
# [8]	validation_0-logloss:0.53895	validation_1-logloss:0.40605
# [9]	validation_0-logloss:0.53358	validation_1-logloss:0.39090
# [10]	validation_0-logloss:0.52690	validation_1-logloss:0.37761
# [11]	validation_0-logloss:0.52395	validation_1-logloss:0.36578
# [12]	validation_0-logloss:0.51910	validation_1-logloss:0.35453
# [13]	validation_0-logloss:0.51786	validation_1-logloss:0.34453
# [14]	validation_0-logloss:0.51807	validation_1-logloss:0.33608
# [15]	validation_0-logloss:0.51698	validation_1-logloss:0.32791
# [16]	validation_0-logloss:0.51849	validation_1-logloss:0.32104
# [17]	validation_0-logloss:0.51820	validation_1-logloss:0.31488
# [18]	validation_0-logloss:0.51686	validation_1-logloss:0.30829
# [19]	validation_0-logloss:0.51805	validation_1-logloss:0.30325
# [20]	validation_0-logloss:0.51849	validation_1-logloss:0.29793
# [21]	validation_0-logloss:0.51919	validation_1-logloss:0.29309
# [22]	validation_0-logloss:0.51704	validation_1-logloss:0.28834
# [23]	validation_0-logloss:0.51697	validation_1-logloss:0.28452
# [24]	validation_0-logloss:0.51935	validation_1-logloss:0.28108
# [25]	validation_0-logloss:0.52271	validation_1-logloss:0.27775
# [26]	validation_0-logloss:0.52402	validation_1-logloss:0.27453
# [27]	validation_0-logloss:0.52871	validation_1-logloss:0.27199
# [28]	validation_0-logloss:0.53247	validation_1-logloss:0.26972
# ...
# [55]	validation_0-logloss:0.50953	validation_1-logloss:0.20962
# [56]	validation_0-logloss:0.50729	validation_1-logloss:0.20789
# [57]	validation_0-logloss:0.50788	validation_1-logloss:0.20747
# [58]	validation_0-logloss:0.50788	validation_1-logloss:0.20642
# [59]	validation_0-logloss:0.50456	validation_1-logloss:0.20434
# [60]	validation_0-logloss:0.50642	validation_1-logloss:0.20323
# [61]	validation_0-logloss:0.50714	validation_1-logloss:0.20260
# [62]	validation_0-logloss:0.50732	validation_1-logloss:0.20228
# [63]	validation_0-logloss:0.50747	validation_1-logloss:0.20090
# [64]	validation_0-logloss:0.50431	validation_1-logloss:0.19834
# [65]	validation_0-logloss:0.50304	validation_1-logloss:0.19766
# [66]	validation_0-logloss:0.50331	validation_1-logloss:0.19676
# [67]	validation_0-logloss:0.50402	validation_1-logloss:0.19634
# [68]	validation_0-logloss:0.50421	validation_1-logloss:0.19553
# [69]	validation_0-logloss:0.50165	validation_1-logloss:0.19315
# [70]	validation_0-logloss:0.50136	validation_1-logloss:0.19131
# [71]	validation_0-logloss:0.50273	validation_1-logloss:0.19071
# [72]	validation_0-logloss:0.50240	validation_1-logloss:0.18994
# [73]	validation_0-logloss:0.50302	validation_1-logloss:0.18931
# [74]	validation_0-logloss:0.50421	validation_1-logloss:0.18802
# [75]	validation_0-logloss:0.50223	validation_1-logloss:0.18607
# [76]	validation_0-logloss:0.50318	validation_1-logloss:0.18463
# [77]	validation_0-logloss:0.50178	validation_1-logloss:0.18311
# [78]	validation_0-logloss:0.50210	validation_1-logloss:0.18283
# [79]	validation_0-logloss:0.50274	validation_1-logloss:0.18235
# [80]	validation_0-logloss:0.50345	validation_1-logloss:0.18204
# [81]	validation_0-logloss:0.50162	validation_1-logloss:0.18087
# [82]	validation_0-logloss:0.50212	validation_1-logloss:0.18060
# [83]	validation_0-logloss:0.50058	validation_1-logloss:0.17965
# [84]	validation_0-logloss:0.49853	validation_1-logloss:0.17809
# [85]	validation_0-logloss:0.50229	validation_1-logloss:0.17656
# [86]	validation_0-logloss:0.50264	validation_1-logloss:0.17631
# [87]	validation_0-logloss:0.50305	validation_1-logloss:0.17557
# [88]	validation_0-logloss:0.50496	validation_1-logloss:0.17426
# [89]	validation_0-logloss:0.50581	validation_1-logloss:0.17385
# [90]	validation_0-logloss:0.50654	validation_1-logloss:0.17295
# [91]	validation_0-logloss:0.50620	validation_1-logloss:0.17236
# [92]	validation_0-logloss:0.50581	validation_1-logloss:0.17190
# [93]	validation_0-logloss:0.50692	validation_1-logloss:0.17154
# [94]	validation_0-logloss:0.50872	validation_1-logloss:0.17113
# [95]	validation_0-logloss:0.51051	validation_1-logloss:0.16975
# [96]	validation_0-logloss:0.51481	validation_1-logloss:0.16811
# [97]	validation_0-logloss:0.51317	validation_1-logloss:0.16664
# [98]	validation_0-logloss:0.51381	validation_1-logloss:0.16633
# [99]	validation_0-logloss:0.51664	validation_1-logloss:0.16537
# [0]	validation_0-logloss:0.60470	validation_1-logloss:0.60459
# [1]	validation_0-logloss:0.53229	validation_1-logloss:0.53209
# [2]	validation_0-logloss:0.47201	validation_1-logloss:0.47172
# [3]	validation_0-logloss:0.42122	validation_1-logloss:0.42078
# [4]	validation_0-logloss:0.37793	validation_1-logloss:0.37741
# [5]	validation_0-logloss:0.34088	validation_1-logloss:0.34014
# [6]	validation_0-logloss:0.30886	validation_1-logloss:0.30793
# [7]	validation_0-logloss:0.28104	validation_1-logloss:0.27997
# [8]	validation_0-logloss:0.25676	validation_1-logloss:0.25556
# [9]	validation_0-logloss:0.23562	validation_1-logloss:0.23415
# [10]	validation_0-logloss:0.21704	validation_1-logloss:0.21538
# [11]	validation_0-logloss:0.20070	validation_1-logloss:0.19881
# [12]	validation_0-logloss:0.18633	validation_1-logloss:0.18423
# [13]	validation_0-logloss:0.17364	validation_1-logloss:0.17138
# [14]	validation_0-logloss:0.16242	validation_1-logloss:0.15994
# [15]	validation_0-logloss:0.15248	validation_1-logloss:0.14979
# [16]	validation_0-logloss:0.14371	validation_1-logloss:0.14076
# [17]	validation_0-logloss:0.13593	validation_1-logloss:0.13277
# [18]	validation_0-logloss:0.12904	validation_1-logloss:0.12565
# [19]	validation_0-logloss:0.12299	validation_1-logloss:0.11925
# [20]	validation_0-logloss:0.11754	validation_1-logloss:0.11360
# [21]	validation_0-logloss:0.11278	validation_1-logloss:0.10853
# [22]	validation_0-logloss:0.10854	validation_1-logloss:0.10401
# [23]	validation_0-logloss:0.10480	validation_1-logloss:0.09999
# [24]	validation_0-logloss:0.10154	validation_1-logloss:0.09638
# [25]	validation_0-logloss:0.09862	validation_1-logloss:0.09314
# [26]	validation_0-logloss:0.09605	validation_1-logloss:0.09025
# [27]	validation_0-logloss:0.09369	validation_1-logloss:0.08763
# [28]	validation_0-logloss:0.09164	validation_1-logloss:0.08525
# [29]	validation_0-logloss:0.08988	validation_1-logloss:0.08316
# [30]	validation_0-logloss:0.08825	validation_1-logloss:0.08124
# [31]	validation_0-logloss:0.08685	validation_1-logloss:0.07952
# [32]	validation_0-logloss:0.08553	validation_1-logloss:0.07796
# [33]	validation_0-logloss:0.08442	validation_1-logloss:0.07658
# [34]	validation_0-logloss:0.08346	validation_1-logloss:0.07534
# [35]	validation_0-logloss:0.08261	validation_1-logloss:0.07424
# [36]	validation_0-logloss:0.08183	validation_1-logloss:0.07324
# [37]	validation_0-logloss:0.08111	validation_1-logloss:0.07229
# [38]	validation_0-logloss:0.08054	validation_1-logloss:0.07144
# [39]	validation_0-logloss:0.08004	validation_1-logloss:0.07073
# [40]	validation_0-logloss:0.07954	validation_1-logloss:0.07002
# [41]	validation_0-logloss:0.07910	validation_1-logloss:0.06942
# [42]	validation_0-logloss:0.07876	validation_1-logloss:0.06883
# [43]	validation_0-logloss:0.07844	validation_1-logloss:0.06831
# [44]	validation_0-logloss:0.07816	validation_1-logloss:0.06782
# [45]	validation_0-logloss:0.07796	validation_1-logloss:0.06736
# [46]	validation_0-logloss:0.07773	validation_1-logloss:0.06702
# [47]	validation_0-logloss:0.07753	validation_1-logloss:0.06663
# [48]	validation_0-logloss:0.07735	validation_1-logloss:0.06628
# [49]	validation_0-logloss:0.07721	validation_1-logloss:0.06599
# [50]	validation_0-logloss:0.07706	validation_1-logloss:0.06566
# [51]	validation_0-logloss:0.07698	validation_1-logloss:0.06541
# [52]	validation_0-logloss:0.07686	validation_1-logloss:0.06515
# [53]	validation_0-logloss:0.07680	validation_1-logloss:0.06492
# [54]	validation_0-logloss:0.07679	validation_1-logloss:0.06460
# [55]	validation_0-logloss:0.07675	validation_1-logloss:0.06443
# [56]	validation_0-logloss:0.07672	validation_1-logloss:0.06427
# [57]	validation_0-logloss:0.07667	validation_1-logloss:0.06413
# [58]	validation_0-logloss:0.07667	validation_1-logloss:0.06399
# [59]	validation_0-logloss:0.07664	validation_1-logloss:0.06370
# [60]	validation_0-logloss:0.07663	validation_1-logloss:0.06362
# [61]	validation_0-logloss:0.07662	validation_1-logloss:0.06355
# [62]	validation_0-logloss:0.07662	validation_1-logloss:0.06344
# [63]	validation_0-logloss:0.07662	validation_1-logloss:0.06338
# [64]	validation_0-logloss:0.07660	validation_1-logloss:0.06316
# [65]	validation_0-logloss:0.07659	validation_1-logloss:0.06307
# [66]	validation_0-logloss:0.07661	validation_1-logloss:0.06294
# [67]	validation_0-logloss:0.07659	validation_1-logloss:0.06280
# [68]	validation_0-logloss:0.07659	validation_1-logloss:0.06273
# [69]	validation_0-logloss:0.07654	validation_1-logloss:0.06259
# [70]	validation_0-logloss:0.07657	validation_1-logloss:0.06246
# [71]	validation_0-logloss:0.07658	validation_1-logloss:0.06240
# [72]	validation_0-logloss:0.07664	validation_1-logloss:0.06230
# [73]	validation_0-logloss:0.07669	validation_1-logloss:0.06216
# [74]	validation_0-logloss:0.07671	validation_1-logloss:0.06213
# [75]	validation_0-logloss:0.07670	validation_1-logloss:0.06199
# [76]	validation_0-logloss:0.07672	validation_1-logloss:0.06180
# [77]	validation_0-logloss:0.07676	validation_1-logloss:0.06169
# [78]	validation_0-logloss:0.07680	validation_1-logloss:0.06162
# [79]	validation_0-logloss:0.07685	validation_1-logloss:0.06148
# [80]	validation_0-logloss:0.07694	validation_1-logloss:0.06121
# [81]	validation_0-logloss:0.07694	validation_1-logloss:0.06109
# [82]	validation_0-logloss:0.07695	validation_1-logloss:0.06099
# [83]	validation_0-logloss:0.07695	validation_1-logloss:0.06087
# [84]	validation_0-logloss:0.07697	validation_1-logloss:0.06067
# [85]	validation_0-logloss:0.07692	validation_1-logloss:0.06059
# [86]	validation_0-logloss:0.07692	validation_1-logloss:0.06049
# [87]	validation_0-logloss:0.07693	validation_1-logloss:0.06044
# [88]	validation_0-logloss:0.07691	validation_1-logloss:0.06030
# [89]	validation_0-logloss:0.07692	validation_1-logloss:0.06026
# [90]	validation_0-logloss:0.07691	validation_1-logloss:0.06021
# [91]	validation_0-logloss:0.07694	validation_1-logloss:0.06014
# [92]	validation_0-logloss:0.07692	validation_1-logloss:0.06010
# [93]	validation_0-logloss:0.07693	validation_1-logloss:0.06008
# [94]	validation_0-logloss:0.07692	validation_1-logloss:0.06004
# [95]	validation_0-logloss:0.07693	validation_1-logloss:0.06003
# [96]	validation_0-logloss:0.07709	validation_1-logloss:0.05970
# [97]	validation_0-logloss:0.07705	validation_1-logloss:0.05941
# [98]	validation_0-logloss:0.07705	validation_1-logloss:0.05939
# [99]	validation_0-logloss:0.07709	validation_1-logloss:0.05933
# /tmp/ipykernel_245814/2120788987.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# /tmp/ipykernel_245814/272878867.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.66163	validation_1-logloss:0.63793
# [1]	validation_0-logloss:0.63558	validation_1-logloss:0.59159
# [2]	validation_0-logloss:0.61633	validation_1-logloss:0.55303
# [3]	validation_0-logloss:0.60165	validation_1-logloss:0.52005
# [4]	validation_0-logloss:0.59132	validation_1-logloss:0.49218
# [5]	validation_0-logloss:0.58030	validation_1-logloss:0.46809
# [6]	validation_0-logloss:0.57248	validation_1-logloss:0.44655
# [7]	validation_0-logloss:0.56679	validation_1-logloss:0.42829
# [8]	validation_0-logloss:0.56268	validation_1-logloss:0.41137
# [9]	validation_0-logloss:0.55953	validation_1-logloss:0.39692
# [10]	validation_0-logloss:0.55573	validation_1-logloss:0.38423
# [11]	validation_0-logloss:0.55337	validation_1-logloss:0.37327
# [12]	validation_0-logloss:0.55439	validation_1-logloss:0.36227
# [13]	validation_0-logloss:0.55383	validation_1-logloss:0.35296
# [14]	validation_0-logloss:0.55301	validation_1-logloss:0.34254
# [15]	validation_0-logloss:0.55312	validation_1-logloss:0.33547
# [16]	validation_0-logloss:0.55576	validation_1-logloss:0.32878
# [17]	validation_0-logloss:0.55646	validation_1-logloss:0.32091
# [18]	validation_0-logloss:0.55834	validation_1-logloss:0.31477
# [19]	validation_0-logloss:0.56525	validation_1-logloss:0.30948
# [20]	validation_0-logloss:0.56148	validation_1-logloss:0.30298
# [21]	validation_0-logloss:0.55646	validation_1-logloss:0.29666
# [22]	validation_0-logloss:0.55392	validation_1-logloss:0.29257
# [23]	validation_0-logloss:0.55893	validation_1-logloss:0.28871
# [24]	validation_0-logloss:0.55918	validation_1-logloss:0.28485
# [25]	validation_0-logloss:0.55958	validation_1-logloss:0.28107
# [26]	validation_0-logloss:0.56492	validation_1-logloss:0.27760
# [27]	validation_0-logloss:0.56626	validation_1-logloss:0.27449
# [28]	validation_0-logloss:0.56801	validation_1-logloss:0.27124
# [29]	validation_0-logloss:0.56789	validation_1-logloss:0.26901
# [30]	validation_0-logloss:0.56474	validation_1-logloss:0.26544
# [31]	validation_0-logloss:0.56435	validation_1-logloss:0.26307
# [32]	validation_0-logloss:0.56758	validation_1-logloss:0.26142
# [33]	validation_0-logloss:0.56137	validation_1-logloss:0.25800
# [34]	validation_0-logloss:0.56405	validation_1-logloss:0.25632
# [35]	validation_0-logloss:0.56146	validation_1-logloss:0.25391
# [36]	validation_0-logloss:0.55867	validation_1-logloss:0.25237
# [37]	validation_0-logloss:0.55772	validation_1-logloss:0.25055
# [38]	validation_0-logloss:0.55870	validation_1-logloss:0.24900
# [39]	validation_0-logloss:0.55892	validation_1-logloss:0.24738
# [40]	validation_0-logloss:0.55374	validation_1-logloss:0.24472
# [41]	validation_0-logloss:0.55270	validation_1-logloss:0.24333
# [42]	validation_0-logloss:0.54984	validation_1-logloss:0.24082
# [43]	validation_0-logloss:0.54808	validation_1-logloss:0.23963
# [44]	validation_0-logloss:0.54901	validation_1-logloss:0.23890
# [45]	validation_0-logloss:0.54751	validation_1-logloss:0.23781
# [46]	validation_0-logloss:0.54967	validation_1-logloss:0.23635
# [47]	validation_0-logloss:0.55020	validation_1-logloss:0.23571
# [48]	validation_0-logloss:0.54963	validation_1-logloss:0.23415
# [49]	validation_0-logloss:0.54856	validation_1-logloss:0.23255
# [50]	validation_0-logloss:0.54976	validation_1-logloss:0.23167
# [51]	validation_0-logloss:0.54769	validation_1-logloss:0.22997
# [52]	validation_0-logloss:0.54360	validation_1-logloss:0.22743
# [53]	validation_0-logloss:0.54282	validation_1-logloss:0.22693
# [54]	validation_0-logloss:0.54270	validation_1-logloss:0.22508
# [55]	validation_0-logloss:0.54234	validation_1-logloss:0.22411
# [56]	validation_0-logloss:0.53789	validation_1-logloss:0.22180
# [57]	validation_0-logloss:0.54009	validation_1-logloss:0.22063
# [58]	validation_0-logloss:0.53986	validation_1-logloss:0.21936
# [59]	validation_0-logloss:0.53880	validation_1-logloss:0.21790
# [60]	validation_0-logloss:0.53387	validation_1-logloss:0.21498
# [61]	validation_0-logloss:0.53311	validation_1-logloss:0.21317
# [62]	validation_0-logloss:0.53056	validation_1-logloss:0.21129
# [63]	validation_0-logloss:0.53362	validation_1-logloss:0.20915
# [64]	validation_0-logloss:0.53346	validation_1-logloss:0.20852
# [65]	validation_0-logloss:0.53373	validation_1-logloss:0.20750
# [66]	validation_0-logloss:0.53409	validation_1-logloss:0.20675
# [67]	validation_0-logloss:0.53617	validation_1-logloss:0.20560
# [68]	validation_0-logloss:0.53520	validation_1-logloss:0.20425
# [69]	validation_0-logloss:0.53766	validation_1-logloss:0.20332
# [70]	validation_0-logloss:0.53668	validation_1-logloss:0.20184
# [71]	validation_0-logloss:0.53707	validation_1-logloss:0.19987
# [72]	validation_0-logloss:0.53665	validation_1-logloss:0.19847
# [73]	validation_0-logloss:0.53603	validation_1-logloss:0.19727
# [74]	validation_0-logloss:0.53191	validation_1-logloss:0.19472
# [75]	validation_0-logloss:0.53139	validation_1-logloss:0.19251
# [76]	validation_0-logloss:0.53299	validation_1-logloss:0.19177
# [77]	validation_0-logloss:0.53083	validation_1-logloss:0.19036
# [78]	validation_0-logloss:0.53052	validation_1-logloss:0.18979
# [79]	validation_0-logloss:0.52901	validation_1-logloss:0.18854
# [80]	validation_0-logloss:0.53145	validation_1-logloss:0.18751
# [81]	validation_0-logloss:0.52955	validation_1-logloss:0.18609
# [82]	validation_0-logloss:0.53068	validation_1-logloss:0.18460
# [83]	validation_0-logloss:0.53111	validation_1-logloss:0.18424
# [84]	validation_0-logloss:0.53143	validation_1-logloss:0.18376
# [85]	validation_0-logloss:0.53312	validation_1-logloss:0.18270
# [86]	validation_0-logloss:0.53442	validation_1-logloss:0.18209
# [87]	validation_0-logloss:0.53328	validation_1-logloss:0.18094
# [88]	validation_0-logloss:0.53655	validation_1-logloss:0.18001
# [89]	validation_0-logloss:0.53918	validation_1-logloss:0.17871
# [90]	validation_0-logloss:0.53944	validation_1-logloss:0.17771
# [91]	validation_0-logloss:0.53978	validation_1-logloss:0.17591
# [92]	validation_0-logloss:0.54308	validation_1-logloss:0.17417
# [93]	validation_0-logloss:0.54322	validation_1-logloss:0.17318
# [94]	validation_0-logloss:0.54317	validation_1-logloss:0.17289
# [95]	validation_0-logloss:0.54518	validation_1-logloss:0.17209
# [96]	validation_0-logloss:0.54518	validation_1-logloss:0.17193
# [97]	validation_0-logloss:0.54616	validation_1-logloss:0.17146
# [98]	validation_0-logloss:0.54773	validation_1-logloss:0.17014
# [99]	validation_0-logloss:0.55080	validation_1-logloss:0.16820
