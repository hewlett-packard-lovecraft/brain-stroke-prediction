# %%
import pandas as pd
import random
import sklearn

from pathlib import Path
import xgboost as xgb
from xgboost.callback import EarlyStopping
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit

from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTENC

# %%
CATEGORICAL_FEATURE_NAMES = [
    "gender",
    "hypertension",
    "heart_disease",
    "ever_married",
    "work_type",
    "residence_type",
    "smoking_status",
]

NUMERIC_FEATURE_NAMES = ["age", "avg_glucose_level", "bmi"]


def encode_int(data: pd.DataFrame, categorical_features: list[str]):
    return pd.get_dummies(data, columns=categorical_features, drop_first=True)


def split_label(data: pd.DataFrame):
    x = data.copy().drop("stroke", axis=1)
    y = data["stroke"]  # labels

    return x, y


def resample(data: pd.DataFrame, seed: int, categorical_features: list[str]):
    """oversample positive cases with SMOTE and undersample negative with EEN"""
    # encode categorical features first
    enc = OrdinalEncoder()
    data[categorical_features] = enc.fit_transform(data[categorical_features])

    X = data.drop(columns=["stroke"], axis=1)
    Y = data["stroke"]

    cat_features_indices = [
        data.columns.get_loc(label) for label in categorical_features
    ]

    smote_nc = SMOTENC(categorical_features=cat_features_indices, random_state=seed)
    smote_een = SMOTEENN(smote=smote_nc, random_state=seed, sampling_strategy="auto")

    x_resampled, y_resampled = smote_een.fit_resample(X, Y)
    x_resampled["stroke"] = y_resampled

    x_resampled[categorical_features] = enc.inverse_transform(
        x_resampled[categorical_features]
    )

    return pd.DataFrame(x_resampled, columns=data.columns)


def scale(df):
    X_num = df[NUMERIC_FEATURE_NAMES]
    X_cat = df[CATEGORICAL_FEATURE_NAMES]

    scaler = StandardScaler()
    scaler.fit(X_num)

    X_scaled = scaler.transform(X_num)
    X_scaled = pd.DataFrame(X_scaled, index=X_num.index, columns=X_num.columns)

    df_scaled = pd.concat([X_scaled, X_cat, df["stroke"]], axis=1)

    return df_scaled


def split_train_valid_test(data_df, seed: int, resample_training: bool):
    data_df = data_df.sample(frac=1, random_state=seed)

    test_set = data_df[round(len(data_df) * 0.85) :]
    train_validation_data = data_df[: round(len(data_df) * 0.85)].sample(
        frac=1, random_state=seed
    )

    train_set = train_validation_data[: round(len(data_df) * 0.70)]
    validation_set = train_validation_data[round(len(data_df) * 0.70) :]

    if resample_training:
        train_set = resample(
            train_set, seed, categorical_features=CATEGORICAL_FEATURE_NAMES
        )

    return train_set, validation_set, test_set

def split_train_valid_test_stratified(data_df, seed: int, resample_training: bool):
    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=seed)
    d_x, d_y = split_label(data_df)

    train_index, valid_test_index = list(sss.split(d_x, d_y))[0]

    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=seed)

    v_t_x, v_t_y = split_label(data_df.iloc[valid_test_index])

    validation_index, test_index = list(sss.split(v_t_x, v_t_y))[0]

    train_df = data_df.iloc[train_index.tolist()]
    validation_df = data_df.iloc[validation_index.tolist()]
    test_df = data_df.iloc[test_index.tolist()]

    if resample_training:
        train_set = resample(
            train_df, seed, categorical_features=CATEGORICAL_FEATURE_NAMES
        )

    return train_df, validation_df, test_df


def one_hot_encode(
    data_df: pd.DataFrame,
    train_df: pd.DataFrame,
    validation_df: pd.DataFrame,
    test_df: pd.DataFrame,
):
    # ensure train, validation, and test all have the same columns after ohe

    ohe_columns = encode_int(data_df, CATEGORICAL_FEATURE_NAMES).columns

    train_df_e, validation_df_e, test_df_e = [
        pd.DataFrame(
            encode_int(data=df, categorical_features=CATEGORICAL_FEATURE_NAMES),
            columns=ohe_columns,
        ).fillna(0)
        for df in [train_df, validation_df, test_df]
    ]

    return train_df_e, validation_df_e, test_df_e


def prepare_data(seed: int, resample_training: bool):
    data_df = pd.read_csv(Path().resolve().joinpath("dataset/full_data_clean.csv"))

    train_df, validation_df, test_df = split_train_valid_test_stratified(
        data_df, seed, resample_training
    )

    train_df, validation_df, test_df = [
        scale(df) for df in [train_df, validation_df, test_df]
    ]

    return one_hot_encode(data_df, train_df, validation_df, test_df)

# %%
RESULT_COLS = [
    "precision",
    "recall",
    "fscore",
    "accuracy",
    "auc",
    "miss_rate",
    "fall_out_rate",
]
NUM_EXPERIMENTS = 10
NUM_ROUNDS = 20


def metrics(y_pred, p_pred, y_true):
    tn, fp, fn, tp = confusion_matrix(y_pred=y_pred, y_true=y_true).ravel()

    # metrics
    auc = roc_auc_score(y_true=y_true, y_score=p_pred)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    fscore = 2 * tp / (2 * tp + fp + fn)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    miss_rate = fn / (tn + tp)
    fall_out_rate = fp / (fp + tn)

    # return
    return [precision, recall, fscore, accuracy, auc, miss_rate, fall_out_rate]

# %%
def run_experiment(seed, experiment, train_data, validation_data, test_data):
    # split labels
    train_validation = pd.concat([train_data, validation_data]).sample(
        frac=1, random_state=seed
    )

    x, y = split_label(train_validation)
    x_test, y_test = split_label(test_data)

    # metrics
    param = {"max_depth": 2, "eta": 1, "objective": "binary:logistic"}

    es = EarlyStopping(
        rounds=3,
        save_best=True,
        maximize=True,
        data_name="validation_0",
        metric_name="auc",
    )

    clf = xgb.sklearn.XGBClassifier(
        learning_rate=0.1,
        objective=param["objective"],
        gpu_id=0,
        predictor="gpu_predictor",
    )

    clf.fit(x, y, eval_set=[(x_test, y_test), (x, y)])

    y_pred = clf.predict(x_test)
    p_pred = clf.predict_proba(x_test)[:, 1]

    return y_pred, p_pred, y_test

# %%
# evaluate xgboost

results = {}
results_resample = {}

for experiment in range(NUM_EXPERIMENTS):
    seed = random.randint(0, 1000)

    train_data, validation_data, test_data = prepare_data(
        seed=experiment, resample_training=False
    )

    y_pred, p_pred, y_test = run_experiment(
        seed, experiment, train_data, validation_data, test_data
    )

    results[experiment] = list(metrics(y_pred, p_pred, y_test))

    train_data, validation_data, test_data = prepare_data(
        seed=experiment, resample_training=True
    )

    y_pred, p_pred, y_test = run_experiment(
        seed, experiment, train_data, validation_data, test_data
    )

    results_resample[experiment] = list(metrics(y_pred, p_pred, y_test))
# Out:
# [0]	validation_0-logloss:0.60456	validation_1-logloss:0.60441
# [1]	validation_0-logloss:0.53207	validation_1-logloss:0.53173
# [2]	validation_0-logloss:0.47171	validation_1-logloss:0.47119
# [3]	validation_0-logloss:0.42083	validation_1-logloss:0.42013
# [4]	validation_0-logloss:0.37750	validation_1-logloss:0.37662
# [5]	validation_0-logloss:0.34031	validation_1-logloss:0.33926
# [6]	validation_0-logloss:0.30823	validation_1-logloss:0.30695
# [7]	validation_0-logloss:0.28032	validation_1-logloss:0.27888
# [8]	validation_0-logloss:0.25599	validation_1-logloss:0.25435
# [9]	validation_0-logloss:0.23467	validation_1-logloss:0.23292
# [10]	validation_0-logloss:0.21599	validation_1-logloss:0.21406
# [11]	validation_0-logloss:0.19955	validation_1-logloss:0.19748
# [12]	validation_0-logloss:0.18506	validation_1-logloss:0.18281
# [13]	validation_0-logloss:0.17232	validation_1-logloss:0.16980
# [14]	validation_0-logloss:0.16107	validation_1-logloss:0.15830
# [15]	validation_0-logloss:0.15109	validation_1-logloss:0.14806
# [16]	validation_0-logloss:0.14226	validation_1-logloss:0.13897
# [17]	validation_0-logloss:0.13429	validation_1-logloss:0.13092
# [18]	validation_0-logloss:0.12731	validation_1-logloss:0.12373
# [19]	validation_0-logloss:0.12108	validation_1-logloss:0.11733
# [20]	validation_0-logloss:0.11562	validation_1-logloss:0.11163
# [21]	validation_0-logloss:0.11071	validation_1-logloss:0.10654
# [22]	validation_0-logloss:0.10630	validation_1-logloss:0.10201
# [23]	validation_0-logloss:0.10251	validation_1-logloss:0.09792
# [24]	validation_0-logloss:0.09906	validation_1-logloss:0.09428
# [25]	validation_0-logloss:0.09593	validation_1-logloss:0.09103
# [26]	validation_0-logloss:0.09324	validation_1-logloss:0.08811
# [27]	validation_0-logloss:0.09071	validation_1-logloss:0.08546
# [28]	validation_0-logloss:0.08849	validation_1-logloss:0.08314
# [29]	validation_0-logloss:0.08655	validation_1-logloss:0.08106
# [30]	validation_0-logloss:0.08480	validation_1-logloss:0.07913
# [31]	validation_0-logloss:0.08335	validation_1-logloss:0.07747
# [32]	validation_0-logloss:0.08204	validation_1-logloss:0.07594
# [33]	validation_0-logloss:0.08089	validation_1-logloss:0.07460
# [34]	validation_0-logloss:0.07979	validation_1-logloss:0.07335
# [35]	validation_0-logloss:0.07878	validation_1-logloss:0.07221
# [36]	validation_0-logloss:0.07797	validation_1-logloss:0.07121
# [37]	validation_0-logloss:0.07721	validation_1-logloss:0.07027
# [38]	validation_0-logloss:0.07637	validation_1-logloss:0.06937
# [39]	validation_0-logloss:0.07574	validation_1-logloss:0.06863
# [40]	validation_0-logloss:0.07500	validation_1-logloss:0.06793
# [41]	validation_0-logloss:0.07440	validation_1-logloss:0.06725
# [42]	validation_0-logloss:0.07387	validation_1-logloss:0.06662
# [43]	validation_0-logloss:0.07348	validation_1-logloss:0.06610
# [44]	validation_0-logloss:0.07312	validation_1-logloss:0.06562
# [45]	validation_0-logloss:0.07275	validation_1-logloss:0.06515
# [46]	validation_0-logloss:0.07240	validation_1-logloss:0.06472
# [47]	validation_0-logloss:0.07215	validation_1-logloss:0.06434
# [48]	validation_0-logloss:0.07183	validation_1-logloss:0.06395
# [49]	validation_0-logloss:0.07170	validation_1-logloss:0.06364
# [50]	validation_0-logloss:0.07145	validation_1-logloss:0.06323
# [51]	validation_0-logloss:0.07126	validation_1-logloss:0.06293
# [52]	validation_0-logloss:0.07115	validation_1-logloss:0.06263
# [53]	validation_0-logloss:0.07110	validation_1-logloss:0.06235
# [54]	validation_0-logloss:0.07099	validation_1-logloss:0.06211
# [55]	validation_0-logloss:0.07092	validation_1-logloss:0.06187
# [56]	validation_0-logloss:0.07086	validation_1-logloss:0.06167
# [57]	validation_0-logloss:0.07054	validation_1-logloss:0.06133
# [58]	validation_0-logloss:0.07038	validation_1-logloss:0.06105
# [59]	validation_0-logloss:0.07035	validation_1-logloss:0.06090
# [60]	validation_0-logloss:0.07030	validation_1-logloss:0.06066
# [61]	validation_0-logloss:0.07024	validation_1-logloss:0.06056
# [62]	validation_0-logloss:0.07015	validation_1-logloss:0.06041
# [63]	validation_0-logloss:0.07012	validation_1-logloss:0.06027
# [64]	validation_0-logloss:0.07004	validation_1-logloss:0.06011
# [65]	validation_0-logloss:0.06998	validation_1-logloss:0.06003
# [66]	validation_0-logloss:0.06992	validation_1-logloss:0.05994
# [67]	validation_0-logloss:0.06987	validation_1-logloss:0.05985
# [68]	validation_0-logloss:0.06986	validation_1-logloss:0.05975
# [69]	validation_0-logloss:0.06984	validation_1-logloss:0.05968
# [70]	validation_0-logloss:0.06978	validation_1-logloss:0.05957
# [71]	validation_0-logloss:0.06974	validation_1-logloss:0.05950
# [72]	validation_0-logloss:0.06960	validation_1-logloss:0.05934
# [73]	validation_0-logloss:0.06957	validation_1-logloss:0.05928
# [74]	validation_0-logloss:0.06953	validation_1-logloss:0.05908
# [75]	validation_0-logloss:0.06959	validation_1-logloss:0.05899
# [76]	validation_0-logloss:0.06954	validation_1-logloss:0.05890
# [77]	validation_0-logloss:0.06949	validation_1-logloss:0.05885
# [78]	validation_0-logloss:0.06947	validation_1-logloss:0.05877
# [79]	validation_0-logloss:0.06943	validation_1-logloss:0.05869
# [80]	validation_0-logloss:0.06942	validation_1-logloss:0.05856
# [81]	validation_0-logloss:0.06935	validation_1-logloss:0.05845
# [82]	validation_0-logloss:0.06932	validation_1-logloss:0.05842
# [83]	validation_0-logloss:0.06932	validation_1-logloss:0.05828
# [84]	validation_0-logloss:0.06930	validation_1-logloss:0.05823
# [85]	validation_0-logloss:0.06930	validation_1-logloss:0.05821
# [86]	validation_0-logloss:0.06924	validation_1-logloss:0.05809
# [87]	validation_0-logloss:0.06924	validation_1-logloss:0.05803
# [88]	validation_0-logloss:0.06922	validation_1-logloss:0.05795
# [89]	validation_0-logloss:0.06922	validation_1-logloss:0.05783
# [90]	validation_0-logloss:0.06920	validation_1-logloss:0.05776
# [91]	validation_0-logloss:0.06918	validation_1-logloss:0.05768
# [92]	validation_0-logloss:0.06918	validation_1-logloss:0.05762
# [93]	validation_0-logloss:0.06916	validation_1-logloss:0.05756
# [94]	validation_0-logloss:0.06895	validation_1-logloss:0.05722
# [95]	validation_0-logloss:0.06891	validation_1-logloss:0.05707
# [96]	validation_0-logloss:0.06891	validation_1-logloss:0.05703
# [97]	validation_0-logloss:0.06888	validation_1-logloss:0.05689
# [98]	validation_0-logloss:0.06888	validation_1-logloss:0.05686
# [99]	validation_0-logloss:0.06887	validation_1-logloss:0.05672
# /tmp/ipykernel_12706/3160611095.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# /tmp/ipykernel_12706/2430262989.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.60472	validation_1-logloss:0.60442
# [1]	validation_0-logloss:0.53234	validation_1-logloss:0.53177
# [2]	validation_0-logloss:0.47209	validation_1-logloss:0.47128
# [3]	validation_0-logloss:0.42128	validation_1-logloss:0.42024
# [4]	validation_0-logloss:0.37803	validation_1-logloss:0.37677
# [5]	validation_0-logloss:0.34090	validation_1-logloss:0.33942
# [6]	validation_0-logloss:0.30881	validation_1-logloss:0.30718
# [7]	validation_0-logloss:0.28102	validation_1-logloss:0.27914
# [8]	validation_0-logloss:0.25669	validation_1-logloss:0.25470
# [9]	validation_0-logloss:0.23549	validation_1-logloss:0.23329
# [10]	validation_0-logloss:0.21692	validation_1-logloss:0.21449
# [11]	validation_0-logloss:0.20062	validation_1-logloss:0.19795
# [12]	validation_0-logloss:0.18611	validation_1-logloss:0.18336
# [13]	validation_0-logloss:0.17330	validation_1-logloss:0.17044
# [14]	validation_0-logloss:0.16199	validation_1-logloss:0.15902
# [15]	validation_0-logloss:0.15199	validation_1-logloss:0.14890
# [16]	validation_0-logloss:0.14315	validation_1-logloss:0.13990
# [17]	validation_0-logloss:0.13537	validation_1-logloss:0.13188
# [18]	validation_0-logloss:0.12844	validation_1-logloss:0.12479
# [19]	validation_0-logloss:0.12231	validation_1-logloss:0.11846
# [20]	validation_0-logloss:0.11686	validation_1-logloss:0.11280
# [21]	validation_0-logloss:0.11201	validation_1-logloss:0.10773
# [22]	validation_0-logloss:0.10767	validation_1-logloss:0.10326
# [23]	validation_0-logloss:0.10374	validation_1-logloss:0.09921
# [24]	validation_0-logloss:0.10025	validation_1-logloss:0.09563
# [25]	validation_0-logloss:0.09720	validation_1-logloss:0.09244
# [26]	validation_0-logloss:0.09439	validation_1-logloss:0.08956
# [27]	validation_0-logloss:0.09203	validation_1-logloss:0.08697
# [28]	validation_0-logloss:0.08987	validation_1-logloss:0.08468
# [29]	validation_0-logloss:0.08801	validation_1-logloss:0.08260
# [30]	validation_0-logloss:0.08635	validation_1-logloss:0.08076
# [31]	validation_0-logloss:0.08492	validation_1-logloss:0.07907
# [32]	validation_0-logloss:0.08359	validation_1-logloss:0.07756
# [33]	validation_0-logloss:0.08241	validation_1-logloss:0.07618
# [34]	validation_0-logloss:0.08143	validation_1-logloss:0.07495
# [35]	validation_0-logloss:0.08054	validation_1-logloss:0.07384
# [36]	validation_0-logloss:0.07971	validation_1-logloss:0.07280
# [37]	validation_0-logloss:0.07899	validation_1-logloss:0.07187
# [38]	validation_0-logloss:0.07826	validation_1-logloss:0.07104
# [39]	validation_0-logloss:0.07765	validation_1-logloss:0.07028
# [40]	validation_0-logloss:0.07712	validation_1-logloss:0.06964
# [41]	validation_0-logloss:0.07679	validation_1-logloss:0.06903
# [42]	validation_0-logloss:0.07639	validation_1-logloss:0.06850
# [43]	validation_0-logloss:0.07609	validation_1-logloss:0.06801
# [44]	validation_0-logloss:0.07574	validation_1-logloss:0.06757
# [45]	validation_0-logloss:0.07558	validation_1-logloss:0.06713
# [46]	validation_0-logloss:0.07529	validation_1-logloss:0.06676
# [47]	validation_0-logloss:0.07510	validation_1-logloss:0.06639
# [48]	validation_0-logloss:0.07495	validation_1-logloss:0.06605
# [49]	validation_0-logloss:0.07480	validation_1-logloss:0.06572
# [50]	validation_0-logloss:0.07461	validation_1-logloss:0.06545
# [51]	validation_0-logloss:0.07444	validation_1-logloss:0.06513
# [52]	validation_0-logloss:0.07427	validation_1-logloss:0.06489
# [53]	validation_0-logloss:0.07413	validation_1-logloss:0.06463
# [54]	validation_0-logloss:0.07405	validation_1-logloss:0.06443
# [55]	validation_0-logloss:0.07392	validation_1-logloss:0.06421
# [56]	validation_0-logloss:0.07389	validation_1-logloss:0.06405
# [57]	validation_0-logloss:0.07376	validation_1-logloss:0.06385
# [58]	validation_0-logloss:0.07375	validation_1-logloss:0.06366
# [59]	validation_0-logloss:0.07374	validation_1-logloss:0.06350
# [60]	validation_0-logloss:0.07365	validation_1-logloss:0.06333
# [61]	validation_0-logloss:0.07364	validation_1-logloss:0.06321
# [62]	validation_0-logloss:0.07361	validation_1-logloss:0.06312
# [63]	validation_0-logloss:0.07361	validation_1-logloss:0.06298
# [64]	validation_0-logloss:0.07357	validation_1-logloss:0.06285
# [65]	validation_0-logloss:0.07357	validation_1-logloss:0.06277
# [66]	validation_0-logloss:0.07345	validation_1-logloss:0.06265
# [67]	validation_0-logloss:0.07341	validation_1-logloss:0.06256
# [68]	validation_0-logloss:0.07344	validation_1-logloss:0.06250
# [69]	validation_0-logloss:0.07348	validation_1-logloss:0.06244
# [70]	validation_0-logloss:0.07350	validation_1-logloss:0.06228
# [71]	validation_0-logloss:0.07344	validation_1-logloss:0.06222
# [72]	validation_0-logloss:0.07338	validation_1-logloss:0.06216
# [73]	validation_0-logloss:0.07335	validation_1-logloss:0.06204
# [74]	validation_0-logloss:0.07340	validation_1-logloss:0.06199
# [75]	validation_0-logloss:0.07336	validation_1-logloss:0.06178
# [76]	validation_0-logloss:0.07329	validation_1-logloss:0.06164
# [77]	validation_0-logloss:0.07327	validation_1-logloss:0.06155
# [78]	validation_0-logloss:0.07321	validation_1-logloss:0.06137
# [79]	validation_0-logloss:0.07328	validation_1-logloss:0.06126
# [80]	validation_0-logloss:0.07330	validation_1-logloss:0.06118
# [81]	validation_0-logloss:0.07324	validation_1-logloss:0.06108
# [82]	validation_0-logloss:0.07325	validation_1-logloss:0.06100
# [83]	validation_0-logloss:0.07323	validation_1-logloss:0.06093
# [84]	validation_0-logloss:0.07327	validation_1-logloss:0.06087
# [85]	validation_0-logloss:0.07332	validation_1-logloss:0.06082
# [86]	validation_0-logloss:0.07333	validation_1-logloss:0.06078
# [87]	validation_0-logloss:0.07333	validation_1-logloss:0.06071
# [88]	validation_0-logloss:0.07331	validation_1-logloss:0.06066
# [89]	validation_0-logloss:0.07323	validation_1-logloss:0.06046
# [90]	validation_0-logloss:0.07325	validation_1-logloss:0.06033
# [91]	validation_0-logloss:0.07314	validation_1-logloss:0.06011
# [92]	validation_0-logloss:0.07315	validation_1-logloss:0.05997
# [93]	validation_0-logloss:0.07310	validation_1-logloss:0.05982
# [94]	validation_0-logloss:0.07299	validation_1-logloss:0.05965
# [95]	validation_0-logloss:0.07292	validation_1-logloss:0.05949
# [96]	validation_0-logloss:0.07296	validation_1-logloss:0.05937
# [97]	validation_0-logloss:0.07296	validation_1-logloss:0.05922
# [98]	validation_0-logloss:0.07285	validation_1-logloss:0.05907
# [99]	validation_0-logloss:0.07280	validation_1-logloss:0.05899
# /tmp/ipykernel_12706/3160611095.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# [0]	validation_0-logloss:0.60415	validation_1-logloss:0.60467
# [1]	validation_0-logloss:0.53122	validation_1-logloss:0.53222
# [2]	validation_0-logloss:0.47044	validation_1-logloss:0.47188
# [3]	validation_0-logloss:0.41919	validation_1-logloss:0.42097
# [4]	validation_0-logloss:0.37549	validation_1-logloss:0.37762
# [5]	validation_0-logloss:0.33796	validation_1-logloss:0.34037
# [6]	validation_0-logloss:0.30550	validation_1-logloss:0.30816
# [7]	validation_0-logloss:0.27727	validation_1-logloss:0.28019
# [8]	validation_0-logloss:0.25261	validation_1-logloss:0.25579
# [9]	validation_0-logloss:0.23102	validation_1-logloss:0.23441
# [10]	validation_0-logloss:0.21205	validation_1-logloss:0.21562
# [11]	validation_0-logloss:0.19534	validation_1-logloss:0.19907
# [12]	validation_0-logloss:0.18057	validation_1-logloss:0.18445
# [13]	validation_0-logloss:0.16751	validation_1-logloss:0.17149
# [14]	validation_0-logloss:0.15598	validation_1-logloss:0.16005
# [15]	validation_0-logloss:0.14578	validation_1-logloss:0.14986
# [16]	validation_0-logloss:0.13674	validation_1-logloss:0.14084
# [17]	validation_0-logloss:0.12862	validation_1-logloss:0.13281
# [18]	validation_0-logloss:0.12136	validation_1-logloss:0.12565
# [19]	validation_0-logloss:0.11503	validation_1-logloss:0.11921
# [20]	validation_0-logloss:0.10935	validation_1-logloss:0.11350
# [21]	validation_0-logloss:0.10431	validation_1-logloss:0.10844
# [22]	validation_0-logloss:0.09976	validation_1-logloss:0.10393
# [23]	validation_0-logloss:0.09571	validation_1-logloss:0.09993
# [24]	validation_0-logloss:0.09213	validation_1-logloss:0.09631
# [25]	validation_0-logloss:0.08895	validation_1-logloss:0.09309
# [26]	validation_0-logloss:0.08585	validation_1-logloss:0.09012
# [27]	validation_0-logloss:0.08316	validation_1-logloss:0.08747
# [28]	validation_0-logloss:0.08080	validation_1-logloss:0.08514
# [29]	validation_0-logloss:0.07871	validation_1-logloss:0.08302
# [30]	validation_0-logloss:0.07679	validation_1-logloss:0.08111
# [31]	validation_0-logloss:0.07515	validation_1-logloss:0.07939
# [32]	validation_0-logloss:0.07366	validation_1-logloss:0.07789
# [33]	validation_0-logloss:0.07234	validation_1-logloss:0.07654
# [34]	validation_0-logloss:0.07110	validation_1-logloss:0.07526
# [35]	validation_0-logloss:0.07002	validation_1-logloss:0.07418
# [36]	validation_0-logloss:0.06900	validation_1-logloss:0.07314
# [37]	validation_0-logloss:0.06804	validation_1-logloss:0.07222
# [38]	validation_0-logloss:0.06726	validation_1-logloss:0.07141
# [39]	validation_0-logloss:0.06658	validation_1-logloss:0.07063
# [40]	validation_0-logloss:0.06583	validation_1-logloss:0.06996
# [41]	validation_0-logloss:0.06529	validation_1-logloss:0.06934
# [42]	validation_0-logloss:0.06463	validation_1-logloss:0.06867
# [43]	validation_0-logloss:0.06423	validation_1-logloss:0.06814
# [44]	validation_0-logloss:0.06377	validation_1-logloss:0.06762
# [45]	validation_0-logloss:0.06336	validation_1-logloss:0.06718
# [46]	validation_0-logloss:0.06295	validation_1-logloss:0.06672
# [47]	validation_0-logloss:0.06268	validation_1-logloss:0.06638
# [48]	validation_0-logloss:0.06234	validation_1-logloss:0.06600
# [49]	validation_0-logloss:0.06206	validation_1-logloss:0.06565
# [50]	validation_0-logloss:0.06187	validation_1-logloss:0.06535
# [51]	validation_0-logloss:0.06170	validation_1-logloss:0.06508
# [52]	validation_0-logloss:0.06140	validation_1-logloss:0.06470
# [53]	validation_0-logloss:0.06119	validation_1-logloss:0.06447
# [54]	validation_0-logloss:0.06105	validation_1-logloss:0.06427
# [55]	validation_0-logloss:0.06091	validation_1-logloss:0.06402
# [56]	validation_0-logloss:0.06078	validation_1-logloss:0.06383
# [57]	validation_0-logloss:0.06067	validation_1-logloss:0.06365
# [58]	validation_0-logloss:0.06056	validation_1-logloss:0.06348
# [59]	validation_0-logloss:0.06050	validation_1-logloss:0.06334
# [60]	validation_0-logloss:0.06041	validation_1-logloss:0.06320
# [61]	validation_0-logloss:0.06023	validation_1-logloss:0.06294
# [62]	validation_0-logloss:0.06013	validation_1-logloss:0.06278
# [63]	validation_0-logloss:0.06008	validation_1-logloss:0.06265
# [64]	validation_0-logloss:0.06001	validation_1-logloss:0.06255
# [65]	validation_0-logloss:0.05986	validation_1-logloss:0.06239
# [66]	validation_0-logloss:0.05983	validation_1-logloss:0.06230
# [67]	validation_0-logloss:0.05975	validation_1-logloss:0.06214
# [68]	validation_0-logloss:0.05970	validation_1-logloss:0.06208
# [69]	validation_0-logloss:0.05962	validation_1-logloss:0.06200
# [70]	validation_0-logloss:0.05956	validation_1-logloss:0.06184
# [71]	validation_0-logloss:0.05950	validation_1-logloss:0.06163
# [72]	validation_0-logloss:0.05944	validation_1-logloss:0.06151
# [73]	validation_0-logloss:0.05935	validation_1-logloss:0.06125
# [74]	validation_0-logloss:0.05931	validation_1-logloss:0.06121
# [75]	validation_0-logloss:0.05929	validation_1-logloss:0.06115
# [76]	validation_0-logloss:0.05924	validation_1-logloss:0.06103
# [77]	validation_0-logloss:0.05917	validation_1-logloss:0.06095
# [78]	validation_0-logloss:0.05914	validation_1-logloss:0.06088
# [79]	validation_0-logloss:0.05909	validation_1-logloss:0.06076
# [80]	validation_0-logloss:0.05907	validation_1-logloss:0.06070
# [81]	validation_0-logloss:0.05905	validation_1-logloss:0.06050
# [82]	validation_0-logloss:0.05900	validation_1-logloss:0.06043
# [83]	validation_0-logloss:0.05899	validation_1-logloss:0.06041
# [84]	validation_0-logloss:0.05893	validation_1-logloss:0.06020
# [85]	validation_0-logloss:0.05889	validation_1-logloss:0.06011
# [86]	validation_0-logloss:0.05886	validation_1-logloss:0.06005
# [87]	validation_0-logloss:0.05878	validation_1-logloss:0.05989
# [88]	validation_0-logloss:0.05874	validation_1-logloss:0.05978
# [89]	validation_0-logloss:0.05864	validation_1-logloss:0.05951
# [90]	validation_0-logloss:0.05863	validation_1-logloss:0.05946
# [91]	validation_0-logloss:0.05859	validation_1-logloss:0.05941
# [92]	validation_0-logloss:0.05861	validation_1-logloss:0.05937
# [93]	validation_0-logloss:0.05854	validation_1-logloss:0.05922
# [94]	validation_0-logloss:0.05846	validation_1-logloss:0.05910
# [95]	validation_0-logloss:0.05845	validation_1-logloss:0.05902
# [96]	validation_0-logloss:0.05827	validation_1-logloss:0.05868
# [97]	validation_0-logloss:0.05814	validation_1-logloss:0.05848
# [98]	validation_0-logloss:0.05812	validation_1-logloss:0.05840
# [99]	validation_0-logloss:0.05796	validation_1-logloss:0.05808
# /tmp/ipykernel_12706/3160611095.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# /tmp/ipykernel_12706/2430262989.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.60440	validation_1-logloss:0.60465
# [1]	validation_0-logloss:0.53171	validation_1-logloss:0.53220
# [2]	validation_0-logloss:0.47109	validation_1-logloss:0.47189
# [3]	validation_0-logloss:0.42003	validation_1-logloss:0.42101
# [4]	validation_0-logloss:0.37661	validation_1-logloss:0.37766
# [5]	validation_0-logloss:0.33938	validation_1-logloss:0.34046
# [6]	validation_0-logloss:0.30720	validation_1-logloss:0.30828
# [7]	validation_0-logloss:0.27913	validation_1-logloss:0.28033
# [8]	validation_0-logloss:0.25462	validation_1-logloss:0.25597
# [9]	validation_0-logloss:0.23313	validation_1-logloss:0.23464
# [10]	validation_0-logloss:0.21433	validation_1-logloss:0.21592
# [11]	validation_0-logloss:0.19767	validation_1-logloss:0.19946
# [12]	validation_0-logloss:0.18293	validation_1-logloss:0.18488
# [13]	validation_0-logloss:0.16996	validation_1-logloss:0.17199
# [14]	validation_0-logloss:0.15840	validation_1-logloss:0.16061
# [15]	validation_0-logloss:0.14820	validation_1-logloss:0.15050
# [16]	validation_0-logloss:0.13915	validation_1-logloss:0.14153
# [17]	validation_0-logloss:0.13118	validation_1-logloss:0.13356
# [18]	validation_0-logloss:0.12399	validation_1-logloss:0.12645
# [19]	validation_0-logloss:0.11753	validation_1-logloss:0.12009
# [20]	validation_0-logloss:0.11180	validation_1-logloss:0.11447
# [21]	validation_0-logloss:0.10672	validation_1-logloss:0.10941
# [22]	validation_0-logloss:0.10207	validation_1-logloss:0.10494
# [23]	validation_0-logloss:0.09793	validation_1-logloss:0.10089
# [24]	validation_0-logloss:0.09426	validation_1-logloss:0.09728
# [25]	validation_0-logloss:0.09096	validation_1-logloss:0.09411
# [26]	validation_0-logloss:0.08814	validation_1-logloss:0.09118
# [27]	validation_0-logloss:0.08557	validation_1-logloss:0.08858
# [28]	validation_0-logloss:0.08325	validation_1-logloss:0.08628
# [29]	validation_0-logloss:0.08120	validation_1-logloss:0.08416
# [30]	validation_0-logloss:0.07925	validation_1-logloss:0.08231
# [31]	validation_0-logloss:0.07758	validation_1-logloss:0.08066
# [32]	validation_0-logloss:0.07611	validation_1-logloss:0.07919
# [33]	validation_0-logloss:0.07477	validation_1-logloss:0.07784
# [34]	validation_0-logloss:0.07355	validation_1-logloss:0.07662
# [35]	validation_0-logloss:0.07253	validation_1-logloss:0.07556
# [36]	validation_0-logloss:0.07150	validation_1-logloss:0.07461
# [37]	validation_0-logloss:0.07064	validation_1-logloss:0.07379
# [38]	validation_0-logloss:0.06995	validation_1-logloss:0.07298
# [39]	validation_0-logloss:0.06917	validation_1-logloss:0.07219
# [40]	validation_0-logloss:0.06850	validation_1-logloss:0.07157
# [41]	validation_0-logloss:0.06795	validation_1-logloss:0.07097
# [42]	validation_0-logloss:0.06747	validation_1-logloss:0.07039
# [43]	validation_0-logloss:0.06705	validation_1-logloss:0.06988
# [44]	validation_0-logloss:0.06657	validation_1-logloss:0.06942
# [45]	validation_0-logloss:0.06618	validation_1-logloss:0.06902
# [46]	validation_0-logloss:0.06583	validation_1-logloss:0.06862
# [47]	validation_0-logloss:0.06547	validation_1-logloss:0.06823
# [48]	validation_0-logloss:0.06513	validation_1-logloss:0.06783
# [49]	validation_0-logloss:0.06483	validation_1-logloss:0.06745
# [50]	validation_0-logloss:0.06459	validation_1-logloss:0.06714
# [51]	validation_0-logloss:0.06440	validation_1-logloss:0.06683
# [52]	validation_0-logloss:0.06422	validation_1-logloss:0.06661
# [53]	validation_0-logloss:0.06410	validation_1-logloss:0.06643
# [54]	validation_0-logloss:0.06397	validation_1-logloss:0.06625
# [55]	validation_0-logloss:0.06385	validation_1-logloss:0.06608
# [56]	validation_0-logloss:0.06374	validation_1-logloss:0.06590
# [57]	validation_0-logloss:0.06368	validation_1-logloss:0.06573
# [58]	validation_0-logloss:0.06352	validation_1-logloss:0.06551
# [59]	validation_0-logloss:0.06344	validation_1-logloss:0.06539
# [60]	validation_0-logloss:0.06335	validation_1-logloss:0.06525
# [61]	validation_0-logloss:0.06322	validation_1-logloss:0.06506
# [62]	validation_0-logloss:0.06312	validation_1-logloss:0.06497
# [63]	validation_0-logloss:0.06314	validation_1-logloss:0.06487
# [64]	validation_0-logloss:0.06307	validation_1-logloss:0.06474
# [65]	validation_0-logloss:0.06303	validation_1-logloss:0.06463
# [66]	validation_0-logloss:0.06296	validation_1-logloss:0.06455
# [67]	validation_0-logloss:0.06285	validation_1-logloss:0.06440
# [68]	validation_0-logloss:0.06278	validation_1-logloss:0.06434
# [69]	validation_0-logloss:0.06274	validation_1-logloss:0.06420
# [70]	validation_0-logloss:0.06281	validation_1-logloss:0.06408
# [71]	validation_0-logloss:0.06276	validation_1-logloss:0.06399
# [72]	validation_0-logloss:0.06269	validation_1-logloss:0.06392
# [73]	validation_0-logloss:0.06266	validation_1-logloss:0.06387
# [74]	validation_0-logloss:0.06263	validation_1-logloss:0.06379
# [75]	validation_0-logloss:0.06258	validation_1-logloss:0.06375
# [76]	validation_0-logloss:0.06250	validation_1-logloss:0.06366
# [77]	validation_0-logloss:0.06247	validation_1-logloss:0.06350
# [78]	validation_0-logloss:0.06243	validation_1-logloss:0.06330
# [79]	validation_0-logloss:0.06242	validation_1-logloss:0.06322
# [80]	validation_0-logloss:0.06234	validation_1-logloss:0.06311
# [81]	validation_0-logloss:0.06228	validation_1-logloss:0.06305
# [82]	validation_0-logloss:0.06226	validation_1-logloss:0.06300
# [83]	validation_0-logloss:0.06220	validation_1-logloss:0.06286
# [84]	validation_0-logloss:0.06218	validation_1-logloss:0.06277
# [85]	validation_0-logloss:0.06209	validation_1-logloss:0.06257
# [86]	validation_0-logloss:0.06207	validation_1-logloss:0.06253
# [87]	validation_0-logloss:0.06199	validation_1-logloss:0.06236
# [88]	validation_0-logloss:0.06196	validation_1-logloss:0.06230
# [89]	validation_0-logloss:0.06193	validation_1-logloss:0.06227
# [90]	validation_0-logloss:0.06195	validation_1-logloss:0.06222
# [91]	validation_0-logloss:0.06197	validation_1-logloss:0.06213
# [92]	validation_0-logloss:0.06198	validation_1-logloss:0.06209
# [93]	validation_0-logloss:0.06202	validation_1-logloss:0.06202
# [94]	validation_0-logloss:0.06186	validation_1-logloss:0.06176
# [95]	validation_0-logloss:0.06181	validation_1-logloss:0.06162
# [96]	validation_0-logloss:0.06173	validation_1-logloss:0.06147
# [97]	validation_0-logloss:0.06174	validation_1-logloss:0.06142
# [98]	validation_0-logloss:0.06173	validation_1-logloss:0.06137
# [99]	validation_0-logloss:0.06171	validation_1-logloss:0.06126
# /tmp/ipykernel_12706/3160611095.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# [0]	validation_0-logloss:0.60458	validation_1-logloss:0.60448
# [1]	validation_0-logloss:0.53206	validation_1-logloss:0.53189
# [2]	validation_0-logloss:0.47172	validation_1-logloss:0.47144
# [3]	validation_0-logloss:0.42082	validation_1-logloss:0.42042
# [4]	validation_0-logloss:0.37748	validation_1-logloss:0.37692
# [5]	validation_0-logloss:0.34027	validation_1-logloss:0.33956
# [6]	validation_0-logloss:0.30811	validation_1-logloss:0.30728
# [7]	validation_0-logloss:0.28022	validation_1-logloss:0.27924
# [8]	validation_0-logloss:0.25588	validation_1-logloss:0.25475
# [9]	validation_0-logloss:0.23451	validation_1-logloss:0.23329
# [10]	validation_0-logloss:0.21579	validation_1-logloss:0.21444
# [11]	validation_0-logloss:0.19928	validation_1-logloss:0.19783
# [12]	validation_0-logloss:0.18478	validation_1-logloss:0.18318
# [13]	validation_0-logloss:0.17193	validation_1-logloss:0.17023
# [14]	validation_0-logloss:0.16054	validation_1-logloss:0.15876
# [15]	validation_0-logloss:0.15044	validation_1-logloss:0.14857
# [16]	validation_0-logloss:0.14151	validation_1-logloss:0.13948
# [17]	validation_0-logloss:0.13354	validation_1-logloss:0.13141
# [18]	validation_0-logloss:0.12643	validation_1-logloss:0.12421
# [19]	validation_0-logloss:0.12017	validation_1-logloss:0.11781
# [20]	validation_0-logloss:0.11460	validation_1-logloss:0.11211
# [21]	validation_0-logloss:0.10963	validation_1-logloss:0.10706
# [22]	validation_0-logloss:0.10522	validation_1-logloss:0.10248
# [23]	validation_0-logloss:0.10125	validation_1-logloss:0.09845
# [24]	validation_0-logloss:0.09765	validation_1-logloss:0.09482
# [25]	validation_0-logloss:0.09442	validation_1-logloss:0.09155
# [26]	validation_0-logloss:0.09156	validation_1-logloss:0.08866
# [27]	validation_0-logloss:0.08902	validation_1-logloss:0.08607
# [28]	validation_0-logloss:0.08682	validation_1-logloss:0.08368
# [29]	validation_0-logloss:0.08486	validation_1-logloss:0.08158
# [30]	validation_0-logloss:0.08303	validation_1-logloss:0.07961
# [31]	validation_0-logloss:0.08153	validation_1-logloss:0.07790
# [32]	validation_0-logloss:0.08015	validation_1-logloss:0.07636
# [33]	validation_0-logloss:0.07894	validation_1-logloss:0.07489
# [34]	validation_0-logloss:0.07781	validation_1-logloss:0.07365
# [35]	validation_0-logloss:0.07689	validation_1-logloss:0.07256
# [36]	validation_0-logloss:0.07604	validation_1-logloss:0.07157
# [37]	validation_0-logloss:0.07528	validation_1-logloss:0.07063
# [38]	validation_0-logloss:0.07458	validation_1-logloss:0.06983
# [39]	validation_0-logloss:0.07395	validation_1-logloss:0.06913
# [40]	validation_0-logloss:0.07328	validation_1-logloss:0.06843
# [41]	validation_0-logloss:0.07269	validation_1-logloss:0.06781
# [42]	validation_0-logloss:0.07222	validation_1-logloss:0.06722
# [43]	validation_0-logloss:0.07179	validation_1-logloss:0.06655
# [44]	validation_0-logloss:0.07126	validation_1-logloss:0.06593
# [45]	validation_0-logloss:0.07089	validation_1-logloss:0.06548
# [46]	validation_0-logloss:0.07062	validation_1-logloss:0.06505
# [47]	validation_0-logloss:0.07032	validation_1-logloss:0.06469
# [48]	validation_0-logloss:0.07003	validation_1-logloss:0.06432
# [49]	validation_0-logloss:0.06977	validation_1-logloss:0.06395
# [50]	validation_0-logloss:0.06957	validation_1-logloss:0.06364
# [51]	validation_0-logloss:0.06935	validation_1-logloss:0.06335
# [52]	validation_0-logloss:0.06915	validation_1-logloss:0.06309
# [53]	validation_0-logloss:0.06907	validation_1-logloss:0.06283
# [54]	validation_0-logloss:0.06888	validation_1-logloss:0.06264
# [55]	validation_0-logloss:0.06865	validation_1-logloss:0.06236
# [56]	validation_0-logloss:0.06850	validation_1-logloss:0.06211
# [57]	validation_0-logloss:0.06835	validation_1-logloss:0.06190
# [58]	validation_0-logloss:0.06828	validation_1-logloss:0.06170
# [59]	validation_0-logloss:0.06816	validation_1-logloss:0.06157
# [60]	validation_0-logloss:0.06808	validation_1-logloss:0.06147
# [61]	validation_0-logloss:0.06801	validation_1-logloss:0.06137
# [62]	validation_0-logloss:0.06788	validation_1-logloss:0.06104
# [63]	validation_0-logloss:0.06781	validation_1-logloss:0.06096
# [64]	validation_0-logloss:0.06775	validation_1-logloss:0.06091
# [65]	validation_0-logloss:0.06771	validation_1-logloss:0.06059
# [66]	validation_0-logloss:0.06761	validation_1-logloss:0.06041
# [67]	validation_0-logloss:0.06755	validation_1-logloss:0.06036
# [68]	validation_0-logloss:0.06751	validation_1-logloss:0.06032
# [69]	validation_0-logloss:0.06745	validation_1-logloss:0.06018
# [70]	validation_0-logloss:0.06742	validation_1-logloss:0.06010
# [71]	validation_0-logloss:0.06732	validation_1-logloss:0.06000
# [72]	validation_0-logloss:0.06728	validation_1-logloss:0.05991
# [73]	validation_0-logloss:0.06725	validation_1-logloss:0.05987
# [74]	validation_0-logloss:0.06719	validation_1-logloss:0.05978
# [75]	validation_0-logloss:0.06712	validation_1-logloss:0.05955
# [76]	validation_0-logloss:0.06709	validation_1-logloss:0.05946
# [77]	validation_0-logloss:0.06699	validation_1-logloss:0.05934
# [78]	validation_0-logloss:0.06698	validation_1-logloss:0.05924
# [79]	validation_0-logloss:0.06693	validation_1-logloss:0.05915
# [80]	validation_0-logloss:0.06692	validation_1-logloss:0.05909
# [81]	validation_0-logloss:0.06690	validation_1-logloss:0.05900
# [82]	validation_0-logloss:0.06689	validation_1-logloss:0.05894
# [83]	validation_0-logloss:0.06689	validation_1-logloss:0.05887
# [84]	validation_0-logloss:0.06687	validation_1-logloss:0.05883
# [85]	validation_0-logloss:0.06672	validation_1-logloss:0.05857
# [86]	validation_0-logloss:0.06673	validation_1-logloss:0.05850
# [87]	validation_0-logloss:0.06669	validation_1-logloss:0.05840
# [88]	validation_0-logloss:0.06668	validation_1-logloss:0.05834
# [89]	validation_0-logloss:0.06665	validation_1-logloss:0.05827
# [90]	validation_0-logloss:0.06660	validation_1-logloss:0.05821
# [91]	validation_0-logloss:0.06658	validation_1-logloss:0.05817
# [92]	validation_0-logloss:0.06651	validation_1-logloss:0.05812
# [93]	validation_0-logloss:0.06644	validation_1-logloss:0.05804
# [94]	validation_0-logloss:0.06642	validation_1-logloss:0.05793
# [95]	validation_0-logloss:0.06637	validation_1-logloss:0.05789
# [96]	validation_0-logloss:0.06616	validation_1-logloss:0.05758
# [97]	validation_0-logloss:0.06607	validation_1-logloss:0.05745
# [98]	validation_0-logloss:0.06585	validation_1-logloss:0.05730
# [99]	validation_0-logloss:0.06584	validation_1-logloss:0.05718
# /tmp/ipykernel_12706/2430262989.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.60481	validation_1-logloss:0.60449
# [1]	validation_0-logloss:0.53239	validation_1-logloss:0.53190
# [2]	validation_0-logloss:0.47207	validation_1-logloss:0.47146
# [3]	validation_0-logloss:0.42114	validation_1-logloss:0.42046
# [4]	validation_0-logloss:0.37793	validation_1-logloss:0.37702
# [5]	validation_0-logloss:0.34085	validation_1-logloss:0.33969
# [6]	validation_0-logloss:0.30869	validation_1-logloss:0.30744
# [7]	validation_0-logloss:0.28070	validation_1-logloss:0.27940
# [8]	validation_0-logloss:0.25639	validation_1-logloss:0.25498
# [9]	validation_0-logloss:0.23504	validation_1-logloss:0.23357
# [10]	validation_0-logloss:0.21635	validation_1-logloss:0.21480
# [11]	validation_0-logloss:0.19992	validation_1-logloss:0.19825
# [12]	validation_0-logloss:0.18536	validation_1-logloss:0.18366
# [13]	validation_0-logloss:0.17250	validation_1-logloss:0.17071
# [14]	validation_0-logloss:0.16123	validation_1-logloss:0.15928
# [15]	validation_0-logloss:0.15116	validation_1-logloss:0.14914
# [16]	validation_0-logloss:0.14222	validation_1-logloss:0.14012
# [17]	validation_0-logloss:0.13429	validation_1-logloss:0.13212
# [18]	validation_0-logloss:0.12723	validation_1-logloss:0.12502
# [19]	validation_0-logloss:0.12095	validation_1-logloss:0.11868
# [20]	validation_0-logloss:0.11543	validation_1-logloss:0.11303
# [21]	validation_0-logloss:0.11060	validation_1-logloss:0.10801
# [22]	validation_0-logloss:0.10625	validation_1-logloss:0.10349
# [23]	validation_0-logloss:0.10232	validation_1-logloss:0.09945
# [24]	validation_0-logloss:0.09883	validation_1-logloss:0.09583
# [25]	validation_0-logloss:0.09560	validation_1-logloss:0.09258
# [26]	validation_0-logloss:0.09283	validation_1-logloss:0.08970
# [27]	validation_0-logloss:0.09029	validation_1-logloss:0.08710
# [28]	validation_0-logloss:0.08806	validation_1-logloss:0.08480
# [29]	validation_0-logloss:0.08614	validation_1-logloss:0.08271
# [30]	validation_0-logloss:0.08434	validation_1-logloss:0.08082
# [31]	validation_0-logloss:0.08272	validation_1-logloss:0.07909
# [32]	validation_0-logloss:0.08140	validation_1-logloss:0.07759
# [33]	validation_0-logloss:0.08019	validation_1-logloss:0.07619
# [34]	validation_0-logloss:0.07914	validation_1-logloss:0.07496
# [35]	validation_0-logloss:0.07819	validation_1-logloss:0.07391
# [36]	validation_0-logloss:0.07737	validation_1-logloss:0.07288
# [37]	validation_0-logloss:0.07668	validation_1-logloss:0.07202
# [38]	validation_0-logloss:0.07596	validation_1-logloss:0.07125
# [39]	validation_0-logloss:0.07529	validation_1-logloss:0.07051
# [40]	validation_0-logloss:0.07478	validation_1-logloss:0.06982
# [41]	validation_0-logloss:0.07429	validation_1-logloss:0.06926
# [42]	validation_0-logloss:0.07375	validation_1-logloss:0.06869
# [43]	validation_0-logloss:0.07330	validation_1-logloss:0.06818
# [44]	validation_0-logloss:0.07295	validation_1-logloss:0.06776
# [45]	validation_0-logloss:0.07268	validation_1-logloss:0.06728
# [46]	validation_0-logloss:0.07238	validation_1-logloss:0.06689
# [47]	validation_0-logloss:0.07209	validation_1-logloss:0.06653
# [48]	validation_0-logloss:0.07191	validation_1-logloss:0.06622
# [49]	validation_0-logloss:0.07164	validation_1-logloss:0.06586
# [50]	validation_0-logloss:0.07140	validation_1-logloss:0.06559
# [51]	validation_0-logloss:0.07123	validation_1-logloss:0.06535
# [52]	validation_0-logloss:0.07112	validation_1-logloss:0.06514
# [53]	validation_0-logloss:0.07102	validation_1-logloss:0.06493
# [54]	validation_0-logloss:0.07089	validation_1-logloss:0.06474
# [55]	validation_0-logloss:0.07068	validation_1-logloss:0.06449
# [56]	validation_0-logloss:0.07059	validation_1-logloss:0.06433
# [57]	validation_0-logloss:0.07063	validation_1-logloss:0.06414
# [58]	validation_0-logloss:0.07052	validation_1-logloss:0.06396
# [59]	validation_0-logloss:0.07050	validation_1-logloss:0.06379
# [60]	validation_0-logloss:0.07036	validation_1-logloss:0.06353
# [61]	validation_0-logloss:0.07028	validation_1-logloss:0.06339
# [62]	validation_0-logloss:0.07020	validation_1-logloss:0.06325
# [63]	validation_0-logloss:0.07012	validation_1-logloss:0.06317
# [64]	validation_0-logloss:0.07003	validation_1-logloss:0.06307
# [65]	validation_0-logloss:0.06999	validation_1-logloss:0.06290
# [66]	validation_0-logloss:0.06989	validation_1-logloss:0.06274
# [67]	validation_0-logloss:0.06996	validation_1-logloss:0.06252
# [68]	validation_0-logloss:0.06990	validation_1-logloss:0.06246
# [69]	validation_0-logloss:0.06986	validation_1-logloss:0.06232
# [70]	validation_0-logloss:0.06982	validation_1-logloss:0.06227
# [71]	validation_0-logloss:0.06975	validation_1-logloss:0.06218
# [72]	validation_0-logloss:0.06976	validation_1-logloss:0.06211
# [73]	validation_0-logloss:0.06971	validation_1-logloss:0.06199
# [74]	validation_0-logloss:0.06958	validation_1-logloss:0.06187
# [75]	validation_0-logloss:0.06952	validation_1-logloss:0.06176
# [76]	validation_0-logloss:0.06947	validation_1-logloss:0.06167
# [77]	validation_0-logloss:0.06941	validation_1-logloss:0.06156
# [78]	validation_0-logloss:0.06935	validation_1-logloss:0.06146
# [79]	validation_0-logloss:0.06932	validation_1-logloss:0.06137
# [80]	validation_0-logloss:0.06924	validation_1-logloss:0.06126
# [81]	validation_0-logloss:0.06905	validation_1-logloss:0.06106
# [82]	validation_0-logloss:0.06899	validation_1-logloss:0.06094
# [83]	validation_0-logloss:0.06904	validation_1-logloss:0.06083
# [84]	validation_0-logloss:0.06902	validation_1-logloss:0.06074
# [85]	validation_0-logloss:0.06897	validation_1-logloss:0.06062
# [86]	validation_0-logloss:0.06895	validation_1-logloss:0.06059
# [87]	validation_0-logloss:0.06890	validation_1-logloss:0.06051
# [88]	validation_0-logloss:0.06888	validation_1-logloss:0.06046
# [89]	validation_0-logloss:0.06888	validation_1-logloss:0.06035
# [90]	validation_0-logloss:0.06901	validation_1-logloss:0.06024
# [91]	validation_0-logloss:0.06900	validation_1-logloss:0.06015
# [92]	validation_0-logloss:0.06897	validation_1-logloss:0.06008
# [93]	validation_0-logloss:0.06890	validation_1-logloss:0.05998
# [94]	validation_0-logloss:0.06906	validation_1-logloss:0.05988
# [95]	validation_0-logloss:0.06897	validation_1-logloss:0.05978
# [96]	validation_0-logloss:0.06883	validation_1-logloss:0.05962
# [97]	validation_0-logloss:0.06900	validation_1-logloss:0.05950
# [98]	validation_0-logloss:0.06893	validation_1-logloss:0.05931
# [99]	validation_0-logloss:0.06899	validation_1-logloss:0.05913
# /tmp/ipykernel_12706/3160611095.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# [0]	validation_0-logloss:0.60447	validation_1-logloss:0.60448
# [1]	validation_0-logloss:0.53188	validation_1-logloss:0.53187
# [2]	validation_0-logloss:0.47147	validation_1-logloss:0.47138
# [3]	validation_0-logloss:0.42046	validation_1-logloss:0.42032
# [4]	validation_0-logloss:0.37704	validation_1-logloss:0.37679
# [5]	validation_0-logloss:0.33974	validation_1-logloss:0.33944
# [6]	validation_0-logloss:0.30758	validation_1-logloss:0.30713
# [7]	validation_0-logloss:0.27959	validation_1-logloss:0.27906
# [8]	validation_0-logloss:0.25518	validation_1-logloss:0.25456
# [9]	validation_0-logloss:0.23385	validation_1-logloss:0.23309
# [10]	validation_0-logloss:0.21513	validation_1-logloss:0.21425
# [11]	validation_0-logloss:0.19863	validation_1-logloss:0.19766
# [12]	validation_0-logloss:0.18405	validation_1-logloss:0.18301
# [13]	validation_0-logloss:0.17123	validation_1-logloss:0.17003
# [14]	validation_0-logloss:0.15989	validation_1-logloss:0.15853
# [15]	validation_0-logloss:0.14980	validation_1-logloss:0.14833
# [16]	validation_0-logloss:0.14094	validation_1-logloss:0.13930
# [17]	validation_0-logloss:0.13296	validation_1-logloss:0.13122
# [18]	validation_0-logloss:0.12589	validation_1-logloss:0.12406
# [19]	validation_0-logloss:0.11960	validation_1-logloss:0.11768
# [20]	validation_0-logloss:0.11399	validation_1-logloss:0.11196
# [21]	validation_0-logloss:0.10904	validation_1-logloss:0.10686
# [22]	validation_0-logloss:0.10449	validation_1-logloss:0.10218
# [23]	validation_0-logloss:0.10053	validation_1-logloss:0.09806
# [24]	validation_0-logloss:0.09692	validation_1-logloss:0.09433
# [25]	validation_0-logloss:0.09375	validation_1-logloss:0.09102
# [26]	validation_0-logloss:0.09096	validation_1-logloss:0.08808
# [27]	validation_0-logloss:0.08845	validation_1-logloss:0.08544
# [28]	validation_0-logloss:0.08620	validation_1-logloss:0.08308
# [29]	validation_0-logloss:0.08420	validation_1-logloss:0.08099
# [30]	validation_0-logloss:0.08237	validation_1-logloss:0.07908
# [31]	validation_0-logloss:0.08076	validation_1-logloss:0.07738
# [32]	validation_0-logloss:0.07933	validation_1-logloss:0.07587
# [33]	validation_0-logloss:0.07806	validation_1-logloss:0.07445
# [34]	validation_0-logloss:0.07696	validation_1-logloss:0.07322
# [35]	validation_0-logloss:0.07603	validation_1-logloss:0.07211
# [36]	validation_0-logloss:0.07503	validation_1-logloss:0.07105
# [37]	validation_0-logloss:0.07415	validation_1-logloss:0.07011
# [38]	validation_0-logloss:0.07350	validation_1-logloss:0.06924
# [39]	validation_0-logloss:0.07290	validation_1-logloss:0.06852
# [40]	validation_0-logloss:0.07234	validation_1-logloss:0.06782
# [41]	validation_0-logloss:0.07190	validation_1-logloss:0.06718
# [42]	validation_0-logloss:0.07140	validation_1-logloss:0.06657
# [43]	validation_0-logloss:0.07103	validation_1-logloss:0.06606
# [44]	validation_0-logloss:0.07060	validation_1-logloss:0.06556
# [45]	validation_0-logloss:0.07029	validation_1-logloss:0.06513
# [46]	validation_0-logloss:0.07003	validation_1-logloss:0.06469
# [47]	validation_0-logloss:0.06983	validation_1-logloss:0.06434
# [48]	validation_0-logloss:0.06949	validation_1-logloss:0.06397
# [49]	validation_0-logloss:0.06928	validation_1-logloss:0.06369
# [50]	validation_0-logloss:0.06908	validation_1-logloss:0.06340
# [51]	validation_0-logloss:0.06886	validation_1-logloss:0.06313
# [52]	validation_0-logloss:0.06861	validation_1-logloss:0.06287
# [53]	validation_0-logloss:0.06849	validation_1-logloss:0.06265
# [54]	validation_0-logloss:0.06840	validation_1-logloss:0.06237
# [55]	validation_0-logloss:0.06825	validation_1-logloss:0.06218
# [56]	validation_0-logloss:0.06815	validation_1-logloss:0.06201
# [57]	validation_0-logloss:0.06809	validation_1-logloss:0.06186
# [58]	validation_0-logloss:0.06800	validation_1-logloss:0.06170
# [59]	validation_0-logloss:0.06794	validation_1-logloss:0.06155
# [60]	validation_0-logloss:0.06786	validation_1-logloss:0.06142
# [61]	validation_0-logloss:0.06785	validation_1-logloss:0.06125
# [62]	validation_0-logloss:0.06783	validation_1-logloss:0.06111
# [63]	validation_0-logloss:0.06775	validation_1-logloss:0.06096
# [64]	validation_0-logloss:0.06775	validation_1-logloss:0.06088
# [65]	validation_0-logloss:0.06775	validation_1-logloss:0.06079
# [66]	validation_0-logloss:0.06774	validation_1-logloss:0.06067
# [67]	validation_0-logloss:0.06775	validation_1-logloss:0.06051
# [68]	validation_0-logloss:0.06769	validation_1-logloss:0.06040
# [69]	validation_0-logloss:0.06767	validation_1-logloss:0.06026
# [70]	validation_0-logloss:0.06764	validation_1-logloss:0.06015
# [71]	validation_0-logloss:0.06765	validation_1-logloss:0.06006
# [72]	validation_0-logloss:0.06764	validation_1-logloss:0.05999
# [73]	validation_0-logloss:0.06763	validation_1-logloss:0.05991
# [74]	validation_0-logloss:0.06763	validation_1-logloss:0.05977
# [75]	validation_0-logloss:0.06762	validation_1-logloss:0.05972
# [76]	validation_0-logloss:0.06760	validation_1-logloss:0.05961
# [77]	validation_0-logloss:0.06761	validation_1-logloss:0.05950
# [78]	validation_0-logloss:0.06760	validation_1-logloss:0.05945
# [79]	validation_0-logloss:0.06761	validation_1-logloss:0.05939
# [80]	validation_0-logloss:0.06766	validation_1-logloss:0.05929
# [81]	validation_0-logloss:0.06766	validation_1-logloss:0.05924
# [82]	validation_0-logloss:0.06768	validation_1-logloss:0.05916
# [83]	validation_0-logloss:0.06769	validation_1-logloss:0.05914
# [84]	validation_0-logloss:0.06770	validation_1-logloss:0.05912
# [85]	validation_0-logloss:0.06766	validation_1-logloss:0.05889
# [86]	validation_0-logloss:0.06766	validation_1-logloss:0.05886
# [87]	validation_0-logloss:0.06765	validation_1-logloss:0.05882
# [88]	validation_0-logloss:0.06767	validation_1-logloss:0.05870
# [89]	validation_0-logloss:0.06766	validation_1-logloss:0.05865
# [90]	validation_0-logloss:0.06765	validation_1-logloss:0.05848
# [91]	validation_0-logloss:0.06766	validation_1-logloss:0.05844
# [92]	validation_0-logloss:0.06761	validation_1-logloss:0.05806
# [93]	validation_0-logloss:0.06758	validation_1-logloss:0.05801
# [94]	validation_0-logloss:0.06758	validation_1-logloss:0.05797
# [95]	validation_0-logloss:0.06754	validation_1-logloss:0.05790
# [96]	validation_0-logloss:0.06732	validation_1-logloss:0.05755
# [97]	validation_0-logloss:0.06723	validation_1-logloss:0.05744
# [98]	validation_0-logloss:0.06719	validation_1-logloss:0.05733
# [99]	validation_0-logloss:0.06716	validation_1-logloss:0.05724
# /tmp/ipykernel_12706/2430262989.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.60451	validation_1-logloss:0.60454
# [1]	validation_0-logloss:0.53216	validation_1-logloss:0.53198
# [2]	validation_0-logloss:0.47195	validation_1-logloss:0.47153
# [3]	validation_0-logloss:0.42093	validation_1-logloss:0.42058
# [4]	validation_0-logloss:0.37762	validation_1-logloss:0.37711
# [5]	validation_0-logloss:0.34047	validation_1-logloss:0.33982
# [6]	validation_0-logloss:0.30848	validation_1-logloss:0.30756
# [7]	validation_0-logloss:0.28049	validation_1-logloss:0.27955
# [8]	validation_0-logloss:0.25635	validation_1-logloss:0.25513
# [9]	validation_0-logloss:0.23488	validation_1-logloss:0.23370
# [10]	validation_0-logloss:0.21605	validation_1-logloss:0.21488
# [11]	validation_0-logloss:0.19962	validation_1-logloss:0.19832
# [12]	validation_0-logloss:0.18513	validation_1-logloss:0.18372
# [13]	validation_0-logloss:0.17227	validation_1-logloss:0.17080
# [14]	validation_0-logloss:0.16099	validation_1-logloss:0.15936
# [15]	validation_0-logloss:0.15090	validation_1-logloss:0.14925
# [16]	validation_0-logloss:0.14198	validation_1-logloss:0.14023
# [17]	validation_0-logloss:0.13399	validation_1-logloss:0.13217
# [18]	validation_0-logloss:0.12697	validation_1-logloss:0.12504
# [19]	validation_0-logloss:0.12066	validation_1-logloss:0.11868
# [20]	validation_0-logloss:0.11515	validation_1-logloss:0.11297
# [21]	validation_0-logloss:0.11013	validation_1-logloss:0.10790
# [22]	validation_0-logloss:0.10575	validation_1-logloss:0.10340
# [23]	validation_0-logloss:0.10183	validation_1-logloss:0.09936
# [24]	validation_0-logloss:0.09836	validation_1-logloss:0.09578
# [25]	validation_0-logloss:0.09525	validation_1-logloss:0.09258
# [26]	validation_0-logloss:0.09245	validation_1-logloss:0.08972
# ...
# [59]	validation_0-logloss:0.06450	validation_1-logloss:0.06523
# [60]	validation_0-logloss:0.06445	validation_1-logloss:0.06512
# [61]	validation_0-logloss:0.06444	validation_1-logloss:0.06503
# [62]	validation_0-logloss:0.06436	validation_1-logloss:0.06493
# [63]	validation_0-logloss:0.06429	validation_1-logloss:0.06485
# [64]	validation_0-logloss:0.06427	validation_1-logloss:0.06470
# [65]	validation_0-logloss:0.06417	validation_1-logloss:0.06457
# [66]	validation_0-logloss:0.06409	validation_1-logloss:0.06445
# [67]	validation_0-logloss:0.06405	validation_1-logloss:0.06439
# [68]	validation_0-logloss:0.06398	validation_1-logloss:0.06426
# [69]	validation_0-logloss:0.06394	validation_1-logloss:0.06421
# [70]	validation_0-logloss:0.06386	validation_1-logloss:0.06410
# [71]	validation_0-logloss:0.06382	validation_1-logloss:0.06407
# [72]	validation_0-logloss:0.06376	validation_1-logloss:0.06384
# [73]	validation_0-logloss:0.06373	validation_1-logloss:0.06380
# [74]	validation_0-logloss:0.06365	validation_1-logloss:0.06367
# [75]	validation_0-logloss:0.06353	validation_1-logloss:0.06350
# [76]	validation_0-logloss:0.06344	validation_1-logloss:0.06333
# [77]	validation_0-logloss:0.06341	validation_1-logloss:0.06331
# [78]	validation_0-logloss:0.06339	validation_1-logloss:0.06317
# [79]	validation_0-logloss:0.06338	validation_1-logloss:0.06306
# [80]	validation_0-logloss:0.06334	validation_1-logloss:0.06286
# [81]	validation_0-logloss:0.06339	validation_1-logloss:0.06279
# [82]	validation_0-logloss:0.06337	validation_1-logloss:0.06265
# [83]	validation_0-logloss:0.06330	validation_1-logloss:0.06246
# [84]	validation_0-logloss:0.06330	validation_1-logloss:0.06241
# [85]	validation_0-logloss:0.06331	validation_1-logloss:0.06232
# [86]	validation_0-logloss:0.06330	validation_1-logloss:0.06223
# [87]	validation_0-logloss:0.06331	validation_1-logloss:0.06220
# [88]	validation_0-logloss:0.06329	validation_1-logloss:0.06213
# [89]	validation_0-logloss:0.06325	validation_1-logloss:0.06193
# [90]	validation_0-logloss:0.06329	validation_1-logloss:0.06187
# [91]	validation_0-logloss:0.06328	validation_1-logloss:0.06183
# [92]	validation_0-logloss:0.06323	validation_1-logloss:0.06162
# [93]	validation_0-logloss:0.06318	validation_1-logloss:0.06149
# [94]	validation_0-logloss:0.06322	validation_1-logloss:0.06142
# [95]	validation_0-logloss:0.06324	validation_1-logloss:0.06137
# [96]	validation_0-logloss:0.06325	validation_1-logloss:0.06130
# [97]	validation_0-logloss:0.06323	validation_1-logloss:0.06124
# [98]	validation_0-logloss:0.06318	validation_1-logloss:0.06116
# [99]	validation_0-logloss:0.06310	validation_1-logloss:0.06094
# /tmp/ipykernel_12706/3160611095.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# [0]	validation_0-logloss:0.60446	validation_1-logloss:0.60441
# [1]	validation_0-logloss:0.53195	validation_1-logloss:0.53176
# [2]	validation_0-logloss:0.47154	validation_1-logloss:0.47127
# [3]	validation_0-logloss:0.42061	validation_1-logloss:0.42026
# [4]	validation_0-logloss:0.37722	validation_1-logloss:0.37676
# [5]	validation_0-logloss:0.34000	validation_1-logloss:0.33940
# [6]	validation_0-logloss:0.30776	validation_1-logloss:0.30712
# [7]	validation_0-logloss:0.27983	validation_1-logloss:0.27906
# [8]	validation_0-logloss:0.25545	validation_1-logloss:0.25457
# [9]	validation_0-logloss:0.23408	validation_1-logloss:0.23311
# [10]	validation_0-logloss:0.21532	validation_1-logloss:0.21427
# [11]	validation_0-logloss:0.19885	validation_1-logloss:0.19768
# [12]	validation_0-logloss:0.18430	validation_1-logloss:0.18298
# [13]	validation_0-logloss:0.17142	validation_1-logloss:0.16998
# [14]	validation_0-logloss:0.16002	validation_1-logloss:0.15844
# [15]	validation_0-logloss:0.14991	validation_1-logloss:0.14823
# [16]	validation_0-logloss:0.14101	validation_1-logloss:0.13914
# [17]	validation_0-logloss:0.13309	validation_1-logloss:0.13109
# [18]	validation_0-logloss:0.12611	validation_1-logloss:0.12386
# [19]	validation_0-logloss:0.11990	validation_1-logloss:0.11744
# [20]	validation_0-logloss:0.11437	validation_1-logloss:0.11175
# [21]	validation_0-logloss:0.10942	validation_1-logloss:0.10670
# [22]	validation_0-logloss:0.10508	validation_1-logloss:0.10220
# [23]	validation_0-logloss:0.10121	validation_1-logloss:0.09811
# [24]	validation_0-logloss:0.09774	validation_1-logloss:0.09448
# [25]	validation_0-logloss:0.09467	validation_1-logloss:0.09119
# [26]	validation_0-logloss:0.09189	validation_1-logloss:0.08824
# [27]	validation_0-logloss:0.08948	validation_1-logloss:0.08567
# [28]	validation_0-logloss:0.08726	validation_1-logloss:0.08331
# [29]	validation_0-logloss:0.08533	validation_1-logloss:0.08114
# [30]	validation_0-logloss:0.08360	validation_1-logloss:0.07922
# [31]	validation_0-logloss:0.08210	validation_1-logloss:0.07751
# [32]	validation_0-logloss:0.08067	validation_1-logloss:0.07593
# [33]	validation_0-logloss:0.07946	validation_1-logloss:0.07453
# [34]	validation_0-logloss:0.07840	validation_1-logloss:0.07323
# [35]	validation_0-logloss:0.07741	validation_1-logloss:0.07212
# [36]	validation_0-logloss:0.07655	validation_1-logloss:0.07103
# [37]	validation_0-logloss:0.07578	validation_1-logloss:0.06997
# [38]	validation_0-logloss:0.07505	validation_1-logloss:0.06910
# [39]	validation_0-logloss:0.07439	validation_1-logloss:0.06838
# [40]	validation_0-logloss:0.07382	validation_1-logloss:0.06770
# [41]	validation_0-logloss:0.07323	validation_1-logloss:0.06695
# [42]	validation_0-logloss:0.07277	validation_1-logloss:0.06639
# [43]	validation_0-logloss:0.07234	validation_1-logloss:0.06581
# [44]	validation_0-logloss:0.07197	validation_1-logloss:0.06525
# [45]	validation_0-logloss:0.07166	validation_1-logloss:0.06471
# [46]	validation_0-logloss:0.07141	validation_1-logloss:0.06423
# [47]	validation_0-logloss:0.07118	validation_1-logloss:0.06380
# [48]	validation_0-logloss:0.07104	validation_1-logloss:0.06346
# [49]	validation_0-logloss:0.07093	validation_1-logloss:0.06316
# [50]	validation_0-logloss:0.07069	validation_1-logloss:0.06282
# [51]	validation_0-logloss:0.07055	validation_1-logloss:0.06251
# [52]	validation_0-logloss:0.07045	validation_1-logloss:0.06224
# [53]	validation_0-logloss:0.07028	validation_1-logloss:0.06198
# [54]	validation_0-logloss:0.07020	validation_1-logloss:0.06178
# [55]	validation_0-logloss:0.07009	validation_1-logloss:0.06163
# [56]	validation_0-logloss:0.07001	validation_1-logloss:0.06151
# [57]	validation_0-logloss:0.06997	validation_1-logloss:0.06137
# [58]	validation_0-logloss:0.06985	validation_1-logloss:0.06123
# [59]	validation_0-logloss:0.06977	validation_1-logloss:0.06114
# [60]	validation_0-logloss:0.06971	validation_1-logloss:0.06105
# [61]	validation_0-logloss:0.06968	validation_1-logloss:0.06094
# [62]	validation_0-logloss:0.06963	validation_1-logloss:0.06082
# [63]	validation_0-logloss:0.06954	validation_1-logloss:0.06072
# [64]	validation_0-logloss:0.06950	validation_1-logloss:0.06065
# [65]	validation_0-logloss:0.06945	validation_1-logloss:0.06060
# [66]	validation_0-logloss:0.06939	validation_1-logloss:0.06042
# [67]	validation_0-logloss:0.06938	validation_1-logloss:0.06035
# [68]	validation_0-logloss:0.06933	validation_1-logloss:0.06021
# [69]	validation_0-logloss:0.06928	validation_1-logloss:0.06017
# [70]	validation_0-logloss:0.06924	validation_1-logloss:0.06012
# [71]	validation_0-logloss:0.06919	validation_1-logloss:0.06006
# [72]	validation_0-logloss:0.06904	validation_1-logloss:0.05975
# [73]	validation_0-logloss:0.06897	validation_1-logloss:0.05967
# [74]	validation_0-logloss:0.06893	validation_1-logloss:0.05963
# [75]	validation_0-logloss:0.06885	validation_1-logloss:0.05948
# [76]	validation_0-logloss:0.06874	validation_1-logloss:0.05936
# [77]	validation_0-logloss:0.06866	validation_1-logloss:0.05910
# [78]	validation_0-logloss:0.06866	validation_1-logloss:0.05897
# [79]	validation_0-logloss:0.06863	validation_1-logloss:0.05885
# [80]	validation_0-logloss:0.06863	validation_1-logloss:0.05883
# [81]	validation_0-logloss:0.06863	validation_1-logloss:0.05870
# [82]	validation_0-logloss:0.06860	validation_1-logloss:0.05862
# [83]	validation_0-logloss:0.06861	validation_1-logloss:0.05851
# [84]	validation_0-logloss:0.06857	validation_1-logloss:0.05841
# [85]	validation_0-logloss:0.06847	validation_1-logloss:0.05816
# [86]	validation_0-logloss:0.06846	validation_1-logloss:0.05809
# [87]	validation_0-logloss:0.06844	validation_1-logloss:0.05804
# [88]	validation_0-logloss:0.06843	validation_1-logloss:0.05800
# [89]	validation_0-logloss:0.06845	validation_1-logloss:0.05794
# [90]	validation_0-logloss:0.06844	validation_1-logloss:0.05789
# [91]	validation_0-logloss:0.06842	validation_1-logloss:0.05783
# [92]	validation_0-logloss:0.06843	validation_1-logloss:0.05779
# [93]	validation_0-logloss:0.06843	validation_1-logloss:0.05774
# [94]	validation_0-logloss:0.06839	validation_1-logloss:0.05760
# [95]	validation_0-logloss:0.06838	validation_1-logloss:0.05757
# [96]	validation_0-logloss:0.06840	validation_1-logloss:0.05754
# [97]	validation_0-logloss:0.06835	validation_1-logloss:0.05732
# [98]	validation_0-logloss:0.06828	validation_1-logloss:0.05710
# [99]	validation_0-logloss:0.06823	validation_1-logloss:0.05705
# /tmp/ipykernel_12706/3160611095.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)
# /tmp/ipykernel_12706/2430262989.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[categorical_features] = enc.fit_transform(data[categorical_features])
# [0]	validation_0-logloss:0.60457	validation_1-logloss:0.60449
# [1]	validation_0-logloss:0.53208	validation_1-logloss:0.53190
# [2]	validation_0-logloss:0.47205	validation_1-logloss:0.47144
# [3]	validation_0-logloss:0.42112	validation_1-logloss:0.42045
# [4]	validation_0-logloss:0.37776	validation_1-logloss:0.37701
# [5]	validation_0-logloss:0.34055	validation_1-logloss:0.33972
# [6]	validation_0-logloss:0.30861	validation_1-logloss:0.30748
# [7]	validation_0-logloss:0.28069	validation_1-logloss:0.27949
# [8]	validation_0-logloss:0.25632	validation_1-logloss:0.25505
# [9]	validation_0-logloss:0.23501	validation_1-logloss:0.23365
# [10]	validation_0-logloss:0.21633	validation_1-logloss:0.21487
# [11]	validation_0-logloss:0.19996	validation_1-logloss:0.19834
# [12]	validation_0-logloss:0.18550	validation_1-logloss:0.18373
# [13]	validation_0-logloss:0.17272	validation_1-logloss:0.17081
# [14]	validation_0-logloss:0.16141	validation_1-logloss:0.15933
# [15]	validation_0-logloss:0.15141	validation_1-logloss:0.14908
# [16]	validation_0-logloss:0.14252	validation_1-logloss:0.14001
# [17]	validation_0-logloss:0.13462	validation_1-logloss:0.13198
# [18]	validation_0-logloss:0.12766	validation_1-logloss:0.12488
# [19]	validation_0-logloss:0.12145	validation_1-logloss:0.11853
# [20]	validation_0-logloss:0.11599	validation_1-logloss:0.11285
# [21]	validation_0-logloss:0.11118	validation_1-logloss:0.10779
# [22]	validation_0-logloss:0.10692	validation_1-logloss:0.10329
# [23]	validation_0-logloss:0.10310	validation_1-logloss:0.09924
# [24]	validation_0-logloss:0.09979	validation_1-logloss:0.09564
# [25]	validation_0-logloss:0.09674	validation_1-logloss:0.09244
# [26]	validation_0-logloss:0.09405	validation_1-logloss:0.08962
# [27]	validation_0-logloss:0.09166	validation_1-logloss:0.08704
# [28]	validation_0-logloss:0.08963	validation_1-logloss:0.08477
# [29]	validation_0-logloss:0.08769	validation_1-logloss:0.08273
# [30]	validation_0-logloss:0.08594	validation_1-logloss:0.08086
# [31]	validation_0-logloss:0.08441	validation_1-logloss:0.07924
# [32]	validation_0-logloss:0.08310	validation_1-logloss:0.07777
# [33]	validation_0-logloss:0.08188	validation_1-logloss:0.07640
# [34]	validation_0-logloss:0.08086	validation_1-logloss:0.07516
# [35]	validation_0-logloss:0.07979	validation_1-logloss:0.07405
# [36]	validation_0-logloss:0.07899	validation_1-logloss:0.07307
# [37]	validation_0-logloss:0.07823	validation_1-logloss:0.07220
# [38]	validation_0-logloss:0.07754	validation_1-logloss:0.07133
# [39]	validation_0-logloss:0.07694	validation_1-logloss:0.07058
# [40]	validation_0-logloss:0.07645	validation_1-logloss:0.06992
# [41]	validation_0-logloss:0.07597	validation_1-logloss:0.06935
# [42]	validation_0-logloss:0.07562	validation_1-logloss:0.06878
# [43]	validation_0-logloss:0.07526	validation_1-logloss:0.06833
# [44]	validation_0-logloss:0.07495	validation_1-logloss:0.06777
# [45]	validation_0-logloss:0.07472	validation_1-logloss:0.06731
# [46]	validation_0-logloss:0.07446	validation_1-logloss:0.06690
# [47]	validation_0-logloss:0.07442	validation_1-logloss:0.06651
# [48]	validation_0-logloss:0.07419	validation_1-logloss:0.06619
# [49]	validation_0-logloss:0.07395	validation_1-logloss:0.06586
# [50]	validation_0-logloss:0.07373	validation_1-logloss:0.06558
# [51]	validation_0-logloss:0.07353	validation_1-logloss:0.06530
# [52]	validation_0-logloss:0.07343	validation_1-logloss:0.06510
# [53]	validation_0-logloss:0.07340	validation_1-logloss:0.06490
# [54]	validation_0-logloss:0.07331	validation_1-logloss:0.06470
# [55]	validation_0-logloss:0.07321	validation_1-logloss:0.06452
# [56]	validation_0-logloss:0.07326	validation_1-logloss:0.06429
# [57]	validation_0-logloss:0.07318	validation_1-logloss:0.06417
# [58]	validation_0-logloss:0.07331	validation_1-logloss:0.06404
# [59]	validation_0-logloss:0.07324	validation_1-logloss:0.06394
# [60]	validation_0-logloss:0.07321	validation_1-logloss:0.06382
# [61]	validation_0-logloss:0.07320	validation_1-logloss:0.06366
# [62]	validation_0-logloss:0.07335	validation_1-logloss:0.06356
# [63]	validation_0-logloss:0.07348	validation_1-logloss:0.06342
# [64]	validation_0-logloss:0.07345	validation_1-logloss:0.06331
# [65]	validation_0-logloss:0.07343	validation_1-logloss:0.06324
# [66]	validation_0-logloss:0.07339	validation_1-logloss:0.06299
# [67]	validation_0-logloss:0.07340	validation_1-logloss:0.06294
# [68]	validation_0-logloss:0.07341	validation_1-logloss:0.06288
# [69]	validation_0-logloss:0.07340	validation_1-logloss:0.06279
# [70]	validation_0-logloss:0.07336	validation_1-logloss:0.06265
# [71]	validation_0-logloss:0.07339	validation_1-logloss:0.06254
# [72]	validation_0-logloss:0.07336	validation_1-logloss:0.06250
# [73]	validation_0-logloss:0.07334	validation_1-logloss:0.06246
# [74]	validation_0-logloss:0.07330	validation_1-logloss:0.06228
# [75]	validation_0-logloss:0.07327	validation_1-logloss:0.06225
# [76]	validation_0-logloss:0.07327	validation_1-logloss:0.06215
# [77]	validation_0-logloss:0.07335	validation_1-logloss:0.06201
# [78]	validation_0-logloss:0.07344	validation_1-logloss:0.06182
# [79]	validation_0-logloss:0.07342	validation_1-logloss:0.06165
# [80]	validation_0-logloss:0.07341	validation_1-logloss:0.06162
# [81]	validation_0-logloss:0.07338	validation_1-logloss:0.06154
# [82]	validation_0-logloss:0.07338	validation_1-logloss:0.06141
# [83]	validation_0-logloss:0.07336	validation_1-logloss:0.06137
# [84]	validation_0-logloss:0.07335	validation_1-logloss:0.06133
# [85]	validation_0-logloss:0.07337	validation_1-logloss:0.06129
# [86]	validation_0-logloss:0.07335	validation_1-logloss:0.06124
# [87]	validation_0-logloss:0.07336	validation_1-logloss:0.06116
# [88]	validation_0-logloss:0.07336	validation_1-logloss:0.06111
# [89]	validation_0-logloss:0.07369	validation_1-logloss:0.06094
# [90]	validation_0-logloss:0.07371	validation_1-logloss:0.06091
# [91]	validation_0-logloss:0.07361	validation_1-logloss:0.06083
# [92]	validation_0-logloss:0.07362	validation_1-logloss:0.06080
# [93]	validation_0-logloss:0.07372	validation_1-logloss:0.06067
# [94]	validation_0-logloss:0.07369	validation_1-logloss:0.06051
# [95]	validation_0-logloss:0.07361	validation_1-logloss:0.06036
# [96]	validation_0-logloss:0.07360	validation_1-logloss:0.06033
# [97]	validation_0-logloss:0.07359	validation_1-logloss:0.06022
# [98]	validation_0-logloss:0.07356	validation_1-logloss:0.06019
# [99]	validation_0-logloss:0.07359	validation_1-logloss:0.06006
# /tmp/ipykernel_12706/3160611095.py:19: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp / (tp + fp)

# %%
results = (
    pd.DataFrame()
    .from_dict(results, orient="index", columns=RESULT_COLS)
    .assign(classifier="XGBoost")
)
results_resample = (
    pd.DataFrame()
    .from_dict(results_resample, orient="index", columns=RESULT_COLS)
    .assign(classifier="XGBoost")
)

# %%
results.to_csv(Path().resolve().joinpath("results/XGBoost_eval.csv"))
results_resample.to_csv(Path().resolve().joinpath("results/XGBoost_eval_resampled.csv"))
