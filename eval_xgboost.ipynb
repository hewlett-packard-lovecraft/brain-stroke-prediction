# %%
import pandas as pd
import random
import sklearn

from pathlib import Path
import xgboost as xgb
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_absolute_error

from imblearn.combine import SMOTEENN

# %%
CATEGORICAL_FEATURE_NAMES = [
    "gender",
    "hypertension",
    "heart_disease",
    "ever_married",
    "work_type",
    "residence_type",
    "smoking_status",
]


def encode_int(data: pd.DataFrame, categorical_features: list[str]):
    return pd.get_dummies(data, columns=categorical_features, drop_first=True)


def split_label(data: pd.DataFrame):
    x = data.copy().drop("stroke", axis=1)
    y = data["stroke"]  # labels

    return x, y


def resample(data: pd.DataFrame, seed: int):
    """oversample positive cases with SMOTE and undersample negative with EEN"""
    X = data.drop(columns=["stroke"], axis=1)
    Y = data["stroke"]

    smote_een = SMOTEENN(random_state=seed, sampling_strategy="auto")

    x_resampled, y_resampled = smote_een.fit_resample(X, Y)
    x_resampled["stroke"] = y_resampled

    return pd.DataFrame(x_resampled, columns=data.columns)


def split_train_valid_test(data_df, seed: int):
    data_df = data_df.sample(frac=1, random_state=seed)

    test_set = data_df[4500:]
    train_validation_data = data_df[:4500].sample(frac=1, random_state=seed)

    train_set = resample(train_validation_data[:4000], seed)
    validation_set = train_validation_data[4000:]

    return train_set, validation_set, test_set


def prepare_data(seed: int):
    data_df = pd.read_csv(Path().resolve().joinpath("dataset/full_data_clean.csv"))
    data_df = encode_int(data=data_df, categorical_features=CATEGORICAL_FEATURE_NAMES)

    train_df, validation_df, test_df = split_train_valid_test(data_df, seed)

    return train_df, validation_df, test_df

# %%
RESULT_COLS = [
    "precision",
    "recall",
    "fscore",
    "accuracy",
    "auc",
    "miss_rate",
    "fall_out_rate",
]
NUM_EXPERIMENTS = 100
NUM_ROUNDS=50

def metrics(y_pred, y_true):
    tn, fp, fn, tp = confusion_matrix(y_pred=y_pred, y_true=y_true).ravel()

    # metrics
    auc = roc_auc_score(y_true=y_true, y_score=y_pred)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    fscore = 2 * tp / (2 * tp + fp + fn)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    miss_rate = fn / (tn + tp)
    fall_out_rate = fp / (fp + tn)

    # return
    return [precision, recall, fscore, accuracy, auc, miss_rate, fall_out_rate]

# %%
# evaluate xgboost
from xgboost.callback import EarlyStopping

results = {}

for experiment in range(NUM_EXPERIMENTS):
    seed = random.randint(0, 1000)

    train_data, validation_data, test_data = prepare_data(seed=experiment)

    # split labels
    x, y = split_label(train_data)
    x_valid, y_valid = split_label(validation_data)
    x_test, y_test = split_label(test_data)

    # metrics
    param = {"max_depth": 2, "eta": 1, "objective": "binary:logistic"}
    
    es = EarlyStopping(
        rounds=5,
        save_best=True,
        maximize=True,
        data_name="validation_0",
        metric_name="auc",
    )
    
    clf = xgb.sklearn.XGBClassifier(
        max_depth=param["max_depth"],
        eta=param['eta'],
        objective=param["objective"],
        gpu_id=0,
        predictor='gpu_predictor',
        eval_metric='auc',
        early_stopping_rounds=5,
        callbacks=[es]
    )

    clf.fit(
        x, y,
        eval_set=[(x_test, y_test), (x, y)]
    )

    y_pred = clf.predict(x_test)

    results[experiment] = list(metrics(y_pred, y_test))

results = pd.DataFrame().from_dict(results, orient="index", columns=RESULT_COLS)

results.to_csv(Path().resolve().joinpath("results/XGBoost.csv"))

results
# Out:
# [0]	validation_0-auc:0.77240	validation_1-auc:0.91073
# [1]	validation_0-auc:0.76537	validation_1-auc:0.92068
# [2]	validation_0-auc:0.77566	validation_1-auc:0.94110
# [3]	validation_0-auc:0.76160	validation_1-auc:0.94976
# [4]	validation_0-auc:0.76799	validation_1-auc:0.95507
# [5]	validation_0-auc:0.77919	validation_1-auc:0.95884
# [6]	validation_0-auc:0.77617	validation_1-auc:0.96287
# [7]	validation_0-auc:0.76656	validation_1-auc:0.96599
# [8]	validation_0-auc:0.76233	validation_1-auc:0.96849
# [9]	validation_0-auc:0.76969	validation_1-auc:0.97014
# [10]	validation_0-auc:0.77134	validation_1-auc:0.97186
# [0]	validation_0-auc:0.80009	validation_1-auc:0.90378
# [1]	validation_0-auc:0.76958	validation_1-auc:0.93550
# [2]	validation_0-auc:0.75825	validation_1-auc:0.94391
# [3]	validation_0-auc:0.76478	validation_1-auc:0.95523
# [4]	validation_0-auc:0.77066	validation_1-auc:0.96118
# [0]	validation_0-auc:0.75532	validation_1-auc:0.91769
# [1]	validation_0-auc:0.73687	validation_1-auc:0.93720
# [2]	validation_0-auc:0.71870	validation_1-auc:0.94956
# [3]	validation_0-auc:0.73100	validation_1-auc:0.95918
# [4]	validation_0-auc:0.75177	validation_1-auc:0.96491
# [5]	validation_0-auc:0.76218	validation_1-auc:0.96883
# [6]	validation_0-auc:0.76561	validation_1-auc:0.97143
# [7]	validation_0-auc:0.76632	validation_1-auc:0.97309
# [8]	validation_0-auc:0.75777	validation_1-auc:0.97447
# [9]	validation_0-auc:0.75946	validation_1-auc:0.97516
# [10]	validation_0-auc:0.75331	validation_1-auc:0.97627
# [11]	validation_0-auc:0.75402	validation_1-auc:0.97765
# [12]	validation_0-auc:0.75670	validation_1-auc:0.97833
# [0]	validation_0-auc:0.84035	validation_1-auc:0.90577
# [1]	validation_0-auc:0.84151	validation_1-auc:0.92773
# [2]	validation_0-auc:0.86683	validation_1-auc:0.94215
# [3]	validation_0-auc:0.86487	validation_1-auc:0.95280
# [4]	validation_0-auc:0.84817	validation_1-auc:0.96098
# [5]	validation_0-auc:0.84471	validation_1-auc:0.96483
# [6]	validation_0-auc:0.85110	validation_1-auc:0.96625
# [0]	validation_0-auc:0.85794	validation_1-auc:0.89373
# [1]	validation_0-auc:0.84939	validation_1-auc:0.92022
# [2]	validation_0-auc:0.86415	validation_1-auc:0.93274
# [3]	validation_0-auc:0.83064	validation_1-auc:0.94428
# [4]	validation_0-auc:0.82974	validation_1-auc:0.94834
# [5]	validation_0-auc:0.76680	validation_1-auc:0.95261
# [6]	validation_0-auc:0.77905	validation_1-auc:0.95621
# [7]	validation_0-auc:0.75854	validation_1-auc:0.96067
# [0]	validation_0-auc:0.78205	validation_1-auc:0.91305
# [1]	validation_0-auc:0.75483	validation_1-auc:0.92974
# [2]	validation_0-auc:0.74672	validation_1-auc:0.94313
# [3]	validation_0-auc:0.72894	validation_1-auc:0.95177
# [4]	validation_0-auc:0.72625	validation_1-auc:0.95807
# [0]	validation_0-auc:0.80824	validation_1-auc:0.91605
# [1]	validation_0-auc:0.80347	validation_1-auc:0.92437
# [2]	validation_0-auc:0.77625	validation_1-auc:0.93617
# [3]	validation_0-auc:0.76361	validation_1-auc:0.94786
# [4]	validation_0-auc:0.75448	validation_1-auc:0.95449
# [5]	validation_0-auc:0.79869	validation_1-auc:0.96069
# [0]	validation_0-auc:0.82164	validation_1-auc:0.89741
# [1]	validation_0-auc:0.81607	validation_1-auc:0.92255
# [2]	validation_0-auc:0.82396	validation_1-auc:0.93442
# [3]	validation_0-auc:0.81916	validation_1-auc:0.94781
# [4]	validation_0-auc:0.78425	validation_1-auc:0.95621
# [5]	validation_0-auc:0.78181	validation_1-auc:0.95966
# [6]	validation_0-auc:0.77388	validation_1-auc:0.96343
# [7]	validation_0-auc:0.79280	validation_1-auc:0.96607
# [0]	validation_0-auc:0.81384	validation_1-auc:0.89400
# [1]	validation_0-auc:0.80164	validation_1-auc:0.92450
# [2]	validation_0-auc:0.79858	validation_1-auc:0.93800
# [3]	validation_0-auc:0.80923	validation_1-auc:0.94633
# [4]	validation_0-auc:0.79646	validation_1-auc:0.95745
# [5]	validation_0-auc:0.79838	validation_1-auc:0.96302
# [0]	validation_0-auc:0.80482	validation_1-auc:0.90467
# [1]	validation_0-auc:0.77930	validation_1-auc:0.91647
# [2]	validation_0-auc:0.78776	validation_1-auc:0.94139
# [3]	validation_0-auc:0.76096	validation_1-auc:0.94755
# [4]	validation_0-auc:0.78096	validation_1-auc:0.95249
# [5]	validation_0-auc:0.78759	validation_1-auc:0.95991
# [0]	validation_0-auc:0.83373	validation_1-auc:0.90523
# [1]	validation_0-auc:0.85014	validation_1-auc:0.92373
# [2]	validation_0-auc:0.83874	validation_1-auc:0.93735
# [3]	validation_0-auc:0.82832	validation_1-auc:0.95051
# [4]	validation_0-auc:0.82758	validation_1-auc:0.95742
# [5]	validation_0-auc:0.85082	validation_1-auc:0.96048
# [6]	validation_0-auc:0.85709	validation_1-auc:0.96339
# [7]	validation_0-auc:0.85720	validation_1-auc:0.96624
# [8]	validation_0-auc:0.86056	validation_1-auc:0.96980
# [9]	validation_0-auc:0.86056	validation_1-auc:0.97106
# [10]	validation_0-auc:0.84928	validation_1-auc:0.97244
# [11]	validation_0-auc:0.83669	validation_1-auc:0.97401
# [12]	validation_0-auc:0.83396	validation_1-auc:0.97584
# [0]	validation_0-auc:0.77025	validation_1-auc:0.91446
# [1]	validation_0-auc:0.75322	validation_1-auc:0.93816
# [2]	validation_0-auc:0.76273	validation_1-auc:0.94805
# [3]	validation_0-auc:0.77629	validation_1-auc:0.96099
# [4]	validation_0-auc:0.76084	validation_1-auc:0.96559
# [5]	validation_0-auc:0.76233	validation_1-auc:0.96875
# [6]	validation_0-auc:0.76936	validation_1-auc:0.97144
# [7]	validation_0-auc:0.76792	validation_1-auc:0.97269
# [8]	validation_0-auc:0.75678	validation_1-auc:0.97382
# [0]	validation_0-auc:0.80250	validation_1-auc:0.90140
# [1]	validation_0-auc:0.82232	validation_1-auc:0.92244
# [2]	validation_0-auc:0.77068	validation_1-auc:0.94080
# [3]	validation_0-auc:0.78679	validation_1-auc:0.95118
# [4]	validation_0-auc:0.76632	validation_1-auc:0.95850
# [5]	validation_0-auc:0.78027	validation_1-auc:0.96268
# [0]	validation_0-auc:0.80355	validation_1-auc:0.90803
# [1]	validation_0-auc:0.77798	validation_1-auc:0.93546
# [2]	validation_0-auc:0.78386	validation_1-auc:0.94817
# [3]	validation_0-auc:0.79925	validation_1-auc:0.95508
# [4]	validation_0-auc:0.80083	validation_1-auc:0.96509
# [5]	validation_0-auc:0.79711	validation_1-auc:0.96912
# [0]	validation_0-auc:0.82838	validation_1-auc:0.90170
# [1]	validation_0-auc:0.83789	validation_1-auc:0.92520
# [2]	validation_0-auc:0.84433	validation_1-auc:0.93740
# [3]	validation_0-auc:0.82206	validation_1-auc:0.94866
# [4]	validation_0-auc:0.82889	validation_1-auc:0.95311
# [5]	validation_0-auc:0.85150	validation_1-auc:0.95846
# [6]	validation_0-auc:0.86187	validation_1-auc:0.96244
# [7]	validation_0-auc:0.85760	validation_1-auc:0.96364
# [8]	validation_0-auc:0.86033	validation_1-auc:0.96478
# [9]	validation_0-auc:0.86734	validation_1-auc:0.96618
# [10]	validation_0-auc:0.86751	validation_1-auc:0.96762
# [11]	validation_0-auc:0.87161	validation_1-auc:0.96977
# [12]	validation_0-auc:0.86552	validation_1-auc:0.97139
# [13]	validation_0-auc:0.86779	validation_1-auc:0.97273
# [14]	validation_0-auc:0.86916	validation_1-auc:0.97382
# [15]	validation_0-auc:0.87133	validation_1-auc:0.97429
# [16]	validation_0-auc:0.86517	validation_1-auc:0.97544
# [0]	validation_0-auc:0.81659	validation_1-auc:0.90078
# [1]	validation_0-auc:0.83180	validation_1-auc:0.92449
# [2]	validation_0-auc:0.81494	validation_1-auc:0.93710
# [3]	validation_0-auc:0.80098	validation_1-auc:0.94787
# [4]	validation_0-auc:0.79836	validation_1-auc:0.95254
# [5]	validation_0-auc:0.81385	validation_1-auc:0.95635
# [6]	validation_0-auc:0.82131	validation_1-auc:0.95936
# [0]	validation_0-auc:0.77980	validation_1-auc:0.90739
# [1]	validation_0-auc:0.76492	validation_1-auc:0.93210
# [2]	validation_0-auc:0.78652	validation_1-auc:0.94366
# [3]	validation_0-auc:0.77481	validation_1-auc:0.95614
# [4]	validation_0-auc:0.77223	validation_1-auc:0.96115
# [5]	validation_0-auc:0.78221	validation_1-auc:0.96467
# [6]	validation_0-auc:0.79535	validation_1-auc:0.96774
# [7]	validation_0-auc:0.80368	validation_1-auc:0.97048
# [8]	validation_0-auc:0.79066	validation_1-auc:0.97267
# [9]	validation_0-auc:0.77853	validation_1-auc:0.97362
# [10]	validation_0-auc:0.78166	validation_1-auc:0.97430
# [11]	validation_0-auc:0.79544	validation_1-auc:0.97583
# [12]	validation_0-auc:0.79653	validation_1-auc:0.97734
# [0]	validation_0-auc:0.68448	validation_1-auc:0.91541
# [1]	validation_0-auc:0.73495	validation_1-auc:0.92778
# [2]	validation_0-auc:0.71384	validation_1-auc:0.94130
# [3]	validation_0-auc:0.72870	validation_1-auc:0.95142
# [4]	validation_0-auc:0.70524	validation_1-auc:0.95925
# [5]	validation_0-auc:0.69987	validation_1-auc:0.96641
# [6]	validation_0-auc:0.70215	validation_1-auc:0.96876
# [0]	validation_0-auc:0.84051	validation_1-auc:0.90043
# [1]	validation_0-auc:0.81323	validation_1-auc:0.92491
# [2]	validation_0-auc:0.79449	validation_1-auc:0.93319
# [3]	validation_0-auc:0.74692	validation_1-auc:0.94953
# [4]	validation_0-auc:0.74527	validation_1-auc:0.95566
# [5]	validation_0-auc:0.78663	validation_1-auc:0.96004
# [0]	validation_0-auc:0.76500	validation_1-auc:0.91959
# [1]	validation_0-auc:0.74520	validation_1-auc:0.93206
# [2]	validation_0-auc:0.78248	validation_1-auc:0.94048
# [3]	validation_0-auc:0.77748	validation_1-auc:0.95435
# [4]	validation_0-auc:0.77956	validation_1-auc:0.96300
# [5]	validation_0-auc:0.77941	validation_1-auc:0.96911
# [6]	validation_0-auc:0.76738	validation_1-auc:0.97200
# [7]	validation_0-auc:0.76015	validation_1-auc:0.97376
# [0]	validation_0-auc:0.82777	validation_1-auc:0.90136
# [1]	validation_0-auc:0.78342	validation_1-auc:0.92741
# [2]	validation_0-auc:0.78109	validation_1-auc:0.94534
# [3]	validation_0-auc:0.78720	validation_1-auc:0.95567
# [4]	validation_0-auc:0.79732	validation_1-auc:0.95983
# [0]	validation_0-auc:0.82421	validation_1-auc:0.90228
# [1]	validation_0-auc:0.83452	validation_1-auc:0.92940
# [2]	validation_0-auc:0.84149	validation_1-auc:0.94005
# [3]	validation_0-auc:0.82939	validation_1-auc:0.95311
# [4]	validation_0-auc:0.84180	validation_1-auc:0.95783
# [5]	validation_0-auc:0.83860	validation_1-auc:0.96365
# [6]	validation_0-auc:0.82873	validation_1-auc:0.96771
# [7]	validation_0-auc:0.82325	validation_1-auc:0.97147
# [8]	validation_0-auc:0.82711	validation_1-auc:0.97469
# [9]	validation_0-auc:0.83123	validation_1-auc:0.97534
# [0]	validation_0-auc:0.83739	validation_1-auc:0.90590
# [1]	validation_0-auc:0.79971	validation_1-auc:0.91843
# [2]	validation_0-auc:0.80211	validation_1-auc:0.94166
# [3]	validation_0-auc:0.79238	validation_1-auc:0.95398
# [4]	validation_0-auc:0.78733	validation_1-auc:0.95972
# [0]	validation_0-auc:0.79336	validation_1-auc:0.90214
# [1]	validation_0-auc:0.80822	validation_1-auc:0.92479
# [2]	validation_0-auc:0.80795	validation_1-auc:0.93705
# [3]	validation_0-auc:0.79277	validation_1-auc:0.94790
# [4]	validation_0-auc:0.78989	validation_1-auc:0.95490
# [5]	validation_0-auc:0.77614	validation_1-auc:0.95991
# [6]	validation_0-auc:0.79084	validation_1-auc:0.96351
# [0]	validation_0-auc:0.81775	validation_1-auc:0.90896
# [1]	validation_0-auc:0.80862	validation_1-auc:0.92452
# [2]	validation_0-auc:0.79336	validation_1-auc:0.94372
# [3]	validation_0-auc:0.80516	validation_1-auc:0.95374
# [4]	validation_0-auc:0.80647	validation_1-auc:0.96025
# [0]	validation_0-auc:0.79547	validation_1-auc:0.90467
# [1]	validation_0-auc:0.77540	validation_1-auc:0.92933
# [2]	validation_0-auc:0.77122	validation_1-auc:0.94577
# [3]	validation_0-auc:0.77053	validation_1-auc:0.95967
# [4]	validation_0-auc:0.76665	validation_1-auc:0.96487
# [0]	validation_0-auc:0.81920	validation_1-auc:0.90306
# [1]	validation_0-auc:0.77497	validation_1-auc:0.92264
# [2]	validation_0-auc:0.75593	validation_1-auc:0.93735
# [3]	validation_0-auc:0.77772	validation_1-auc:0.94841
# [4]	validation_0-auc:0.75721	validation_1-auc:0.95362
# [5]	validation_0-auc:0.75038	validation_1-auc:0.95916
# [0]	validation_0-auc:0.82549	validation_1-auc:0.90213
# [1]	validation_0-auc:0.77773	validation_1-auc:0.92960
# [2]	validation_0-auc:0.76809	validation_1-auc:0.94019
# [3]	validation_0-auc:0.79565	validation_1-auc:0.95070
# [4]	validation_0-auc:0.81669	validation_1-auc:0.95664
# [5]	validation_0-auc:0.81023	validation_1-auc:0.96115
# [0]	validation_0-auc:0.68987	validation_1-auc:0.92197
# [1]	validation_0-auc:0.70727	validation_1-auc:0.93488
# [2]	validation_0-auc:0.65789	validation_1-auc:0.95233
# [3]	validation_0-auc:0.63593	validation_1-auc:0.96246
# [4]	validation_0-auc:0.66937	validation_1-auc:0.96805
# [5]	validation_0-auc:0.67445	validation_1-auc:0.97301
# [6]	validation_0-auc:0.69561	validation_1-auc:0.97497
# [0]	validation_0-auc:0.85549	validation_1-auc:0.90073
# [1]	validation_0-auc:0.83853	validation_1-auc:0.92156
# [2]	validation_0-auc:0.84833	validation_1-auc:0.93841
# [3]	validation_0-auc:0.85417	validation_1-auc:0.94841
# [4]	validation_0-auc:0.82914	validation_1-auc:0.95450
# [5]	validation_0-auc:0.82704	validation_1-auc:0.96065
# [0]	validation_0-auc:0.81389	validation_1-auc:0.89996
# [1]	validation_0-auc:0.85247	validation_1-auc:0.92366
# [2]	validation_0-auc:0.84083	validation_1-auc:0.94126
# [3]	validation_0-auc:0.83399	validation_1-auc:0.95051
# [4]	validation_0-auc:0.82007	validation_1-auc:0.96018
# [5]	validation_0-auc:0.82769	validation_1-auc:0.96368
# [6]	validation_0-auc:0.84125	validation_1-auc:0.96610
# [0]	validation_0-auc:0.81258	validation_1-auc:0.89835
# [1]	validation_0-auc:0.82143	validation_1-auc:0.92114
# [2]	validation_0-auc:0.81755	validation_1-auc:0.94022
# [3]	validation_0-auc:0.76661	validation_1-auc:0.94885
# [4]	validation_0-auc:0.76444	validation_1-auc:0.95394
# [5]	validation_0-auc:0.77919	validation_1-auc:0.95796
# [0]	validation_0-auc:0.77684	validation_1-auc:0.91271
# [1]	validation_0-auc:0.77393	validation_1-auc:0.92669
# [2]	validation_0-auc:0.76829	validation_1-auc:0.93925
# [3]	validation_0-auc:0.75682	validation_1-auc:0.95724
# [4]	validation_0-auc:0.76095	validation_1-auc:0.96227
# [5]	validation_0-auc:0.77598	validation_1-auc:0.96708
# [0]	validation_0-auc:0.80840	validation_1-auc:0.90270
# [1]	validation_0-auc:0.79244	validation_1-auc:0.93292
# [2]	validation_0-auc:0.78469	validation_1-auc:0.94320
# [3]	validation_0-auc:0.78259	validation_1-auc:0.95364
# [4]	validation_0-auc:0.79964	validation_1-auc:0.95806
# [5]	validation_0-auc:0.78811	validation_1-auc:0.96278
# [0]	validation_0-auc:0.81313	validation_1-auc:0.91261
# [1]	validation_0-auc:0.79585	validation_1-auc:0.92365
# [2]	validation_0-auc:0.79557	validation_1-auc:0.94322
# [3]	validation_0-auc:0.77606	validation_1-auc:0.95121
# [4]	validation_0-auc:0.81512	validation_1-auc:0.95638
# [5]	validation_0-auc:0.80848	validation_1-auc:0.95928
# [6]	validation_0-auc:0.80881	validation_1-auc:0.96198
# [7]	validation_0-auc:0.81194	validation_1-auc:0.96337
# [8]	validation_0-auc:0.78285	validation_1-auc:0.96594
# [9]	validation_0-auc:0.78261	validation_1-auc:0.96712
# [0]	validation_0-auc:0.84949	validation_1-auc:0.89697
# [1]	validation_0-auc:0.84897	validation_1-auc:0.91998
# [2]	validation_0-auc:0.85064	validation_1-auc:0.93221
# [3]	validation_0-auc:0.85729	validation_1-auc:0.95032
# [4]	validation_0-auc:0.86268	validation_1-auc:0.95638
# [5]	validation_0-auc:0.85701	validation_1-auc:0.96013
# [6]	validation_0-auc:0.86640	validation_1-auc:0.96320
# [7]	validation_0-auc:0.84866	validation_1-auc:0.96553
# [8]	validation_0-auc:0.85186	validation_1-auc:0.96660
# [9]	validation_0-auc:0.85663	validation_1-auc:0.96899
# [10]	validation_0-auc:0.85123	validation_1-auc:0.97055
# [11]	validation_0-auc:0.84302	validation_1-auc:0.97153
# [0]	validation_0-auc:0.82868	validation_1-auc:0.90527
# [1]	validation_0-auc:0.84497	validation_1-auc:0.93581
# [2]	validation_0-auc:0.83670	validation_1-auc:0.94263
# [3]	validation_0-auc:0.83521	validation_1-auc:0.95676
# [4]	validation_0-auc:0.83111	validation_1-auc:0.96205
# [5]	validation_0-auc:0.84170	validation_1-auc:0.96537
# [6]	validation_0-auc:0.83923	validation_1-auc:0.96763
# [0]	validation_0-auc:0.84606	validation_1-auc:0.91398
# [1]	validation_0-auc:0.84235	validation_1-auc:0.92739
# [2]	validation_0-auc:0.83170	validation_1-auc:0.94119
# [3]	validation_0-auc:0.84667	validation_1-auc:0.95153
# [4]	validation_0-auc:0.83003	validation_1-auc:0.95696
# [5]	validation_0-auc:0.83460	validation_1-auc:0.96463
# [6]	validation_0-auc:0.82587	validation_1-auc:0.96703
# [7]	validation_0-auc:0.82999	validation_1-auc:0.97021
# [8]	validation_0-auc:0.83872	validation_1-auc:0.97203
# [0]	validation_0-auc:0.83056	validation_1-auc:0.90372
# [1]	validation_0-auc:0.84471	validation_1-auc:0.92636
# [2]	validation_0-auc:0.81930	validation_1-auc:0.94826
# [3]	validation_0-auc:0.80184	validation_1-auc:0.95800
# [4]	validation_0-auc:0.81669	validation_1-auc:0.96286
# [5]	validation_0-auc:0.79250	validation_1-auc:0.96661
# [0]	validation_0-auc:0.83438	validation_1-auc:0.90393
# [1]	validation_0-auc:0.83530	validation_1-auc:0.92578
# [2]	validation_0-auc:0.83216	validation_1-auc:0.94238
# [3]	validation_0-auc:0.82012	validation_1-auc:0.94994
# [4]	validation_0-auc:0.81226	validation_1-auc:0.95716
# [5]	validation_0-auc:0.79159	validation_1-auc:0.96139
# [6]	validation_0-auc:0.79073	validation_1-auc:0.96511
# [0]	validation_0-auc:0.80768	validation_1-auc:0.90178
# [1]	validation_0-auc:0.84798	validation_1-auc:0.92515
# [2]	validation_0-auc:0.85744	validation_1-auc:0.93734
# [3]	validation_0-auc:0.84463	validation_1-auc:0.94421
# [4]	validation_0-auc:0.82709	validation_1-auc:0.95243
# [5]	validation_0-auc:0.83133	validation_1-auc:0.95804
# [6]	validation_0-auc:0.82864	validation_1-auc:0.96008
# [0]	validation_0-auc:0.83471	validation_1-auc:0.91236
# [1]	validation_0-auc:0.85184	validation_1-auc:0.92873
# [2]	validation_0-auc:0.77842	validation_1-auc:0.94107
# [3]	validation_0-auc:0.74973	validation_1-auc:0.95523
# [4]	validation_0-auc:0.78509	validation_1-auc:0.96143
# [5]	validation_0-auc:0.78818	validation_1-auc:0.96474
# [6]	validation_0-auc:0.79658	validation_1-auc:0.96995
# [0]	validation_0-auc:0.80583	validation_1-auc:0.91458
# [1]	validation_0-auc:0.80320	validation_1-auc:0.93358
# [2]	validation_0-auc:0.82342	validation_1-auc:0.94341
# [3]	validation_0-auc:0.82079	validation_1-auc:0.95403
# [4]	validation_0-auc:0.80772	validation_1-auc:0.95919
# [5]	validation_0-auc:0.80491	validation_1-auc:0.96293
# [6]	validation_0-auc:0.80206	validation_1-auc:0.96738
# [7]	validation_0-auc:0.81627	validation_1-auc:0.96937
# [0]	validation_0-auc:0.76842	validation_1-auc:0.90660
# [1]	validation_0-auc:0.75076	validation_1-auc:0.92573
# [2]	validation_0-auc:0.70980	validation_1-auc:0.94604
# [3]	validation_0-auc:0.70249	validation_1-auc:0.95391
# [4]	validation_0-auc:0.73657	validation_1-auc:0.96103
# [5]	validation_0-auc:0.72774	validation_1-auc:0.96407
# [0]	validation_0-auc:0.82583	validation_1-auc:0.90923
# [1]	validation_0-auc:0.81397	validation_1-auc:0.93251
# [2]	validation_0-auc:0.81223	validation_1-auc:0.94430
# [3]	validation_0-auc:0.80155	validation_1-auc:0.95054
# [4]	validation_0-auc:0.80824	validation_1-auc:0.96123
# [5]	validation_0-auc:0.79305	validation_1-auc:0.96424
# [0]	validation_0-auc:0.85800	validation_1-auc:0.91029
# [1]	validation_0-auc:0.85195	validation_1-auc:0.92883
# [2]	validation_0-auc:0.85605	validation_1-auc:0.93988
# [3]	validation_0-auc:0.87493	validation_1-auc:0.94886
# [4]	validation_0-auc:0.86599	validation_1-auc:0.95731
# [5]	validation_0-auc:0.88696	validation_1-auc:0.96084
# [6]	validation_0-auc:0.87897	validation_1-auc:0.96531
# [7]	validation_0-auc:0.88595	validation_1-auc:0.96723
# [8]	validation_0-auc:0.87265	validation_1-auc:0.96825
# [9]	validation_0-auc:0.87345	validation_1-auc:0.96942
# [10]	validation_0-auc:0.86599	validation_1-auc:0.97193
# [0]	validation_0-auc:0.75966	validation_1-auc:0.91832
# [1]	validation_0-auc:0.75962	validation_1-auc:0.93283
# [2]	validation_0-auc:0.74736	validation_1-auc:0.94136
# [3]	validation_0-auc:0.73382	validation_1-auc:0.95322
# [4]	validation_0-auc:0.74480	validation_1-auc:0.95767
# [5]	validation_0-auc:0.72643	validation_1-auc:0.96127
# [0]	validation_0-auc:0.77802	validation_1-auc:0.91211
# [1]	validation_0-auc:0.77722	validation_1-auc:0.92404
# [2]	validation_0-auc:0.77599	validation_1-auc:0.94264
# [3]	validation_0-auc:0.78926	validation_1-auc:0.95058
# [4]	validation_0-auc:0.77143	validation_1-auc:0.95783
# [5]	validation_0-auc:0.78081	validation_1-auc:0.96312
# [6]	validation_0-auc:0.77908	validation_1-auc:0.96546
# [7]	validation_0-auc:0.77342	validation_1-auc:0.96822
# [0]	validation_0-auc:0.75220	validation_1-auc:0.90714
# [1]	validation_0-auc:0.72409	validation_1-auc:0.92078
# [2]	validation_0-auc:0.68250	validation_1-auc:0.94063
# [3]	validation_0-auc:0.71826	validation_1-auc:0.95056
# [4]	validation_0-auc:0.70372	validation_1-auc:0.95865
# [5]	validation_0-auc:0.70642	validation_1-auc:0.96136
# [0]	validation_0-auc:0.87339	validation_1-auc:0.90491
# [1]	validation_0-auc:0.85804	validation_1-auc:0.92963
# [2]	validation_0-auc:0.85992	validation_1-auc:0.94420
# [3]	validation_0-auc:0.85730	validation_1-auc:0.95525
# [4]	validation_0-auc:0.87418	validation_1-auc:0.95932
# [5]	validation_0-auc:0.87527	validation_1-auc:0.96263
# [6]	validation_0-auc:0.86918	validation_1-auc:0.96553
# [7]	validation_0-auc:0.86884	validation_1-auc:0.96909
# [8]	validation_0-auc:0.86745	validation_1-auc:0.97050
# [9]	validation_0-auc:0.86121	validation_1-auc:0.97169
# [0]	validation_0-auc:0.87502	validation_1-auc:0.90520
# [1]	validation_0-auc:0.86858	validation_1-auc:0.92100
# [2]	validation_0-auc:0.85944	validation_1-auc:0.94365
# [3]	validation_0-auc:0.80857	validation_1-auc:0.95009
# [4]	validation_0-auc:0.81755	validation_1-auc:0.95679
# [5]	validation_0-auc:0.80698	validation_1-auc:0.96254
# [0]	validation_0-auc:0.83627	validation_1-auc:0.90956
# [1]	validation_0-auc:0.83782	validation_1-auc:0.92228
# [2]	validation_0-auc:0.77248	validation_1-auc:0.93889
# [3]	validation_0-auc:0.78112	validation_1-auc:0.94880
# [4]	validation_0-auc:0.80348	validation_1-auc:0.95609
# [5]	validation_0-auc:0.80229	validation_1-auc:0.96121
# [0]	validation_0-auc:0.82492	validation_1-auc:0.90276
# [1]	validation_0-auc:0.81996	validation_1-auc:0.92117
# [2]	validation_0-auc:0.82591	validation_1-auc:0.93507
# [3]	validation_0-auc:0.79595	validation_1-auc:0.95248
# [4]	validation_0-auc:0.80273	validation_1-auc:0.95818
# [5]	validation_0-auc:0.80402	validation_1-auc:0.96247
# [6]	validation_0-auc:0.80184	validation_1-auc:0.96390
# [7]	validation_0-auc:0.80026	validation_1-auc:0.96628
# [0]	validation_0-auc:0.80849	validation_1-auc:0.90798
# [1]	validation_0-auc:0.81879	validation_1-auc:0.91771
# [2]	validation_0-auc:0.78533	validation_1-auc:0.93411
# [3]	validation_0-auc:0.74248	validation_1-auc:0.94693
# [4]	validation_0-auc:0.76176	validation_1-auc:0.95150
# [5]	validation_0-auc:0.75064	validation_1-auc:0.95721
# [6]	validation_0-auc:0.73623	validation_1-auc:0.96179
# [0]	validation_0-auc:0.85780	validation_1-auc:0.90603
# [1]	validation_0-auc:0.80874	validation_1-auc:0.92043
# [2]	validation_0-auc:0.84603	validation_1-auc:0.94353
# [3]	validation_0-auc:0.83656	validation_1-auc:0.95554
# [4]	validation_0-auc:0.84073	validation_1-auc:0.95871
# [5]	validation_0-auc:0.85316	validation_1-auc:0.96336
# [0]	validation_0-auc:0.81504	validation_1-auc:0.90932
# [1]	validation_0-auc:0.75957	validation_1-auc:0.93229
# [2]	validation_0-auc:0.76371	validation_1-auc:0.94566
# [3]	validation_0-auc:0.77417	validation_1-auc:0.95479
# [4]	validation_0-auc:0.78936	validation_1-auc:0.95990
# [5]	validation_0-auc:0.77801	validation_1-auc:0.96245
# [0]	validation_0-auc:0.85004	validation_1-auc:0.89809
# [1]	validation_0-auc:0.85148	validation_1-auc:0.91703
# [2]	validation_0-auc:0.85359	validation_1-auc:0.93803
# [3]	validation_0-auc:0.88149	validation_1-auc:0.94941
# [4]	validation_0-auc:0.85194	validation_1-auc:0.95368
# [5]	validation_0-auc:0.84413	validation_1-auc:0.95979
# [6]	validation_0-auc:0.82811	validation_1-auc:0.96549
# [7]	validation_0-auc:0.82316	validation_1-auc:0.96859
# [0]	validation_0-auc:0.78525	validation_1-auc:0.91832
# [1]	validation_0-auc:0.76965	validation_1-auc:0.93116
# [2]	validation_0-auc:0.75473	validation_1-auc:0.94860
# [3]	validation_0-auc:0.75106	validation_1-auc:0.96012
# [4]	validation_0-auc:0.76970	validation_1-auc:0.96527
# [5]	validation_0-auc:0.77899	validation_1-auc:0.96909
# [0]	validation_0-auc:0.79674	validation_1-auc:0.89686
# [1]	validation_0-auc:0.78653	validation_1-auc:0.92602
# [2]	validation_0-auc:0.78017	validation_1-auc:0.93476
# [3]	validation_0-auc:0.77591	validation_1-auc:0.94787
# [4]	validation_0-auc:0.79671	validation_1-auc:0.95557
# [0]	validation_0-auc:0.79554	validation_1-auc:0.91639
# [1]	validation_0-auc:0.78280	validation_1-auc:0.92987
# [2]	validation_0-auc:0.78685	validation_1-auc:0.94395
# [3]	validation_0-auc:0.75156	validation_1-auc:0.95484
# [4]	validation_0-auc:0.78277	validation_1-auc:0.95999
# [5]	validation_0-auc:0.78032	validation_1-auc:0.96438
# [0]	validation_0-auc:0.76303	validation_1-auc:0.91469
# [1]	validation_0-auc:0.74697	validation_1-auc:0.92719
# [2]	validation_0-auc:0.76338	validation_1-auc:0.93813
# [3]	validation_0-auc:0.73912	validation_1-auc:0.95097
# [4]	validation_0-auc:0.74596	validation_1-auc:0.95941
# [5]	validation_0-auc:0.73961	validation_1-auc:0.96377
# [6]	validation_0-auc:0.72855	validation_1-auc:0.96597
# [7]	validation_0-auc:0.72583	validation_1-auc:0.96728
# [0]	validation_0-auc:0.83729	validation_1-auc:0.90282
# [1]	validation_0-auc:0.78508	validation_1-auc:0.93328
# [2]	validation_0-auc:0.76490	validation_1-auc:0.94074
# [3]	validation_0-auc:0.78365	validation_1-auc:0.95587
# [4]	validation_0-auc:0.80753	validation_1-auc:0.96068
# [0]	validation_0-auc:0.78994	validation_1-auc:0.91544
# [1]	validation_0-auc:0.79129	validation_1-auc:0.93528
# [2]	validation_0-auc:0.76957	validation_1-auc:0.94604
# [3]	validation_0-auc:0.78111	validation_1-auc:0.95118
# [4]	validation_0-auc:0.79907	validation_1-auc:0.95726
# [5]	validation_0-auc:0.79413	validation_1-auc:0.96076
# [6]	validation_0-auc:0.80465	validation_1-auc:0.96261
# [7]	validation_0-auc:0.80237	validation_1-auc:0.96498
# [8]	validation_0-auc:0.80642	validation_1-auc:0.96708
# [9]	validation_0-auc:0.81302	validation_1-auc:0.96905
# [10]	validation_0-auc:0.79112	validation_1-auc:0.97097
# [11]	validation_0-auc:0.78085	validation_1-auc:0.97199
# [12]	validation_0-auc:0.78969	validation_1-auc:0.97244
# [13]	validation_0-auc:0.77536	validation_1-auc:0.97385
# [14]	validation_0-auc:0.77967	validation_1-auc:0.97460
# [0]	validation_0-auc:0.76309	validation_1-auc:0.90249
# [1]	validation_0-auc:0.79442	validation_1-auc:0.92245
# [2]	validation_0-auc:0.74936	validation_1-auc:0.94025
# [3]	validation_0-auc:0.78484	validation_1-auc:0.94796
# [4]	validation_0-auc:0.79077	validation_1-auc:0.95469
# [5]	validation_0-auc:0.80751	validation_1-auc:0.95956
# [6]	validation_0-auc:0.79957	validation_1-auc:0.96314
# [7]	validation_0-auc:0.79585	validation_1-auc:0.96518
# [8]	validation_0-auc:0.80114	validation_1-auc:0.96699
# [9]	validation_0-auc:0.79106	validation_1-auc:0.96796
# [10]	validation_0-auc:0.79771	validation_1-auc:0.97014
# [0]	validation_0-auc:0.78613	validation_1-auc:0.90390
# [1]	validation_0-auc:0.78416	validation_1-auc:0.92373
# [2]	validation_0-auc:0.76594	validation_1-auc:0.94351
# [3]	validation_0-auc:0.74042	validation_1-auc:0.95326
# [4]	validation_0-auc:0.78028	validation_1-auc:0.95762
# [5]	validation_0-auc:0.78157	validation_1-auc:0.96235
# [0]	validation_0-auc:0.85248	validation_1-auc:0.89947
# [1]	validation_0-auc:0.81664	validation_1-auc:0.92351
# [2]	validation_0-auc:0.79443	validation_1-auc:0.93871
# [3]	validation_0-auc:0.80895	validation_1-auc:0.95100
# [4]	validation_0-auc:0.81289	validation_1-auc:0.95641
# [0]	validation_0-auc:0.76790	validation_1-auc:0.91275
# [1]	validation_0-auc:0.77827	validation_1-auc:0.92718
# [2]	validation_0-auc:0.76689	validation_1-auc:0.93875
# [3]	validation_0-auc:0.75046	validation_1-auc:0.94687
# [4]	validation_0-auc:0.73153	validation_1-auc:0.95641
# [5]	validation_0-auc:0.74948	validation_1-auc:0.96336
# [6]	validation_0-auc:0.74543	validation_1-auc:0.96612
# [0]	validation_0-auc:0.82817	validation_1-auc:0.90357
# [1]	validation_0-auc:0.85247	validation_1-auc:0.92349
# [2]	validation_0-auc:0.83729	validation_1-auc:0.93727
# [3]	validation_0-auc:0.85871	validation_1-auc:0.94757
# [4]	validation_0-auc:0.84509	validation_1-auc:0.95386
# [5]	validation_0-auc:0.85673	validation_1-auc:0.95822
# [6]	validation_0-auc:0.85457	validation_1-auc:0.96320
# [7]	validation_0-auc:0.85031	validation_1-auc:0.96650
# [0]	validation_0-auc:0.76471	validation_1-auc:0.91279
# [1]	validation_0-auc:0.77872	validation_1-auc:0.91862
# [2]	validation_0-auc:0.74975	validation_1-auc:0.93875
# [3]	validation_0-auc:0.76495	validation_1-auc:0.94933
# [4]	validation_0-auc:0.75540	validation_1-auc:0.95895
# [5]	validation_0-auc:0.75213	validation_1-auc:0.96405
# [6]	validation_0-auc:0.75267	validation_1-auc:0.96604
# [0]	validation_0-auc:0.82387	validation_1-auc:0.90434
# [1]	validation_0-auc:0.79819	validation_1-auc:0.92325
# [2]	validation_0-auc:0.79139	validation_1-auc:0.94086
# [3]	validation_0-auc:0.79313	validation_1-auc:0.95524
# [4]	validation_0-auc:0.79634	validation_1-auc:0.95968
# [0]	validation_0-auc:0.75118	validation_1-auc:0.90163
# [1]	validation_0-auc:0.69886	validation_1-auc:0.91675
# [2]	validation_0-auc:0.71842	validation_1-auc:0.93806
# [3]	validation_0-auc:0.73934	validation_1-auc:0.94884
# [4]	validation_0-auc:0.73750	validation_1-auc:0.95818
# [5]	validation_0-auc:0.76307	validation_1-auc:0.96435
# [6]	validation_0-auc:0.76645	validation_1-auc:0.96592
# [7]	validation_0-auc:0.76294	validation_1-auc:0.96820
# [8]	validation_0-auc:0.76311	validation_1-auc:0.96966
# [9]	validation_0-auc:0.76434	validation_1-auc:0.97007
# [10]	validation_0-auc:0.76715	validation_1-auc:0.97185
# [11]	validation_0-auc:0.77583	validation_1-auc:0.97423
# [12]	validation_0-auc:0.77570	validation_1-auc:0.97567
# [13]	validation_0-auc:0.78018	validation_1-auc:0.97686
# [14]	validation_0-auc:0.76474	validation_1-auc:0.97815
# [15]	validation_0-auc:0.74939	validation_1-auc:0.97962
# [16]	validation_0-auc:0.75219	validation_1-auc:0.98007
# [17]	validation_0-auc:0.74816	validation_1-auc:0.98097
# [0]	validation_0-auc:0.74211	validation_1-auc:0.90297
# [1]	validation_0-auc:0.82237	validation_1-auc:0.93418
# [2]	validation_0-auc:0.79409	validation_1-auc:0.94628
# [3]	validation_0-auc:0.79430	validation_1-auc:0.95504
# [4]	validation_0-auc:0.79821	validation_1-auc:0.95970
# [5]	validation_0-auc:0.79545	validation_1-auc:0.96441
# [6]	validation_0-auc:0.80541	validation_1-auc:0.96930
# [0]	validation_0-auc:0.79932	validation_1-auc:0.90731
# [1]	validation_0-auc:0.78264	validation_1-auc:0.93055
# [2]	validation_0-auc:0.76116	validation_1-auc:0.94293
# [3]	validation_0-auc:0.74727	validation_1-auc:0.95573
# [4]	validation_0-auc:0.70284	validation_1-auc:0.96201
# [5]	validation_0-auc:0.71983	validation_1-auc:0.96405
# [0]	validation_0-auc:0.80164	validation_1-auc:0.90285
# [1]	validation_0-auc:0.77046	validation_1-auc:0.92492
# [2]	validation_0-auc:0.77641	validation_1-auc:0.93985
# [3]	validation_0-auc:0.75954	validation_1-auc:0.95108
# [4]	validation_0-auc:0.78515	validation_1-auc:0.95734
# [5]	validation_0-auc:0.79750	validation_1-auc:0.96284
# [0]	validation_0-auc:0.83251	validation_1-auc:0.90586
# [1]	validation_0-auc:0.81339	validation_1-auc:0.93029
# [2]	validation_0-auc:0.79640	validation_1-auc:0.94425
# [3]	validation_0-auc:0.80022	validation_1-auc:0.95129
# [4]	validation_0-auc:0.81134	validation_1-auc:0.95992
# [0]	validation_0-auc:0.80808	validation_1-auc:0.88322
# [1]	validation_0-auc:0.80851	validation_1-auc:0.92307
# [2]	validation_0-auc:0.81670	validation_1-auc:0.93895
# [3]	validation_0-auc:0.81367	validation_1-auc:0.95030
# [4]	validation_0-auc:0.81009	validation_1-auc:0.95845
# [5]	validation_0-auc:0.81258	validation_1-auc:0.96122
# [6]	validation_0-auc:0.80597	validation_1-auc:0.96458
# [7]	validation_0-auc:0.80927	validation_1-auc:0.96599
# [0]	validation_0-auc:0.83700	validation_1-auc:0.90336
# [1]	validation_0-auc:0.82561	validation_1-auc:0.92507
# [2]	validation_0-auc:0.82647	validation_1-auc:0.93854
# [3]	validation_0-auc:0.81887	validation_1-auc:0.95034
# [4]	validation_0-auc:0.83530	validation_1-auc:0.95534
# [5]	validation_0-auc:0.82951	validation_1-auc:0.95798
# [0]	validation_0-auc:0.80022	validation_1-auc:0.91116
# [1]	validation_0-auc:0.75466	validation_1-auc:0.93381
# [2]	validation_0-auc:0.76556	validation_1-auc:0.94996
# [3]	validation_0-auc:0.78465	validation_1-auc:0.95643
# [4]	validation_0-auc:0.79002	validation_1-auc:0.96269
# [5]	validation_0-auc:0.79018	validation_1-auc:0.96859
# [0]	validation_0-auc:0.82571	validation_1-auc:0.89935
# [1]	validation_0-auc:0.80760	validation_1-auc:0.91550
# [2]	validation_0-auc:0.81419	validation_1-auc:0.93924
# [3]	validation_0-auc:0.82655	validation_1-auc:0.95061
# [4]	validation_0-auc:0.82607	validation_1-auc:0.95747
# [5]	validation_0-auc:0.82613	validation_1-auc:0.96089
# [6]	validation_0-auc:0.82679	validation_1-auc:0.96628
# [7]	validation_0-auc:0.81983	validation_1-auc:0.96891
# [8]	validation_0-auc:0.82133	validation_1-auc:0.97035
# [9]	validation_0-auc:0.82163	validation_1-auc:0.97214
# [10]	validation_0-auc:0.82349	validation_1-auc:0.97412
# [11]	validation_0-auc:0.82439	validation_1-auc:0.97548
# [0]	validation_0-auc:0.85313	validation_1-auc:0.90589
# [1]	validation_0-auc:0.87071	validation_1-auc:0.92493
# [2]	validation_0-auc:0.81383	validation_1-auc:0.93982
# [3]	validation_0-auc:0.77838	validation_1-auc:0.95497
# [4]	validation_0-auc:0.79206	validation_1-auc:0.96162
# [5]	validation_0-auc:0.79008	validation_1-auc:0.96724
# [6]	validation_0-auc:0.80268	validation_1-auc:0.97097
# [0]	validation_0-auc:0.82801	validation_1-auc:0.89747
# [1]	validation_0-auc:0.80185	validation_1-auc:0.92605
# [2]	validation_0-auc:0.76829	validation_1-auc:0.93659
# [3]	validation_0-auc:0.78710	validation_1-auc:0.94975
# [4]	validation_0-auc:0.80798	validation_1-auc:0.95552
# [5]	validation_0-auc:0.80081	validation_1-auc:0.96061
# [0]	validation_0-auc:0.79577	validation_1-auc:0.91023
# [1]	validation_0-auc:0.79062	validation_1-auc:0.93304
# [2]	validation_0-auc:0.76769	validation_1-auc:0.94392
# [3]	validation_0-auc:0.78738	validation_1-auc:0.95143
# [4]	validation_0-auc:0.79012	validation_1-auc:0.95945
# [0]	validation_0-auc:0.75942	validation_1-auc:0.90990
# [1]	validation_0-auc:0.76275	validation_1-auc:0.93443
# [2]	validation_0-auc:0.75939	validation_1-auc:0.94326
# [3]	validation_0-auc:0.78101	validation_1-auc:0.95706
# [4]	validation_0-auc:0.77620	validation_1-auc:0.96176
# [5]	validation_0-auc:0.78744	validation_1-auc:0.96603
# [6]	validation_0-auc:0.78263	validation_1-auc:0.96833
# [7]	validation_0-auc:0.78544	validation_1-auc:0.96951
# [8]	validation_0-auc:0.78503	validation_1-auc:0.97123
# [9]	validation_0-auc:0.78655	validation_1-auc:0.97310
# [0]	validation_0-auc:0.86319	validation_1-auc:0.89479
# [1]	validation_0-auc:0.84763	validation_1-auc:0.91925
# [2]	validation_0-auc:0.85351	validation_1-auc:0.93229
# [3]	validation_0-auc:0.83516	validation_1-auc:0.94870
# [4]	validation_0-auc:0.84180	validation_1-auc:0.95391
# [5]	validation_0-auc:0.82570	validation_1-auc:0.95785
# [0]	validation_0-auc:0.83398	validation_1-auc:0.90930
# [1]	validation_0-auc:0.82502	validation_1-auc:0.92453
# [2]	validation_0-auc:0.82667	validation_1-auc:0.94329
# [3]	validation_0-auc:0.81814	validation_1-auc:0.95237
# [4]	validation_0-auc:0.82068	validation_1-auc:0.95815
# [5]	validation_0-auc:0.81867	validation_1-auc:0.96236
# [0]	validation_0-auc:0.84231	validation_1-auc:0.91220
# [1]	validation_0-auc:0.84131	validation_1-auc:0.92765
# [2]	validation_0-auc:0.84774	validation_1-auc:0.93792
# [3]	validation_0-auc:0.84386	validation_1-auc:0.94767
# [4]	validation_0-auc:0.84833	validation_1-auc:0.95409
# [5]	validation_0-auc:0.84263	validation_1-auc:0.96131
# [6]	validation_0-auc:0.82531	validation_1-auc:0.96517
# [7]	validation_0-auc:0.82007	validation_1-auc:0.96750
# [8]	validation_0-auc:0.82198	validation_1-auc:0.97090
# [0]	validation_0-auc:0.79960	validation_1-auc:0.91298
# [1]	validation_0-auc:0.78835	validation_1-auc:0.92256
# [2]	validation_0-auc:0.79414	validation_1-auc:0.94067
# [3]	validation_0-auc:0.77293	validation_1-auc:0.95475
# [4]	validation_0-auc:0.78702	validation_1-auc:0.96050
# [5]	validation_0-auc:0.79485	validation_1-auc:0.96373
# [0]	validation_0-auc:0.78989	validation_1-auc:0.90093
# [1]	validation_0-auc:0.74641	validation_1-auc:0.92760
# [2]	validation_0-auc:0.74082	validation_1-auc:0.94321
# [3]	validation_0-auc:0.73638	validation_1-auc:0.95579
# [4]	validation_0-auc:0.71725	validation_1-auc:0.96103
# [0]	validation_0-auc:0.83039	validation_1-auc:0.90874
# [1]	validation_0-auc:0.80562	validation_1-auc:0.93196
# [2]	validation_0-auc:0.80364	validation_1-auc:0.93836
# [3]	validation_0-auc:0.76446	validation_1-auc:0.95275
# [4]	validation_0-auc:0.79332	validation_1-auc:0.96027
# [5]	validation_0-auc:0.79878	validation_1-auc:0.96336
# [0]	validation_0-auc:0.83899	validation_1-auc:0.90525
# [1]	validation_0-auc:0.84883	validation_1-auc:0.92666
# [2]	validation_0-auc:0.84241	validation_1-auc:0.94129
# [3]	validation_0-auc:0.84332	validation_1-auc:0.95200
# [4]	validation_0-auc:0.83342	validation_1-auc:0.95789
# [5]	validation_0-auc:0.83146	validation_1-auc:0.96119
# [0]	validation_0-auc:0.80748	validation_1-auc:0.90829
# [1]	validation_0-auc:0.79333	validation_1-auc:0.92890
# [2]	validation_0-auc:0.79928	validation_1-auc:0.94486
# [3]	validation_0-auc:0.80264	validation_1-auc:0.95545
# [4]	validation_0-auc:0.81248	validation_1-auc:0.96097
# [5]	validation_0-auc:0.81069	validation_1-auc:0.96440
# [6]	validation_0-auc:0.78906	validation_1-auc:0.96789
# [7]	validation_0-auc:0.78982	validation_1-auc:0.97197
# [8]	validation_0-auc:0.78769	validation_1-auc:0.97388
# [9]	validation_0-auc:0.78853	validation_1-auc:0.97497
# [0]	validation_0-auc:0.80928	validation_1-auc:0.91191
# [1]	validation_0-auc:0.81332	validation_1-auc:0.92389
# [2]	validation_0-auc:0.76472	validation_1-auc:0.93901
# [3]	validation_0-auc:0.78231	validation_1-auc:0.94842
# [4]	validation_0-auc:0.78917	validation_1-auc:0.95789
# [5]	validation_0-auc:0.81404	validation_1-auc:0.96099
# [6]	validation_0-auc:0.80218	validation_1-auc:0.96482
# [7]	validation_0-auc:0.80062	validation_1-auc:0.96698
# [8]	validation_0-auc:0.80169	validation_1-auc:0.97018
# [9]	validation_0-auc:0.79406	validation_1-auc:0.97192
# [10]	validation_0-auc:0.79295	validation_1-auc:0.97329
# [0]	validation_0-auc:0.79821	validation_1-auc:0.90978
# [1]	validation_0-auc:0.82215	validation_1-auc:0.93011
# [2]	validation_0-auc:0.80717	validation_1-auc:0.94801
# [3]	validation_0-auc:0.81882	validation_1-auc:0.95592
# [4]	validation_0-auc:0.80498	validation_1-auc:0.96233
# [5]	validation_0-auc:0.80452	validation_1-auc:0.96557
# [6]	validation_0-auc:0.80616	validation_1-auc:0.96910
# [0]	validation_0-auc:0.81422	validation_1-auc:0.90460
# [1]	validation_0-auc:0.80933	validation_1-auc:0.92745
# [2]	validation_0-auc:0.76557	validation_1-auc:0.93815
# [3]	validation_0-auc:0.80454	validation_1-auc:0.94823
# [4]	validation_0-auc:0.82243	validation_1-auc:0.95232
# [5]	validation_0-auc:0.83995	validation_1-auc:0.95770
# [6]	validation_0-auc:0.83999	validation_1-auc:0.96164
# [7]	validation_0-auc:0.82723	validation_1-auc:0.96531
# [8]	validation_0-auc:0.83003	validation_1-auc:0.96877
# [9]	validation_0-auc:0.81659	validation_1-auc:0.97054
# [10]	validation_0-auc:0.79637	validation_1-auc:0.97203
# [11]	validation_0-auc:0.79628	validation_1-auc:0.97288
# [0]	validation_0-auc:0.80490	validation_1-auc:0.90798
# [1]	validation_0-auc:0.76213	validation_1-auc:0.93013
# [2]	validation_0-auc:0.80144	validation_1-auc:0.94197
# [3]	validation_0-auc:0.81462	validation_1-auc:0.95382
# [4]	validation_0-auc:0.79992	validation_1-auc:0.95892
# [5]	validation_0-auc:0.79755	validation_1-auc:0.96270
# [6]	validation_0-auc:0.80647	validation_1-auc:0.96617
# [7]	validation_0-auc:0.80702	validation_1-auc:0.96790
# [0]	validation_0-auc:0.85228	validation_1-auc:0.91064
# [1]	validation_0-auc:0.84063	validation_1-auc:0.93160
# [2]	validation_0-auc:0.82671	validation_1-auc:0.94444
# [3]	validation_0-auc:0.82930	validation_1-auc:0.95744
# [4]	validation_0-auc:0.84022	validation_1-auc:0.96174
# [5]	validation_0-auc:0.83209	validation_1-auc:0.96624
# [0]	validation_0-auc:0.78187	validation_1-auc:0.90365
# [1]	validation_0-auc:0.81158	validation_1-auc:0.92777
# [2]	validation_0-auc:0.80216	validation_1-auc:0.94039
# [3]	validation_0-auc:0.82215	validation_1-auc:0.95103
# [4]	validation_0-auc:0.82109	validation_1-auc:0.95798
# [5]	validation_0-auc:0.83081	validation_1-auc:0.96262
# [6]	validation_0-auc:0.82046	validation_1-auc:0.96802
# [7]	validation_0-auc:0.83005	validation_1-auc:0.96991
# [8]	validation_0-auc:0.83208	validation_1-auc:0.97134
# [9]	validation_0-auc:0.82933	validation_1-auc:0.97366
# [10]	validation_0-auc:0.82883	validation_1-auc:0.97476
# [11]	validation_0-auc:0.83090	validation_1-auc:0.97537
# [12]	validation_0-auc:0.82101	validation_1-auc:0.97693
# [0]	validation_0-auc:0.82133	validation_1-auc:0.90943
# [1]	validation_0-auc:0.80331	validation_1-auc:0.93148
# [2]	validation_0-auc:0.80963	validation_1-auc:0.94312
# [3]	validation_0-auc:0.82298	validation_1-auc:0.95596
# [4]	validation_0-auc:0.80047	validation_1-auc:0.96200
# [5]	validation_0-auc:0.79596	validation_1-auc:0.96557
# [6]	validation_0-auc:0.78851	validation_1-auc:0.97024
# [7]	validation_0-auc:0.77955	validation_1-auc:0.97182
# [8]	validation_0-auc:0.75197	validation_1-auc:0.97305
# [0]	validation_0-auc:0.82325	validation_1-auc:0.89965
# [1]	validation_0-auc:0.80764	validation_1-auc:0.92531
# [2]	validation_0-auc:0.78657	validation_1-auc:0.94335
# [3]	validation_0-auc:0.75507	validation_1-auc:0.95018
# [4]	validation_0-auc:0.75068	validation_1-auc:0.95925
# [0]	validation_0-auc:0.79597	validation_1-auc:0.90559
# [1]	validation_0-auc:0.75640	validation_1-auc:0.92763
# [2]	validation_0-auc:0.76044	validation_1-auc:0.94037
# [3]	validation_0-auc:0.76603	validation_1-auc:0.95225
# [4]	validation_0-auc:0.76371	validation_1-auc:0.95759
# [5]	validation_0-auc:0.75330	validation_1-auc:0.96550
#     precision    recall    fscore  accuracy       auc  miss_rate  \
# 0    0.165517  0.648649  0.263736  0.721414  0.688063   0.037464
# 1    0.142857  0.575758  0.228916  0.733888  0.660647   0.039660
# 2    0.126984  0.571429  0.207792  0.746362  0.664301   0.033426
# 3    0.065693  0.750000  0.120805  0.727651  0.738539   0.008571
# 4    0.123810  0.565217  0.203125  0.787942  0.682172   0.026385
# ..        ...       ...       ...       ...       ...        ...
# 95   0.120690  0.666667  0.204380  0.773389  0.722464   0.018817
# 96   0.156522  0.692308  0.255319  0.781705  0.739560   0.021277
# 97   0.098361  0.571429  0.167832  0.752599  0.666149   0.024862
# 98   0.082645  0.526316  0.142857  0.750520  0.643028   0.024931
# 99   0.126984  0.592593  0.209150  0.748441  0.675151   0.030556
#
#     fall_out_rate
# 0        0.272523
# 1        0.254464
# 2        0.242826
# 3        0.272921
# 4        0.200873
# ..            ...
# 95       0.221739
# 96       0.213187
# 97       0.239130
# 98       0.240260
# 99       0.242291
#
# [100 rows x 7 columns]
