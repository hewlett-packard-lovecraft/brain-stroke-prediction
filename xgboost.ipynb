# %%
import pandas as pd
import random
import sklearn

from pathlib import Path
import xgboost as xgb
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_absolute_error

from imblearn.combine import SMOTEENN

# %%
CATEGORICAL_FEATURE_NAMES = [
    "gender",
    "hypertension",
    "heart_disease",
    "ever_married",
    "work_type",
    "residence_type",
    "smoking_status",
]


def encode_int(data: pd.DataFrame, categorical_features: list[str]):
    return pd.get_dummies(data, columns=categorical_features, drop_first=True)


def split_label(data: pd.DataFrame):
    x = data.copy().drop("stroke", axis=1)
    y = data["stroke"]  # labels

    return x, y


def resample(data: pd.DataFrame, seed: int):
    """oversample positive cases with SMOTE and undersample negative with EEN"""
    X = data.drop(columns=["stroke"], axis=1)
    Y = data["stroke"]

    smote_een = SMOTEENN(random_state=seed, sampling_strategy="auto")

    x_resampled, y_resampled = smote_een.fit_resample(X, Y)
    x_resampled["stroke"] = y_resampled

    return pd.DataFrame(x_resampled, columns=data.columns)


def split_train_valid_test(data_df, seed: int):
    data_df = data_df.sample(frac=1, random_state=seed)

    test_set = data_df[4500:]
    train_validation_data = data_df[:4500].sample(frac=1, random_state=seed)

    train_set = resample(train_validation_data[:4000], seed)
    validation_set = train_validation_data[4000:]

    return train_set, validation_set, test_set


def prepare_data(seed: int):
    data_df = pd.read_csv(Path().resolve().joinpath("dataset/full_data_clean.csv"))
    data_df = encode_int(data=data_df, categorical_features=CATEGORICAL_FEATURE_NAMES)

    train_df, validation_df, test_df = split_train_valid_test(data_df, seed)

    return train_df, validation_df, test_df

# %%
RESULT_COLS = [
    "precision",
    "recall",
    "fscore",
    "accuracy",
    "auc",
    "miss_rate",
    "fall_out_rate",
]
NUM_EXPERIMENTS = 100
NUM_ROUNDS=50

def metrics(y_pred, y_true):
    tn, fp, fn, tp = confusion_matrix(y_pred=y_pred, y_true=y_true).ravel()

    # metrics
    auc = roc_auc_score(y_true=y_true, y_score=y_pred)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    fscore = 2 * tp / (2 * tp + fp + fn)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    miss_rate = fn / (tn + tp)
    fall_out_rate = fp / (fp + tn)

    # return
    return [precision, recall, fscore, accuracy, auc, miss_rate, fall_out_rate]

# %%
# evaluate xgboost
from xgboost.callback import EarlyStopping

results = {}

for experiment in range(NUM_EXPERIMENTS):
    seed = random.randint(0, 1000)

    train_data, validation_data, test_data = prepare_data(seed=experiment)

    # split labels
    x, y = split_label(train_data)
    x_valid, y_valid = split_label(validation_data)
    x_test, y_test = split_label(test_data)

    # metrics
    param = {"max_depth": 2, "eta": 1, "objective": "binary:logistic"}
    
    es = EarlyStopping(
        rounds=5,
        save_best=True,
        maximize=True,
        data_name="validation_0",
        metric_name="auc",
    )
    
    clf = xgb.sklearn.XGBClassifier(
        max_depth=param["max_depth"],
        eta=param['eta'],
        objective=param["objective"],
        gpu_id=0,
        predictor='gpu_predictor',
        eval_metric='auc',
        early_stopping_rounds=5,
        callbacks=[es]
    )

    clf.fit(
        x, y,
        eval_set=[(x_valid, y_valid), (x, y)]
    )

    y_pred = clf.predict(x_test)

    results[experiment] = list(metrics(y_pred, y_test))

results = pd.DataFrame().from_dict(results, orient="index", columns=RESULT_COLS)

results.to_csv(Path().resolve().joinpath("results/XGBoost.csv"))

results
# Out:
# [0]	validation_0-auc:0.81672	validation_1-auc:0.90667
# [1]	validation_0-auc:0.81204	validation_1-auc:0.93274
# [2]	validation_0-auc:0.82366	validation_1-auc:0.94178
# [3]	validation_0-auc:0.82400	validation_1-auc:0.95367
# [4]	validation_0-auc:0.83204	validation_1-auc:0.95900
# [5]	validation_0-auc:0.84400	validation_1-auc:0.96287
# [6]	validation_0-auc:0.82661	validation_1-auc:0.96566
# [7]	validation_0-auc:0.83423	validation_1-auc:0.96907
# [8]	validation_0-auc:0.81819	validation_1-auc:0.97018
# [9]	validation_0-auc:0.82505	validation_1-auc:0.97202
# [0]	validation_0-auc:0.79032	validation_1-auc:0.89991
# [1]	validation_0-auc:0.78553	validation_1-auc:0.93592
# [2]	validation_0-auc:0.78498	validation_1-auc:0.94423
# [3]	validation_0-auc:0.77594	validation_1-auc:0.95526
# [4]	validation_0-auc:0.80189	validation_1-auc:0.96123
# [5]	validation_0-auc:0.78655	validation_1-auc:0.96561
# [6]	validation_0-auc:0.78011	validation_1-auc:0.96863
# [7]	validation_0-auc:0.78047	validation_1-auc:0.97133
# [8]	validation_0-auc:0.78769	validation_1-auc:0.97268
# [9]	validation_0-auc:0.78395	validation_1-auc:0.97517
# [0]	validation_0-auc:0.80812	validation_1-auc:0.91762
# [1]	validation_0-auc:0.79854	validation_1-auc:0.94050
# [2]	validation_0-auc:0.81490	validation_1-auc:0.94957
# [3]	validation_0-auc:0.79255	validation_1-auc:0.95890
# [4]	validation_0-auc:0.79984	validation_1-auc:0.96515
# [5]	validation_0-auc:0.79573	validation_1-auc:0.96876
# [6]	validation_0-auc:0.80010	validation_1-auc:0.97151
# [0]	validation_0-auc:0.79242	validation_1-auc:0.90636
# [1]	validation_0-auc:0.80508	validation_1-auc:0.93415
# [2]	validation_0-auc:0.82079	validation_1-auc:0.94421
# [3]	validation_0-auc:0.81453	validation_1-auc:0.95805
# [4]	validation_0-auc:0.81312	validation_1-auc:0.96369
# [5]	validation_0-auc:0.81416	validation_1-auc:0.96544
# [6]	validation_0-auc:0.80869	validation_1-auc:0.96883
# [0]	validation_0-auc:0.83094	validation_1-auc:0.89387
# [1]	validation_0-auc:0.82531	validation_1-auc:0.92455
# [2]	validation_0-auc:0.81141	validation_1-auc:0.93663
# [3]	validation_0-auc:0.78816	validation_1-auc:0.95104
# [4]	validation_0-auc:0.81716	validation_1-auc:0.95512
# [5]	validation_0-auc:0.82263	validation_1-auc:0.95908
# [0]	validation_0-auc:0.82677	validation_1-auc:0.90704
# [1]	validation_0-auc:0.83361	validation_1-auc:0.92581
# [2]	validation_0-auc:0.82873	validation_1-auc:0.94586
# [3]	validation_0-auc:0.82590	validation_1-auc:0.95608
# [4]	validation_0-auc:0.84413	validation_1-auc:0.96172
# [5]	validation_0-auc:0.85161	validation_1-auc:0.96362
# [6]	validation_0-auc:0.85275	validation_1-auc:0.96526
# [7]	validation_0-auc:0.85803	validation_1-auc:0.96870
# [8]	validation_0-auc:0.85247	validation_1-auc:0.97106
# [9]	validation_0-auc:0.85603	validation_1-auc:0.97311
# [10]	validation_0-auc:0.84117	validation_1-auc:0.97457
# [11]	validation_0-auc:0.84979	validation_1-auc:0.97551
# [0]	validation_0-auc:0.81499	validation_1-auc:0.91527
# [1]	validation_0-auc:0.78970	validation_1-auc:0.93649
# [2]	validation_0-auc:0.78418	validation_1-auc:0.94773
# [3]	validation_0-auc:0.79482	validation_1-auc:0.95478
# [4]	validation_0-auc:0.80182	validation_1-auc:0.95988
# [5]	validation_0-auc:0.80270	validation_1-auc:0.96429
# [0]	validation_0-auc:0.79794	validation_1-auc:0.89753
# [1]	validation_0-auc:0.80547	validation_1-auc:0.92608
# [2]	validation_0-auc:0.82093	validation_1-auc:0.93876
# [3]	validation_0-auc:0.80084	validation_1-auc:0.94906
# [4]	validation_0-auc:0.78118	validation_1-auc:0.95776
# [5]	validation_0-auc:0.79288	validation_1-auc:0.96162
# [6]	validation_0-auc:0.78362	validation_1-auc:0.96564
# [0]	validation_0-auc:0.81286	validation_1-auc:0.89364
# [1]	validation_0-auc:0.83901	validation_1-auc:0.92445
# [2]	validation_0-auc:0.85240	validation_1-auc:0.93565
# [3]	validation_0-auc:0.84332	validation_1-auc:0.94676
# [4]	validation_0-auc:0.83607	validation_1-auc:0.95535
# [5]	validation_0-auc:0.83678	validation_1-auc:0.95956
# [6]	validation_0-auc:0.81579	validation_1-auc:0.96211
# [7]	validation_0-auc:0.79982	validation_1-auc:0.96471
# [0]	validation_0-auc:0.82066	validation_1-auc:0.90421
# [1]	validation_0-auc:0.77542	validation_1-auc:0.92835
# [2]	validation_0-auc:0.76737	validation_1-auc:0.93929
# [3]	validation_0-auc:0.77841	validation_1-auc:0.95174
# [4]	validation_0-auc:0.77682	validation_1-auc:0.95875
# [0]	validation_0-auc:0.80289	validation_1-auc:0.90456
# [1]	validation_0-auc:0.79625	validation_1-auc:0.92430
# [2]	validation_0-auc:0.79509	validation_1-auc:0.93786
# [3]	validation_0-auc:0.78334	validation_1-auc:0.95080
# [4]	validation_0-auc:0.80940	validation_1-auc:0.95762
# [5]	validation_0-auc:0.80599	validation_1-auc:0.96221
# [6]	validation_0-auc:0.81440	validation_1-auc:0.96538
# [7]	validation_0-auc:0.81074	validation_1-auc:0.96768
# [8]	validation_0-auc:0.80922	validation_1-auc:0.97113
# [9]	validation_0-auc:0.80569	validation_1-auc:0.97295
# [10]	validation_0-auc:0.80940	validation_1-auc:0.97539
# [0]	validation_0-auc:0.80439	validation_1-auc:0.91409
# [1]	validation_0-auc:0.78706	validation_1-auc:0.94085
# [2]	validation_0-auc:0.80549	validation_1-auc:0.95155
# [3]	validation_0-auc:0.82482	validation_1-auc:0.95760
# [4]	validation_0-auc:0.80879	validation_1-auc:0.96465
# [5]	validation_0-auc:0.81673	validation_1-auc:0.96844
# [6]	validation_0-auc:0.80876	validation_1-auc:0.97162
# [7]	validation_0-auc:0.80645	validation_1-auc:0.97290
# [8]	validation_0-auc:0.80827	validation_1-auc:0.97386
# [0]	validation_0-auc:0.84375	validation_1-auc:0.90048
# [1]	validation_0-auc:0.84410	validation_1-auc:0.92985
# [2]	validation_0-auc:0.81171	validation_1-auc:0.94507
# [3]	validation_0-auc:0.82629	validation_1-auc:0.95272
# [4]	validation_0-auc:0.81959	validation_1-auc:0.95969
# [5]	validation_0-auc:0.82791	validation_1-auc:0.96458
# [0]	validation_0-auc:0.81629	validation_1-auc:0.90876
# [1]	validation_0-auc:0.78252	validation_1-auc:0.93854
# [2]	validation_0-auc:0.76287	validation_1-auc:0.94931
# [3]	validation_0-auc:0.75563	validation_1-auc:0.96063
# [4]	validation_0-auc:0.78247	validation_1-auc:0.96387
# [5]	validation_0-auc:0.79213	validation_1-auc:0.96903
# [0]	validation_0-auc:0.81842	validation_1-auc:0.90117
# [1]	validation_0-auc:0.80796	validation_1-auc:0.92732
# [2]	validation_0-auc:0.77006	validation_1-auc:0.93899
# [3]	validation_0-auc:0.77887	validation_1-auc:0.95080
# [4]	validation_0-auc:0.77872	validation_1-auc:0.95483
# [5]	validation_0-auc:0.80209	validation_1-auc:0.95955
# [0]	validation_0-auc:0.81443	validation_1-auc:0.90059
# [1]	validation_0-auc:0.79309	validation_1-auc:0.92476
# [2]	validation_0-auc:0.76618	validation_1-auc:0.93549
# [3]	validation_0-auc:0.75576	validation_1-auc:0.94986
# [4]	validation_0-auc:0.77967	validation_1-auc:0.95650
# [0]	validation_0-auc:0.86235	validation_1-auc:0.90965
# [1]	validation_0-auc:0.85356	validation_1-auc:0.93644
# [2]	validation_0-auc:0.84324	validation_1-auc:0.94554
# [3]	validation_0-auc:0.85341	validation_1-auc:0.95756
# [4]	validation_0-auc:0.83069	validation_1-auc:0.96284
# [5]	validation_0-auc:0.84129	validation_1-auc:0.96638
# [0]	validation_0-auc:0.84058	validation_1-auc:0.91603
# [1]	validation_0-auc:0.85384	validation_1-auc:0.92810
# [2]	validation_0-auc:0.82996	validation_1-auc:0.94175
# [3]	validation_0-auc:0.83757	validation_1-auc:0.95145
# [4]	validation_0-auc:0.85831	validation_1-auc:0.95994
# [5]	validation_0-auc:0.86897	validation_1-auc:0.96335
# [6]	validation_0-auc:0.86747	validation_1-auc:0.96799
# [7]	validation_0-auc:0.86610	validation_1-auc:0.97040
# [8]	validation_0-auc:0.84682	validation_1-auc:0.97237
# [9]	validation_0-auc:0.86455	validation_1-auc:0.97388
# [0]	validation_0-auc:0.86216	validation_1-auc:0.90144
# [1]	validation_0-auc:0.83558	validation_1-auc:0.93032
# [2]	validation_0-auc:0.81966	validation_1-auc:0.93965
# [3]	validation_0-auc:0.84136	validation_1-auc:0.95267
# [4]	validation_0-auc:0.82502	validation_1-auc:0.95749
# [5]	validation_0-auc:0.83654	validation_1-auc:0.96142
# [0]	validation_0-auc:0.76873	validation_1-auc:0.91710
# [1]	validation_0-auc:0.74909	validation_1-auc:0.92916
# [2]	validation_0-auc:0.70445	validation_1-auc:0.94587
# [3]	validation_0-auc:0.73337	validation_1-auc:0.95502
# [4]	validation_0-auc:0.71621	validation_1-auc:0.96399
# [5]	validation_0-auc:0.71748	validation_1-auc:0.96839
# [0]	validation_0-auc:0.85097	validation_1-auc:0.90265
# [1]	validation_0-auc:0.81273	validation_1-auc:0.93243
# [2]	validation_0-auc:0.79068	validation_1-auc:0.94817
# [3]	validation_0-auc:0.79538	validation_1-auc:0.95723
# [4]	validation_0-auc:0.81180	validation_1-auc:0.96014
# [0]	validation_0-auc:0.87160	validation_1-auc:0.90203
# [1]	validation_0-auc:0.84969	validation_1-auc:0.93268
# [2]	validation_0-auc:0.80868	validation_1-auc:0.94254
# [3]	validation_0-auc:0.83599	validation_1-auc:0.95513
# [4]	validation_0-auc:0.85688	validation_1-auc:0.96112
# [0]	validation_0-auc:0.76654	validation_1-auc:0.90129
# [1]	validation_0-auc:0.79350	validation_1-auc:0.93076
# [2]	validation_0-auc:0.78733	validation_1-auc:0.93905
# [3]	validation_0-auc:0.78628	validation_1-auc:0.95522
# [4]	validation_0-auc:0.79613	validation_1-auc:0.96301
# [5]	validation_0-auc:0.78423	validation_1-auc:0.96810
# [6]	validation_0-auc:0.78322	validation_1-auc:0.97214
# [7]	validation_0-auc:0.79272	validation_1-auc:0.97436
# [8]	validation_0-auc:0.77897	validation_1-auc:0.97617
# [9]	validation_0-auc:0.78213	validation_1-auc:0.97791
# [0]	validation_0-auc:0.82940	validation_1-auc:0.90172
# [1]	validation_0-auc:0.82527	validation_1-auc:0.92975
# [2]	validation_0-auc:0.82208	validation_1-auc:0.94351
# [3]	validation_0-auc:0.81433	validation_1-auc:0.95293
# [4]	validation_0-auc:0.82655	validation_1-auc:0.95860
# [0]	validation_0-auc:0.77524	validation_1-auc:0.90985
# [1]	validation_0-auc:0.78730	validation_1-auc:0.92461
# [2]	validation_0-auc:0.74674	validation_1-auc:0.94306
# [3]	validation_0-auc:0.77743	validation_1-auc:0.94953
# [4]	validation_0-auc:0.78078	validation_1-auc:0.95579
# [5]	validation_0-auc:0.77280	validation_1-auc:0.96190
# [0]	validation_0-auc:0.85685	validation_1-auc:0.90459
# [1]	validation_0-auc:0.83241	validation_1-auc:0.93114
# [2]	validation_0-auc:0.83212	validation_1-auc:0.94525
# [3]	validation_0-auc:0.82959	validation_1-auc:0.95777
# [4]	validation_0-auc:0.83368	validation_1-auc:0.96403
# [5]	validation_0-auc:0.84630	validation_1-auc:0.96809
# [0]	validation_0-auc:0.85248	validation_1-auc:0.90299
# [1]	validation_0-auc:0.85094	validation_1-auc:0.92251
# [2]	validation_0-auc:0.72945	validation_1-auc:0.93715
# [3]	validation_0-auc:0.74065	validation_1-auc:0.94852
# [4]	validation_0-auc:0.75694	validation_1-auc:0.95817
# [0]	validation_0-auc:0.82012	validation_1-auc:0.90224
# [1]	validation_0-auc:0.82992	validation_1-auc:0.93174
# [2]	validation_0-auc:0.81975	validation_1-auc:0.94177
# [3]	validation_0-auc:0.83536	validation_1-auc:0.95244
# [4]	validation_0-auc:0.83834	validation_1-auc:0.95709
# [5]	validation_0-auc:0.83960	validation_1-auc:0.95855
# [6]	validation_0-auc:0.83112	validation_1-auc:0.96405
# [7]	validation_0-auc:0.81770	validation_1-auc:0.96594
# [8]	validation_0-auc:0.83072	validation_1-auc:0.96853
# [9]	validation_0-auc:0.82765	validation_1-auc:0.97208
# [10]	validation_0-auc:0.82246	validation_1-auc:0.97371
# [0]	validation_0-auc:0.76522	validation_1-auc:0.92228
# [1]	validation_0-auc:0.76392	validation_1-auc:0.95188
# [2]	validation_0-auc:0.78851	validation_1-auc:0.95710
# [3]	validation_0-auc:0.78446	validation_1-auc:0.96681
# [4]	validation_0-auc:0.78497	validation_1-auc:0.97182
# [5]	validation_0-auc:0.78261	validation_1-auc:0.97497
# [6]	validation_0-auc:0.78526	validation_1-auc:0.97716
# [7]	validation_0-auc:0.77916	validation_1-auc:0.97936
# [0]	validation_0-auc:0.80514	validation_1-auc:0.90112
# [1]	validation_0-auc:0.80664	validation_1-auc:0.93058
# [2]	validation_0-auc:0.78189	validation_1-auc:0.94308
# [3]	validation_0-auc:0.79447	validation_1-auc:0.95336
# [4]	validation_0-auc:0.77836	validation_1-auc:0.96021
# [5]	validation_0-auc:0.78984	validation_1-auc:0.96393
# [0]	validation_0-auc:0.83758	validation_1-auc:0.89953
# [1]	validation_0-auc:0.82467	validation_1-auc:0.92797
# [2]	validation_0-auc:0.83653	validation_1-auc:0.93923
# [3]	validation_0-auc:0.83491	validation_1-auc:0.95143
# [4]	validation_0-auc:0.84099	validation_1-auc:0.95596
# [5]	validation_0-auc:0.82156	validation_1-auc:0.96042
# [6]	validation_0-auc:0.82112	validation_1-auc:0.96463
# [7]	validation_0-auc:0.82629	validation_1-auc:0.96589
# [8]	validation_0-auc:0.81885	validation_1-auc:0.96786
# [0]	validation_0-auc:0.84897	validation_1-auc:0.89826
# [1]	validation_0-auc:0.85272	validation_1-auc:0.92520
# [2]	validation_0-auc:0.83713	validation_1-auc:0.93863
# [3]	validation_0-auc:0.81821	validation_1-auc:0.94908
# [4]	validation_0-auc:0.84004	validation_1-auc:0.95611
# [5]	validation_0-auc:0.83365	validation_1-auc:0.96158
# [0]	validation_0-auc:0.82978	validation_1-auc:0.91154
# [1]	validation_0-auc:0.82447	validation_1-auc:0.93432
# [2]	validation_0-auc:0.82275	validation_1-auc:0.94361
# [3]	validation_0-auc:0.82202	validation_1-auc:0.95719
# [4]	validation_0-auc:0.82491	validation_1-auc:0.96331
# [0]	validation_0-auc:0.78906	validation_1-auc:0.90263
# [1]	validation_0-auc:0.78876	validation_1-auc:0.93535
# [2]	validation_0-auc:0.76439	validation_1-auc:0.94430
# [3]	validation_0-auc:0.75801	validation_1-auc:0.95456
# [4]	validation_0-auc:0.76449	validation_1-auc:0.95897
# [5]	validation_0-auc:0.78863	validation_1-auc:0.96367
# [0]	validation_0-auc:0.77919	validation_1-auc:0.91332
# [1]	validation_0-auc:0.79487	validation_1-auc:0.92425
# [2]	validation_0-auc:0.80635	validation_1-auc:0.94460
# [3]	validation_0-auc:0.76315	validation_1-auc:0.95155
# [4]	validation_0-auc:0.78913	validation_1-auc:0.95593
# [5]	validation_0-auc:0.80713	validation_1-auc:0.96184
# [6]	validation_0-auc:0.81392	validation_1-auc:0.96481
# [7]	validation_0-auc:0.81592	validation_1-auc:0.96610
# [8]	validation_0-auc:0.82126	validation_1-auc:0.96894
# [9]	validation_0-auc:0.82581	validation_1-auc:0.97007
# [10]	validation_0-auc:0.82659	validation_1-auc:0.97146
# [11]	validation_0-auc:0.82408	validation_1-auc:0.97290
# [12]	validation_0-auc:0.82809	validation_1-auc:0.97334
# [13]	validation_0-auc:0.81971	validation_1-auc:0.97424
# [14]	validation_0-auc:0.81943	validation_1-auc:0.97459
# [15]	validation_0-auc:0.81269	validation_1-auc:0.97599
# [16]	validation_0-auc:0.80854	validation_1-auc:0.97688
# [17]	validation_0-auc:0.80644	validation_1-auc:0.97717
# [0]	validation_0-auc:0.84445	validation_1-auc:0.89674
# [1]	validation_0-auc:0.84809	validation_1-auc:0.92506
# [2]	validation_0-auc:0.83130	validation_1-auc:0.94220
# [3]	validation_0-auc:0.83282	validation_1-auc:0.95060
# [4]	validation_0-auc:0.84704	validation_1-auc:0.95706
# [5]	validation_0-auc:0.85675	validation_1-auc:0.96293
# [6]	validation_0-auc:0.84015	validation_1-auc:0.96551
# [7]	validation_0-auc:0.84449	validation_1-auc:0.96782
# [8]	validation_0-auc:0.82503	validation_1-auc:0.97097
# [9]	validation_0-auc:0.82977	validation_1-auc:0.97174
# [10]	validation_0-auc:0.83380	validation_1-auc:0.97414
# [0]	validation_0-auc:0.76552	validation_1-auc:0.90559
# [1]	validation_0-auc:0.76584	validation_1-auc:0.93872
# [2]	validation_0-auc:0.77927	validation_1-auc:0.95079
# [3]	validation_0-auc:0.79395	validation_1-auc:0.95864
# [4]	validation_0-auc:0.80734	validation_1-auc:0.96333
# [5]	validation_0-auc:0.79767	validation_1-auc:0.96800
# [6]	validation_0-auc:0.81305	validation_1-auc:0.97048
# [7]	validation_0-auc:0.81086	validation_1-auc:0.97172
# [8]	validation_0-auc:0.80444	validation_1-auc:0.97318
# [9]	validation_0-auc:0.80522	validation_1-auc:0.97485
# [10]	validation_0-auc:0.81505	validation_1-auc:0.97675
# [11]	validation_0-auc:0.80898	validation_1-auc:0.97769
# [12]	validation_0-auc:0.80608	validation_1-auc:0.97839
# [13]	validation_0-auc:0.80385	validation_1-auc:0.97982
# [14]	validation_0-auc:0.80597	validation_1-auc:0.98047
# [15]	validation_0-auc:0.80397	validation_1-auc:0.98153
# [0]	validation_0-auc:0.73450	validation_1-auc:0.91469
# [1]	validation_0-auc:0.69751	validation_1-auc:0.93646
# [2]	validation_0-auc:0.71477	validation_1-auc:0.94510
# [3]	validation_0-auc:0.72713	validation_1-auc:0.95467
# [4]	validation_0-auc:0.74624	validation_1-auc:0.96116
# [5]	validation_0-auc:0.73160	validation_1-auc:0.96601
# [6]	validation_0-auc:0.71791	validation_1-auc:0.96812
# [7]	validation_0-auc:0.72452	validation_1-auc:0.97090
# [8]	validation_0-auc:0.73060	validation_1-auc:0.97312
# [0]	validation_0-auc:0.79296	validation_1-auc:0.90357
# [1]	validation_0-auc:0.79000	validation_1-auc:0.93291
# [2]	validation_0-auc:0.78266	validation_1-auc:0.94789
# [3]	validation_0-auc:0.79163	validation_1-auc:0.95724
# [4]	validation_0-auc:0.77390	validation_1-auc:0.96260
# [0]	validation_0-auc:0.83627	validation_1-auc:0.90424
# [1]	validation_0-auc:0.81996	validation_1-auc:0.93383
# [2]	validation_0-auc:0.83617	validation_1-auc:0.94686
# [3]	validation_0-auc:0.83408	validation_1-auc:0.95476
# [4]	validation_0-auc:0.84576	validation_1-auc:0.95983
# [5]	validation_0-auc:0.85302	validation_1-auc:0.96428
# [6]	validation_0-auc:0.85774	validation_1-auc:0.96744
# [7]	validation_0-auc:0.86137	validation_1-auc:0.96884
# [8]	validation_0-auc:0.84899	validation_1-auc:0.96940
# [9]	validation_0-auc:0.84168	validation_1-auc:0.97082
# [10]	validation_0-auc:0.86077	validation_1-auc:0.97272
# [11]	validation_0-auc:0.85406	validation_1-auc:0.97426
# [12]	validation_0-auc:0.85386	validation_1-auc:0.97507
# [0]	validation_0-auc:0.85346	validation_1-auc:0.90185
# [1]	validation_0-auc:0.84428	validation_1-auc:0.93084
# [2]	validation_0-auc:0.85983	validation_1-auc:0.93962
# [3]	validation_0-auc:0.85655	validation_1-auc:0.94880
# [4]	validation_0-auc:0.85769	validation_1-auc:0.95553
# [5]	validation_0-auc:0.86787	validation_1-auc:0.96039
# [6]	validation_0-auc:0.85294	validation_1-auc:0.96357
# [7]	validation_0-auc:0.85998	validation_1-auc:0.96619
# [8]	validation_0-auc:0.87576	validation_1-auc:0.96895
# [9]	validation_0-auc:0.86815	validation_1-auc:0.97105
# [10]	validation_0-auc:0.85479	validation_1-auc:0.97231
# [11]	validation_0-auc:0.85812	validation_1-auc:0.97326
# [12]	validation_0-auc:0.85337	validation_1-auc:0.97449
# [0]	validation_0-auc:0.81302	validation_1-auc:0.91160
# [1]	validation_0-auc:0.78494	validation_1-auc:0.93784
# [2]	validation_0-auc:0.77806	validation_1-auc:0.94882
# [3]	validation_0-auc:0.73409	validation_1-auc:0.96015
# [4]	validation_0-auc:0.75123	validation_1-auc:0.96397
# [5]	validation_0-auc:0.77678	validation_1-auc:0.96892
# [0]	validation_0-auc:0.79568	validation_1-auc:0.91494
# [1]	validation_0-auc:0.77954	validation_1-auc:0.94074
# [2]	validation_0-auc:0.78846	validation_1-auc:0.95025
# [3]	validation_0-auc:0.78173	validation_1-auc:0.95894
# [4]	validation_0-auc:0.79130	validation_1-auc:0.96179
# [5]	validation_0-auc:0.81220	validation_1-auc:0.96661
# [6]	validation_0-auc:0.81098	validation_1-auc:0.96823
# [7]	validation_0-auc:0.79260	validation_1-auc:0.96981
# [8]	validation_0-auc:0.79398	validation_1-auc:0.97123
# [9]	validation_0-auc:0.79901	validation_1-auc:0.97215
# [10]	validation_0-auc:0.79800	validation_1-auc:0.97462
# [0]	validation_0-auc:0.83124	validation_1-auc:0.90657
# [1]	validation_0-auc:0.82686	validation_1-auc:0.92572
# [2]	validation_0-auc:0.85156	validation_1-auc:0.94546
# [3]	validation_0-auc:0.85981	validation_1-auc:0.95388
# [4]	validation_0-auc:0.85343	validation_1-auc:0.96156
# [5]	validation_0-auc:0.85398	validation_1-auc:0.96469
# [6]	validation_0-auc:0.86013	validation_1-auc:0.96679
# [7]	validation_0-auc:0.85986	validation_1-auc:0.96954
# [8]	validation_0-auc:0.86328	validation_1-auc:0.97137
# [9]	validation_0-auc:0.85088	validation_1-auc:0.97269
# [10]	validation_0-auc:0.85712	validation_1-auc:0.97377
# [11]	validation_0-auc:0.85694	validation_1-auc:0.97532
# [12]	validation_0-auc:0.86633	validation_1-auc:0.97631
# [13]	validation_0-auc:0.86715	validation_1-auc:0.97685
# [14]	validation_0-auc:0.86742	validation_1-auc:0.97755
# [15]	validation_0-auc:0.85840	validation_1-auc:0.97879
# [16]	validation_0-auc:0.86697	validation_1-auc:0.97918
# [17]	validation_0-auc:0.86195	validation_1-auc:0.97966
# [18]	validation_0-auc:0.86423	validation_1-auc:0.97991
# [0]	validation_0-auc:0.79058	validation_1-auc:0.90887
# [1]	validation_0-auc:0.75071	validation_1-auc:0.93690
# [2]	validation_0-auc:0.73589	validation_1-auc:0.94587
# [3]	validation_0-auc:0.73403	validation_1-auc:0.95243
# [4]	validation_0-auc:0.71844	validation_1-auc:0.96259
# [0]	validation_0-auc:0.80472	validation_1-auc:0.91116
# [1]	validation_0-auc:0.79484	validation_1-auc:0.93217
# [2]	validation_0-auc:0.78585	validation_1-auc:0.94152
# [3]	validation_0-auc:0.80882	validation_1-auc:0.94993
# [4]	validation_0-auc:0.80131	validation_1-auc:0.95886
# [5]	validation_0-auc:0.80721	validation_1-auc:0.96235
# [6]	validation_0-auc:0.79200	validation_1-auc:0.96824
# [7]	validation_0-auc:0.79399	validation_1-auc:0.97045
# [8]	validation_0-auc:0.79532	validation_1-auc:0.97113
# [0]	validation_0-auc:0.74826	validation_1-auc:0.91778
# [1]	validation_0-auc:0.74489	validation_1-auc:0.93810
# [2]	validation_0-auc:0.76005	validation_1-auc:0.95004
# [3]	validation_0-auc:0.78069	validation_1-auc:0.95603
# [4]	validation_0-auc:0.77436	validation_1-auc:0.96230
# [5]	validation_0-auc:0.78827	validation_1-auc:0.96632
# [6]	validation_0-auc:0.78278	validation_1-auc:0.96895
# [7]	validation_0-auc:0.78315	validation_1-auc:0.96987
# [8]	validation_0-auc:0.78963	validation_1-auc:0.97137
# [9]	validation_0-auc:0.78695	validation_1-auc:0.97478
# [10]	validation_0-auc:0.78194	validation_1-auc:0.97599
# [11]	validation_0-auc:0.78516	validation_1-auc:0.97758
# [12]	validation_0-auc:0.78190	validation_1-auc:0.97796
# [13]	validation_0-auc:0.78893	validation_1-auc:0.97867
# [0]	validation_0-auc:0.80219	validation_1-auc:0.91275
# [1]	validation_0-auc:0.82189	validation_1-auc:0.92462
# [2]	validation_0-auc:0.78224	validation_1-auc:0.94328
# [3]	validation_0-auc:0.76945	validation_1-auc:0.95336
# [4]	validation_0-auc:0.74960	validation_1-auc:0.95980
# [5]	validation_0-auc:0.75022	validation_1-auc:0.96338
# [0]	validation_0-auc:0.86826	validation_1-auc:0.90427
# [1]	validation_0-auc:0.86704	validation_1-auc:0.93250
# [2]	validation_0-auc:0.88043	validation_1-auc:0.94757
# [3]	validation_0-auc:0.88959	validation_1-auc:0.95432
# [4]	validation_0-auc:0.88928	validation_1-auc:0.95924
# [5]	validation_0-auc:0.90529	validation_1-auc:0.96371
# [6]	validation_0-auc:0.89089	validation_1-auc:0.96707
# [7]	validation_0-auc:0.88204	validation_1-auc:0.97005
# [8]	validation_0-auc:0.87887	validation_1-auc:0.97323
# [9]	validation_0-auc:0.87319	validation_1-auc:0.97489
# [0]	validation_0-auc:0.79803	validation_1-auc:0.90492
# [1]	validation_0-auc:0.80738	validation_1-auc:0.93338
# [2]	validation_0-auc:0.78269	validation_1-auc:0.94546
# [3]	validation_0-auc:0.77175	validation_1-auc:0.95671
# [4]	validation_0-auc:0.78458	validation_1-auc:0.95988
# [5]	validation_0-auc:0.79913	validation_1-auc:0.96313
# [6]	validation_0-auc:0.79534	validation_1-auc:0.96670
# [0]	validation_0-auc:0.78880	validation_1-auc:0.90492
# [1]	validation_0-auc:0.77380	validation_1-auc:0.93063
# [2]	validation_0-auc:0.77911	validation_1-auc:0.94364
# [3]	validation_0-auc:0.76038	validation_1-auc:0.95509
# [4]	validation_0-auc:0.74853	validation_1-auc:0.96176
# [0]	validation_0-auc:0.78694	validation_1-auc:0.90996
# [1]	validation_0-auc:0.76347	validation_1-auc:0.93570
# [2]	validation_0-auc:0.76985	validation_1-auc:0.94658
# [3]	validation_0-auc:0.77577	validation_1-auc:0.95327
# [4]	validation_0-auc:0.75157	validation_1-auc:0.96106
# [0]	validation_0-auc:0.81951	validation_1-auc:0.90258
# [1]	validation_0-auc:0.79943	validation_1-auc:0.93101
# [2]	validation_0-auc:0.80775	validation_1-auc:0.94207
# [3]	validation_0-auc:0.80501	validation_1-auc:0.95386
# [4]	validation_0-auc:0.79609	validation_1-auc:0.96009
# [5]	validation_0-auc:0.81229	validation_1-auc:0.96334
# [0]	validation_0-auc:0.80173	validation_1-auc:0.90552
# [1]	validation_0-auc:0.81679	validation_1-auc:0.93625
# [2]	validation_0-auc:0.82554	validation_1-auc:0.94570
# [3]	validation_0-auc:0.81828	validation_1-auc:0.95675
# [4]	validation_0-auc:0.82318	validation_1-auc:0.96028
# [5]	validation_0-auc:0.83329	validation_1-auc:0.96587
# [6]	validation_0-auc:0.84020	validation_1-auc:0.96741
# [7]	validation_0-auc:0.82957	validation_1-auc:0.96954
# [8]	validation_0-auc:0.82764	validation_1-auc:0.97285
# [9]	validation_0-auc:0.83027	validation_1-auc:0.97362
# [10]	validation_0-auc:0.83438	validation_1-auc:0.97424
# [0]	validation_0-auc:0.81416	validation_1-auc:0.90579
# [1]	validation_0-auc:0.77293	validation_1-auc:0.92243
# [2]	validation_0-auc:0.80291	validation_1-auc:0.93802
# [3]	validation_0-auc:0.79364	validation_1-auc:0.95085
# [4]	validation_0-auc:0.79372	validation_1-auc:0.95821
# [0]	validation_0-auc:0.82030	validation_1-auc:0.90956
# [1]	validation_0-auc:0.82616	validation_1-auc:0.93601
# [2]	validation_0-auc:0.84798	validation_1-auc:0.94707
# [3]	validation_0-auc:0.83893	validation_1-auc:0.95342
# [4]	validation_0-auc:0.84640	validation_1-auc:0.95987
# [5]	validation_0-auc:0.84852	validation_1-auc:0.96336
# [6]	validation_0-auc:0.83765	validation_1-auc:0.96625
# [7]	validation_0-auc:0.84464	validation_1-auc:0.96955
# [8]	validation_0-auc:0.84501	validation_1-auc:0.97044
# [9]	validation_0-auc:0.85021	validation_1-auc:0.97208
# [10]	validation_0-auc:0.84878	validation_1-auc:0.97324
# [11]	validation_0-auc:0.84896	validation_1-auc:0.97463
# [12]	validation_0-auc:0.86170	validation_1-auc:0.97544
# [13]	validation_0-auc:0.85380	validation_1-auc:0.97655
# [14]	validation_0-auc:0.85720	validation_1-auc:0.97703
# [15]	validation_0-auc:0.85149	validation_1-auc:0.97775
# [16]	validation_0-auc:0.85918	validation_1-auc:0.97809
# [17]	validation_0-auc:0.85757	validation_1-auc:0.97890
# [0]	validation_0-auc:0.85069	validation_1-auc:0.89784
# [1]	validation_0-auc:0.82296	validation_1-auc:0.92451
# [2]	validation_0-auc:0.77640	validation_1-auc:0.93668
# [3]	validation_0-auc:0.79303	validation_1-auc:0.95214
# [4]	validation_0-auc:0.80649	validation_1-auc:0.95741
# [5]	validation_0-auc:0.81026	validation_1-auc:0.96200
# [0]	validation_0-auc:0.72906	validation_1-auc:0.91877
# [1]	validation_0-auc:0.76307	validation_1-auc:0.94164
# [2]	validation_0-auc:0.78307	validation_1-auc:0.95121
# [3]	validation_0-auc:0.75823	validation_1-auc:0.96062
# [4]	validation_0-auc:0.73594	validation_1-auc:0.96575
# [5]	validation_0-auc:0.73469	validation_1-auc:0.97038
# [6]	validation_0-auc:0.74187	validation_1-auc:0.97332
# [7]	validation_0-auc:0.74938	validation_1-auc:0.97560
# [0]	validation_0-auc:0.86733	validation_1-auc:0.89686
# [1]	validation_0-auc:0.84805	validation_1-auc:0.93148
# [2]	validation_0-auc:0.79849	validation_1-auc:0.94378
# [3]	validation_0-auc:0.82354	validation_1-auc:0.95171
# [4]	validation_0-auc:0.80450	validation_1-auc:0.95715
# [5]	validation_0-auc:0.80918	validation_1-auc:0.96079
# [0]	validation_0-auc:0.74268	validation_1-auc:0.91641
# [1]	validation_0-auc:0.71610	validation_1-auc:0.93530
# [2]	validation_0-auc:0.72375	validation_1-auc:0.94953
# [3]	validation_0-auc:0.70702	validation_1-auc:0.95940
# [4]	validation_0-auc:0.72318	validation_1-auc:0.96452
# [0]	validation_0-auc:0.86782	validation_1-auc:0.91434
# [1]	validation_0-auc:0.86375	validation_1-auc:0.92690
# [2]	validation_0-auc:0.88572	validation_1-auc:0.93982
# [3]	validation_0-auc:0.88030	validation_1-auc:0.94722
# [4]	validation_0-auc:0.86101	validation_1-auc:0.95570
# [5]	validation_0-auc:0.86178	validation_1-auc:0.96170
# [6]	validation_0-auc:0.86020	validation_1-auc:0.96519
# [7]	validation_0-auc:0.85650	validation_1-auc:0.96681
# [0]	validation_0-auc:0.79972	validation_1-auc:0.90225
# [1]	validation_0-auc:0.74138	validation_1-auc:0.93478
# [2]	validation_0-auc:0.73564	validation_1-auc:0.94687
# [3]	validation_0-auc:0.73993	validation_1-auc:0.95355
# [4]	validation_0-auc:0.74869	validation_1-auc:0.96030
# [5]	validation_0-auc:0.74339	validation_1-auc:0.96557
# [0]	validation_0-auc:0.81814	validation_1-auc:0.91536
# [1]	validation_0-auc:0.78843	validation_1-auc:0.93859
# [2]	validation_0-auc:0.79285	validation_1-auc:0.94880
# [3]	validation_0-auc:0.80276	validation_1-auc:0.95285
# [4]	validation_0-auc:0.82112	validation_1-auc:0.95912
# [5]	validation_0-auc:0.83294	validation_1-auc:0.96363
# [6]	validation_0-auc:0.83909	validation_1-auc:0.96472
# [7]	validation_0-auc:0.84214	validation_1-auc:0.96834
# [8]	validation_0-auc:0.84500	validation_1-auc:0.96928
# [9]	validation_0-auc:0.84653	validation_1-auc:0.97127
# [10]	validation_0-auc:0.84394	validation_1-auc:0.97189
# [11]	validation_0-auc:0.83541	validation_1-auc:0.97340
# [12]	validation_0-auc:0.83831	validation_1-auc:0.97381
# [13]	validation_0-auc:0.85205	validation_1-auc:0.97482
# [14]	validation_0-auc:0.85025	validation_1-auc:0.97546
# [15]	validation_0-auc:0.85252	validation_1-auc:0.97595
# [16]	validation_0-auc:0.84798	validation_1-auc:0.97654
# [17]	validation_0-auc:0.84845	validation_1-auc:0.97669
# [18]	validation_0-auc:0.85017	validation_1-auc:0.97767
# [19]	validation_0-auc:0.85213	validation_1-auc:0.97788
# [0]	validation_0-auc:0.84611	validation_1-auc:0.90300
# [1]	validation_0-auc:0.82593	validation_1-auc:0.93056
# [2]	validation_0-auc:0.81524	validation_1-auc:0.94257
# [3]	validation_0-auc:0.79068	validation_1-auc:0.94986
# [4]	validation_0-auc:0.80237	validation_1-auc:0.95714
# [0]	validation_0-auc:0.79917	validation_1-auc:0.90053
# [1]	validation_0-auc:0.83199	validation_1-auc:0.92887
# [2]	validation_0-auc:0.82571	validation_1-auc:0.94271
# [3]	validation_0-auc:0.81069	validation_1-auc:0.95643
# [4]	validation_0-auc:0.82080	validation_1-auc:0.95868
# [5]	validation_0-auc:0.81982	validation_1-auc:0.96156
# [0]	validation_0-auc:0.81598	validation_1-auc:0.89954
# [1]	validation_0-auc:0.83300	validation_1-auc:0.92942
# [2]	validation_0-auc:0.81890	validation_1-auc:0.94354
# [3]	validation_0-auc:0.82791	validation_1-auc:0.95374
# [4]	validation_0-auc:0.82220	validation_1-auc:0.95862
# [5]	validation_0-auc:0.83245	validation_1-auc:0.96026
# [6]	validation_0-auc:0.81333	validation_1-auc:0.96170
# [0]	validation_0-auc:0.85699	validation_1-auc:0.91242
# [1]	validation_0-auc:0.85703	validation_1-auc:0.93761
# [2]	validation_0-auc:0.85139	validation_1-auc:0.94368
# [3]	validation_0-auc:0.84640	validation_1-auc:0.95482
# [4]	validation_0-auc:0.85252	validation_1-auc:0.96067
# [5]	validation_0-auc:0.85321	validation_1-auc:0.96477
# [6]	validation_0-auc:0.85549	validation_1-auc:0.96803
# [0]	validation_0-auc:0.81946	validation_1-auc:0.90311
# [1]	validation_0-auc:0.79611	validation_1-auc:0.93295
# [2]	validation_0-auc:0.77468	validation_1-auc:0.94440
# [3]	validation_0-auc:0.76259	validation_1-auc:0.95090
# [4]	validation_0-auc:0.76859	validation_1-auc:0.95689
# [5]	validation_0-auc:0.76824	validation_1-auc:0.96220
# [0]	validation_0-auc:0.82467	validation_1-auc:0.91253
# [1]	validation_0-auc:0.80397	validation_1-auc:0.93654
# [2]	validation_0-auc:0.83202	validation_1-auc:0.94768
# [3]	validation_0-auc:0.84209	validation_1-auc:0.95422
# [4]	validation_0-auc:0.84594	validation_1-auc:0.96072
# [5]	validation_0-auc:0.83206	validation_1-auc:0.96498
# [6]	validation_0-auc:0.83885	validation_1-auc:0.96739
# [7]	validation_0-auc:0.84073	validation_1-auc:0.96918
# [8]	validation_0-auc:0.83911	validation_1-auc:0.97091
# [9]	validation_0-auc:0.83246	validation_1-auc:0.97246
# [0]	validation_0-auc:0.81646	validation_1-auc:0.90385
# [1]	validation_0-auc:0.84034	validation_1-auc:0.93207
# [2]	validation_0-auc:0.81937	validation_1-auc:0.94652
# [3]	validation_0-auc:0.83629	validation_1-auc:0.95670
# [4]	validation_0-auc:0.83057	validation_1-auc:0.96221
# [5]	validation_0-auc:0.81688	validation_1-auc:0.96411
# [0]	validation_0-auc:0.83571	validation_1-auc:0.90087
# [1]	validation_0-auc:0.81649	validation_1-auc:0.93042
# [2]	validation_0-auc:0.81814	validation_1-auc:0.94128
# [3]	validation_0-auc:0.82008	validation_1-auc:0.95326
# [4]	validation_0-auc:0.81510	validation_1-auc:0.95770
# [5]	validation_0-auc:0.81100	validation_1-auc:0.96300
# [0]	validation_0-auc:0.74881	validation_1-auc:0.90442
# [1]	validation_0-auc:0.78666	validation_1-auc:0.93506
# [2]	validation_0-auc:0.73135	validation_1-auc:0.95005
# [3]	validation_0-auc:0.73208	validation_1-auc:0.95856
# [4]	validation_0-auc:0.74559	validation_1-auc:0.96301
# [5]	validation_0-auc:0.76334	validation_1-auc:0.96722
# [0]	validation_0-auc:0.81246	validation_1-auc:0.90722
# [1]	validation_0-auc:0.82290	validation_1-auc:0.93711
# [2]	validation_0-auc:0.84500	validation_1-auc:0.94597
# [3]	validation_0-auc:0.84924	validation_1-auc:0.96035
# [4]	validation_0-auc:0.83037	validation_1-auc:0.96318
# [5]	validation_0-auc:0.82244	validation_1-auc:0.96764
# [6]	validation_0-auc:0.83839	validation_1-auc:0.97077
# [7]	validation_0-auc:0.84655	validation_1-auc:0.97234
# [0]	validation_0-auc:0.88247	validation_1-auc:0.90145
# [1]	validation_0-auc:0.84968	validation_1-auc:0.93131
# [2]	validation_0-auc:0.84599	validation_1-auc:0.94113
# [3]	validation_0-auc:0.85013	validation_1-auc:0.95236
# [4]	validation_0-auc:0.85970	validation_1-auc:0.95859
# [5]	validation_0-auc:0.84307	validation_1-auc:0.96332
# [0]	validation_0-auc:0.77031	validation_1-auc:0.90621
# [1]	validation_0-auc:0.77031	validation_1-auc:0.93410
# [2]	validation_0-auc:0.77615	validation_1-auc:0.94736
# [3]	validation_0-auc:0.76928	validation_1-auc:0.95455
# [4]	validation_0-auc:0.76807	validation_1-auc:0.96413
# [5]	validation_0-auc:0.78062	validation_1-auc:0.96667
# [6]	validation_0-auc:0.77684	validation_1-auc:0.96736
# [7]	validation_0-auc:0.77605	validation_1-auc:0.96889
# [8]	validation_0-auc:0.76075	validation_1-auc:0.97128
# [9]	validation_0-auc:0.74579	validation_1-auc:0.97364
# [0]	validation_0-auc:0.81491	validation_1-auc:0.90754
# [1]	validation_0-auc:0.76860	validation_1-auc:0.93546
# [2]	validation_0-auc:0.79364	validation_1-auc:0.94158
# [3]	validation_0-auc:0.78655	validation_1-auc:0.95057
# [4]	validation_0-auc:0.74431	validation_1-auc:0.95853
# [5]	validation_0-auc:0.74943	validation_1-auc:0.96108
# [0]	validation_0-auc:0.82023	validation_1-auc:0.90390
# [1]	validation_0-auc:0.79990	validation_1-auc:0.92968
# [2]	validation_0-auc:0.76367	validation_1-auc:0.94184
# [3]	validation_0-auc:0.77187	validation_1-auc:0.95126
# [4]	validation_0-auc:0.78870	validation_1-auc:0.95709
# [0]	validation_0-auc:0.79479	validation_1-auc:0.91122
# [1]	validation_0-auc:0.79135	validation_1-auc:0.93575
# [2]	validation_0-auc:0.77651	validation_1-auc:0.94967
# [3]	validation_0-auc:0.77036	validation_1-auc:0.95563
# [4]	validation_0-auc:0.73792	validation_1-auc:0.96149
# [5]	validation_0-auc:0.76719	validation_1-auc:0.96739
# [0]	validation_0-auc:0.85284	validation_1-auc:0.89920
# [1]	validation_0-auc:0.79878	validation_1-auc:0.92338
# [2]	validation_0-auc:0.79629	validation_1-auc:0.93558
# [3]	validation_0-auc:0.74644	validation_1-auc:0.95215
# [4]	validation_0-auc:0.77234	validation_1-auc:0.95962
# [5]	validation_0-auc:0.77629	validation_1-auc:0.96407
# [0]	validation_0-auc:0.73854	validation_1-auc:0.90557
# [1]	validation_0-auc:0.78119	validation_1-auc:0.92293
# [2]	validation_0-auc:0.73094	validation_1-auc:0.94719
# [3]	validation_0-auc:0.74157	validation_1-auc:0.95605
# [4]	validation_0-auc:0.74371	validation_1-auc:0.96033
# [5]	validation_0-auc:0.76946	validation_1-auc:0.96301
# [6]	validation_0-auc:0.76817	validation_1-auc:0.96768
# [0]	validation_0-auc:0.80833	validation_1-auc:0.89838
# [1]	validation_0-auc:0.80006	validation_1-auc:0.93207
# [2]	validation_0-auc:0.81690	validation_1-auc:0.93928
# [3]	validation_0-auc:0.81946	validation_1-auc:0.95168
# [4]	validation_0-auc:0.82645	validation_1-auc:0.95736
# [5]	validation_0-auc:0.83685	validation_1-auc:0.96235
# [6]	validation_0-auc:0.85365	validation_1-auc:0.96491
# [7]	validation_0-auc:0.85391	validation_1-auc:0.96781
# [8]	validation_0-auc:0.84336	validation_1-auc:0.97006
# [9]	validation_0-auc:0.85244	validation_1-auc:0.97267
# [10]	validation_0-auc:0.84629	validation_1-auc:0.97439
# [11]	validation_0-auc:0.84300	validation_1-auc:0.97470
# [0]	validation_0-auc:0.80021	validation_1-auc:0.91052
# [1]	validation_0-auc:0.75842	validation_1-auc:0.93738
# [2]	validation_0-auc:0.76526	validation_1-auc:0.94718
# [3]	validation_0-auc:0.76151	validation_1-auc:0.95442
# [4]	validation_0-auc:0.76174	validation_1-auc:0.96270
# [0]	validation_0-auc:0.82633	validation_1-auc:0.90953
# [1]	validation_0-auc:0.76379	validation_1-auc:0.93945
# [2]	validation_0-auc:0.74565	validation_1-auc:0.94600
# [3]	validation_0-auc:0.76251	validation_1-auc:0.95843
# [4]	validation_0-auc:0.74522	validation_1-auc:0.96441
# [5]	validation_0-auc:0.76111	validation_1-auc:0.96781
# [0]	validation_0-auc:0.83019	validation_1-auc:0.89538
# [1]	validation_0-auc:0.84291	validation_1-auc:0.92458
# [2]	validation_0-auc:0.85011	validation_1-auc:0.93688
# [3]	validation_0-auc:0.82539	validation_1-auc:0.95152
# [4]	validation_0-auc:0.82981	validation_1-auc:0.95847
# [5]	validation_0-auc:0.83693	validation_1-auc:0.96279
# [6]	validation_0-auc:0.84248	validation_1-auc:0.96668
# [7]	validation_0-auc:0.82139	validation_1-auc:0.96907
# [0]	validation_0-auc:0.79913	validation_1-auc:0.90986
# [1]	validation_0-auc:0.78675	validation_1-auc:0.93382
# [2]	validation_0-auc:0.77488	validation_1-auc:0.94751
# [3]	validation_0-auc:0.79080	validation_1-auc:0.95502
# [4]	validation_0-auc:0.78193	validation_1-auc:0.96184
# [0]	validation_0-auc:0.75617	validation_1-auc:0.91235
# [1]	validation_0-auc:0.74775	validation_1-auc:0.93434
# [2]	validation_0-auc:0.78216	validation_1-auc:0.94358
# [3]	validation_0-auc:0.77709	validation_1-auc:0.95479
# [4]	validation_0-auc:0.74931	validation_1-auc:0.95951
# [5]	validation_0-auc:0.76043	validation_1-auc:0.96312
# [6]	validation_0-auc:0.77155	validation_1-auc:0.96771
# [7]	validation_0-auc:0.77236	validation_1-auc:0.96991
# [0]	validation_0-auc:0.82320	validation_1-auc:0.91267
# [1]	validation_0-auc:0.86265	validation_1-auc:0.93213
# [2]	validation_0-auc:0.84905	validation_1-auc:0.94740
# [3]	validation_0-auc:0.81844	validation_1-auc:0.95392
# [4]	validation_0-auc:0.81794	validation_1-auc:0.95884
# [5]	validation_0-auc:0.83583	validation_1-auc:0.96313
# [0]	validation_0-auc:0.85970	validation_1-auc:0.90127
# [1]	validation_0-auc:0.84457	validation_1-auc:0.93182
# [2]	validation_0-auc:0.84226	validation_1-auc:0.94509
# [3]	validation_0-auc:0.84230	validation_1-auc:0.95681
# [4]	validation_0-auc:0.84490	validation_1-auc:0.96272
# [5]	validation_0-auc:0.82887	validation_1-auc:0.96534
# [0]	validation_0-auc:0.75895	validation_1-auc:0.90910
# [1]	validation_0-auc:0.77788	validation_1-auc:0.94097
# [2]	validation_0-auc:0.75522	validation_1-auc:0.94814
# [3]	validation_0-auc:0.76830	validation_1-auc:0.95659
# [4]	validation_0-auc:0.77618	validation_1-auc:0.96154
# [5]	validation_0-auc:0.77990	validation_1-auc:0.96582
# [6]	validation_0-auc:0.77798	validation_1-auc:0.96792
# [7]	validation_0-auc:0.76912	validation_1-auc:0.96977
# [8]	validation_0-auc:0.74746	validation_1-auc:0.97104
# [9]	validation_0-auc:0.74915	validation_1-auc:0.97191
# [0]	validation_0-auc:0.83383	validation_1-auc:0.90468
# [1]	validation_0-auc:0.81515	validation_1-auc:0.93202
# [2]	validation_0-auc:0.81295	validation_1-auc:0.94353
# [3]	validation_0-auc:0.84002	validation_1-auc:0.95353
# [4]	validation_0-auc:0.84022	validation_1-auc:0.95948
# [5]	validation_0-auc:0.84418	validation_1-auc:0.96250
# [6]	validation_0-auc:0.80607	validation_1-auc:0.96604
# [7]	validation_0-auc:0.80628	validation_1-auc:0.96756
# [8]	validation_0-auc:0.82826	validation_1-auc:0.97007
# [9]	validation_0-auc:0.82478	validation_1-auc:0.97130
# [0]	validation_0-auc:0.77363	validation_1-auc:0.90802
# [1]	validation_0-auc:0.80687	validation_1-auc:0.92977
# [2]	validation_0-auc:0.74031	validation_1-auc:0.94535
# [3]	validation_0-auc:0.75996	validation_1-auc:0.95585
# [4]	validation_0-auc:0.73867	validation_1-auc:0.96205
# [5]	validation_0-auc:0.75315	validation_1-auc:0.96555
# [6]	validation_0-auc:0.76243	validation_1-auc:0.96915
# [0]	validation_0-auc:0.82265	validation_1-auc:0.91067
# [1]	validation_0-auc:0.81072	validation_1-auc:0.93659
# [2]	validation_0-auc:0.84541	validation_1-auc:0.94549
# [3]	validation_0-auc:0.83284	validation_1-auc:0.95761
# [4]	validation_0-auc:0.82667	validation_1-auc:0.96214
# [5]	validation_0-auc:0.84467	validation_1-auc:0.96575
# [6]	validation_0-auc:0.84372	validation_1-auc:0.96924
# [0]	validation_0-auc:0.81553	validation_1-auc:0.90997
# [1]	validation_0-auc:0.79495	validation_1-auc:0.93039
# [2]	validation_0-auc:0.80550	validation_1-auc:0.94937
# [3]	validation_0-auc:0.80826	validation_1-auc:0.95679
# [4]	validation_0-auc:0.79184	validation_1-auc:0.96120
# [5]	validation_0-auc:0.80183	validation_1-auc:0.96645
# [0]	validation_0-auc:0.80163	validation_1-auc:0.90455
# [1]	validation_0-auc:0.84512	validation_1-auc:0.93469
# [2]	validation_0-auc:0.82711	validation_1-auc:0.94320
# [3]	validation_0-auc:0.82733	validation_1-auc:0.95089
# [4]	validation_0-auc:0.84984	validation_1-auc:0.95805
# [5]	validation_0-auc:0.84933	validation_1-auc:0.96362
# [6]	validation_0-auc:0.83974	validation_1-auc:0.96692
# [7]	validation_0-auc:0.84150	validation_1-auc:0.96928
# [8]	validation_0-auc:0.83996	validation_1-auc:0.97098
# [9]	validation_0-auc:0.83231	validation_1-auc:0.97244
# [0]	validation_0-auc:0.78626	validation_1-auc:0.90368
# [1]	validation_0-auc:0.84989	validation_1-auc:0.93223
# [2]	validation_0-auc:0.83239	validation_1-auc:0.94280
# [3]	validation_0-auc:0.81604	validation_1-auc:0.95445
# [4]	validation_0-auc:0.81494	validation_1-auc:0.95831
# [5]	validation_0-auc:0.83353	validation_1-auc:0.96406
# [0]	validation_0-auc:0.75808	validation_1-auc:0.91051
# [1]	validation_0-auc:0.75225	validation_1-auc:0.93564
# [2]	validation_0-auc:0.76658	validation_1-auc:0.94640
# [3]	validation_0-auc:0.76008	validation_1-auc:0.95846
# [4]	validation_0-auc:0.75284	validation_1-auc:0.96321
# [5]	validation_0-auc:0.71474	validation_1-auc:0.96761
# [6]	validation_0-auc:0.74661	validation_1-auc:0.97018
# [7]	validation_0-auc:0.73170	validation_1-auc:0.97172
# [0]	validation_0-auc:0.73277	validation_1-auc:0.90320
# [1]	validation_0-auc:0.73807	validation_1-auc:0.93242
# [2]	validation_0-auc:0.74706	validation_1-auc:0.94610
# [3]	validation_0-auc:0.74735	validation_1-auc:0.95405
# [4]	validation_0-auc:0.72793	validation_1-auc:0.96335
# [5]	validation_0-auc:0.73208	validation_1-auc:0.96589
# [6]	validation_0-auc:0.76135	validation_1-auc:0.96875
# [7]	validation_0-auc:0.75040	validation_1-auc:0.97191
# [8]	validation_0-auc:0.74689	validation_1-auc:0.97388
# [9]	validation_0-auc:0.73346	validation_1-auc:0.97649
# [10]	validation_0-auc:0.73588	validation_1-auc:0.97695
# [0]	validation_0-auc:0.76174	validation_1-auc:0.90908
# [1]	validation_0-auc:0.72710	validation_1-auc:0.93323
# [2]	validation_0-auc:0.75034	validation_1-auc:0.94577
# [3]	validation_0-auc:0.74884	validation_1-auc:0.95358
# [4]	validation_0-auc:0.74825	validation_1-auc:0.96096
# [5]	validation_0-auc:0.74291	validation_1-auc:0.96562
# [0]	validation_0-auc:0.82841	validation_1-auc:0.90002
# [1]	validation_0-auc:0.81489	validation_1-auc:0.92812
# [2]	validation_0-auc:0.80197	validation_1-auc:0.94410
# [3]	validation_0-auc:0.80306	validation_1-auc:0.95505
# [4]	validation_0-auc:0.83666	validation_1-auc:0.95960
# [5]	validation_0-auc:0.80306	validation_1-auc:0.96269
# [6]	validation_0-auc:0.76066	validation_1-auc:0.96661
# [7]	validation_0-auc:0.75947	validation_1-auc:0.96803
# [8]	validation_0-auc:0.74744	validation_1-auc:0.96949
# [9]	validation_0-auc:0.74799	validation_1-auc:0.97108
# [0]	validation_0-auc:0.82444	validation_1-auc:0.90722
# [1]	validation_0-auc:0.82160	validation_1-auc:0.93421
# [2]	validation_0-auc:0.84168	validation_1-auc:0.94347
# [3]	validation_0-auc:0.81027	validation_1-auc:0.95494
# [4]	validation_0-auc:0.81206	validation_1-auc:0.96143
# [5]	validation_0-auc:0.80942	validation_1-auc:0.96852
# [6]	validation_0-auc:0.80878	validation_1-auc:0.97030
#     precision    recall    fscore  accuracy       auc  miss_rate  \
# 0    0.144000  0.486486  0.222222  0.738046  0.622748   0.053521
# 1    0.161290  0.454545  0.238095  0.800416  0.640219   0.046753
# 2    0.159091  0.750000  0.262500  0.754678  0.752483   0.019284
# 3    0.065693  0.750000  0.120805  0.727651  0.738539   0.008571
# 4    0.145038  0.826087  0.246753  0.758836  0.790773   0.010959
# ..        ...       ...       ...       ...       ...        ...
# 95   0.133929  0.714286  0.225564  0.785863  0.751708   0.015873
# 96   0.153846  0.692308  0.251748  0.777547  0.737363   0.021390
# 97   0.098485  0.619048  0.169935  0.735967  0.680176   0.022599
# 98   0.102564  0.631579  0.176471  0.767152  0.702153   0.018970
# 99   0.122807  0.518519  0.198582  0.765073  0.649127   0.035326
#
#     fall_out_rate
# 0        0.240991
# 1        0.174107
# 2        0.245033
# 3        0.272921
# 4        0.244541
# ..            ...
# 95       0.210870
# 96       0.217582
# 97       0.258696
# 98       0.227273
# 99       0.220264
#
# [100 rows x 7 columns]
